# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
target_directory = os.path.join(parent_dir, '/local0/rossin/git/CRN-GenerativeAI/FINAL_nicolo/LogicCircuitHF_4s_6r_SIL')
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Working directory set to: /local0/rossin/git/CRN-GenerativeAI/FINAL_nicolo
# Target directory set to: /local0/rossin/git/CRN-GenerativeAI/FINAL_nicolo/LogicCircuitHF_4s_6r_SIL

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_hill_production_library

# Import Reward packages
from RL4CRN.rewards.deterministic import dynamic_tracking_error

# %%
# Filename for loading the agent checkpoint
# load_path = '/local0/rossin/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/RPA_3species_5rxns/models/' 
# get directory of this script (must work in a jupyter notebook as well)
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/rossin/git/CRN-GenerativeAI/FINAL_nicolo/LogicCircuitHF_4s_6r_SIL/models

# %%
productions = []
dilutions = []
n_inputs = 3
species_labels = [f'X_{i+1}' for i in range(n_inputs)] 
for i,s in enumerate(species_labels):
    productions.append(MassAction(reactant_labels=[], product_labels=[s], input_channels=[f'u_{i+1}'], params=[1.], params_controllability=[True]))
    dilutions.append(MassAction(reactant_labels=[s], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True])) 

# add diluting output
species_labels.append('OUT') # add output species label
dilutions.append(MassAction(reactant_labels=['OUT'], product_labels=[], input_channels=[None], params=[1.0], params_controllability=[True]))
# productions.append(MassAction(reactant_labels=[], product_labels=['OUT'], input_channels=[None], params=[.5], params_controllability=[True]))

# support_nodes = ['S1', 'S2']
# species_labels.extend(support_nodes) # add support nodes to species labels

crn_template = IOCRN(productions + dilutions, output_labels=['OUT'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
library = construct_hill_production_library(species_labels=species_labels, max_product_order=1, max_num_regulators=2)
library.add_reactions(productions+dilutions) # add the production reactions to the library
library.prepare_lookup_tables()

crn_template.set_library_context(library)

M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")



device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
print(f'Number of CPUs available: {os.cpu_count()}') 

# %%
from RL4CRN.utils.visualizations import plot_truth_table

# Hyperparameters
max_added_reactions = 6                             # Maximum number of reactions
N_CPUs = os.cpu_count()                             # Number of CPUs          
N = 10*N_CPUs                                       # Number of samples (batch size)    
width = 1024                                        # Width of the neural networks  
depth = 5                                           # Depth of the neural networks 
deep_layer_size = 1024*10                           # Size of the deep layer encoding the CRNs
allow_input_influence = False                       # Allow input influence in the policy
learning_rate = 1e-4                                # Learning rate for the optimizer 
hall_of_fame_size = 30                              # Size of the hall of fame  
entropy_scheduler = {                               # Entropy scheduler parameters 
    'entropy_weight': 1e-3, 
    'topk_entropy_weight' : 1.0,
    'remainder_entropy_weight' : 1.0,
    'entropy_update_coefficient': 1, 
    'entropy_schedule': 1000, 
    'minimum_entropy_weight': 0.0
}
entropy_weights_per_head = {'structure': 2.0, 'continuous': 1.0, 'discrete': 0.0, 'input_influence': 0.0} 
structure_head_temperature = {"target_entropy_ratio_to_max": np.log(5)/np.log(M), "initial_temperature": 1.0, "rate": 0.0, "current_temperature": 1.0}
risk_scheduler = {                                  # Risk scheduler parameters
    'risk': 0.95, 
    'risk_update': 0.0, 
    'max_risk': 1.0, 
    'risk_schedule': 1000
}
epoch_num = 300                                     # Number of epochs for training
render_schedule = 10                                 # Render every # of epochs
render_mode = {                                     # Mode of the experiment
    'style': 'logger', 
    'task': 'transients + logic', 
    'format': 'image',
    'topology': True,
    'bounds': [2.5]
}
# Ordering specific parameters
ordering_parameters = {
    'enforce_ordering': False,
    'constraint_weight' : float('inf')
}

render_n_best = 10                                                    # Number of best CRNs to plot responses for
render_disregard_percentage = 0.99                                    # Percentage of worst CRNs to disregard in the responses plotting

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_independent'}

# Time horizon for the simulation
t_f = 100                                           # Final time for the simulation
N_t = 1000                                          # Number of time steps
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
# all combination of inputs between 0 and 1 
nums = [0., 1.]
u_list = [np.array(u) for u in product(*[nums for _ in range(n_inputs)])] # list of input combinations, each input is a numpy array of shape (p,)

# --- define the logic function ---
logic_target = lambda u : (u[0] and u[1]) or (u[1] and u[2])  # Example: Majority function

# Construct the reference setpoints
r_list = [np.array([float(logic_target(u))]) for u in u_list]  # list of reference outputs, each output is a numpy array of shape (q,)

# Plot the truth table for the target logic function
plot_truth_table(u_list, r_list, title='Truth Table for Target Logic Function')

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.0 for _ in species_labels]])

# Construct the weights for the performance metric
# w = np.ones(N_t)
# w[(len(w)//5)*4:] = w[(len(w)//5)*4:]*2
# w[:(len(w)//5)] = w[:(len(w)//5)]*0.25
# w = w[np.newaxis, :]
# No transients
w = np.zeros((1, N_t))
w[:, -1] = 1.0 * N_t

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return dynamic_tracking_error(state, u_list, x0_list, time_horizon, r_list, w, norm=1, LARGE_NUMBER=1e4)
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['OUT', 'X_1', 'X_2', 'X_3']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_3 ----> ∅;  [MAK(1.0)]
# OUT ----> ∅;  [MAK(1.0)]
# Library of possible reactions:
# Number of reactions: 135
# R0: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R1: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R2: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R3: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R4: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R5: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R6: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R7: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R8: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R9: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R10: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R11: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R12: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R13: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R14: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R15: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R16: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R17: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R18: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R19: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R20: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R21: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R22: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R23: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R24: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R25: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R26: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R27: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R28: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R29: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R30: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R31: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R32: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R33: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R34: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R35: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R36: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R37: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R38: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R39: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R40: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R41: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R42: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R43: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R44: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R45: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R46: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R47: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R48: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R49: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R50: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R51: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R52: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R53: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R54: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R55: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R56: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R57: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R58: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R59: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R60: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R61: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R62: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R63: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R64: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R65: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R66: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R67: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R68: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R69: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R70: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R71: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R72: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R73: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R74: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R75: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R76: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R77: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R78: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R79: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R80: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R81: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R82: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R83: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R84: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R85: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R86: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R87: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R88: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R89: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R90: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R91: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R92: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R93: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R94: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R95: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R96: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R97: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R98: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R99: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R100: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R101: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R102: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R103: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R104: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R105: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R106: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R107: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R108: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R109: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R110: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R111: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R112: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R113: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R114: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R115: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R116: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R117: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R118: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R119: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R120: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R121: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R122: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R123: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R124: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R125: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R126: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R127: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R128: ∅ ----> X_1;  [MAK(1.0, u_1)]
# R129: ∅ ----> X_2;  [MAK(1.0, u_2)]
# R130: ∅ ----> X_3;  [MAK(1.0, u_3)]
# R131: X_1 ----> ∅;  [MAK(1.0)]
# R132: X_2 ----> ∅;  [MAK(1.0)]
# R133: X_3 ----> ∅;  [MAK(1.0)]
# R134: OUT ----> ∅;  [MAK(1.0)]
# ------------------------------------------------
# Using device: cuda
# Number of CPUs available: 128

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
policy = AddReactionByOrderedIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, target_set_size=crn_template.num_reactions+max_added_reactions, allow_input_influence=False, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head,
                                    combinatorial_bias_enabled=ordering_parameters["enforce_ordering"], constraint_strength=ordering_parameters["constraint_weight"])

if ordering_parameters["enforce_ordering"]:
    policy = AddReactionByOrderedIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, target_set_size=crn_template.num_reactions+max_added_reactions, allow_input_influence=False, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head,
                                        combinatorial_bias_enabled=ordering_parameters["enforce_ordering"], constraint_strength=ordering_parameters["constraint_weight"])
else:
    policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=False, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=False, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device)

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library, allow_input_observation=allow_input_influence)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Test the model
from tqdm import tqdm

sorted_crns_rewards_list = []
for p in tqdm(input_paths):
    agent.policy.load_state_dict(torch.load(p, map_location=device))

    agent.policy.eval()
    mult_env.reset()
    for j in range(max_added_reactions):
        observations = mult_env.observe(observer, tensorizer)
        actions, raw_actions = agent.act(observations, actuator)
        out = mult_env.step(actions, stepper, raw_actions=raw_actions)
    rewards = mult_env.get_reward(compute_reward)

    # Gather the CRNs from the environments
    crns = mult_env.gather()

    # Sort the CRNs by rewards
    sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])
    sorted_crns_rewards_list.append(sorted_crns_rewards)
# Out:
# 100%|██████████| 1/1 [00:29<00:00, 29.90s/it]

# %%
# Plot the results
for  j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
    n_plot = 100
    ax = None
    for i in range(n_plot):
        x0_list = ic.get_ic(sorted_crns_rewards[i][0])
        time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
        fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
        model_name = os.path.basename(input_paths[j]).replace('.pth','')
        ax[0].set_title(f'Top IOCRNs from model {model_name} - Setpoint tracking responses')
        # print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
        # print(sorted_crns_rewards[i][0])

# %%
if save_flag:
    for j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
        load_filename = os.path.basename(input_paths[j]).replace('.pth','')
        output_path = os.path.join(target_directory, 'models', 'generated_' + load_filename + '.pth')
        print('Saving generated CRNs to file:','generated_' + output_path + '.pth')
        sorted_crns = [crn for crn, _ in sorted_crns_rewards]
        torch.save(sorted_crns, output_path)
# Out:
# Saving generated CRNs to file: generated_/local0/rossin/git/CRN-GenerativeAI/FINAL_nicolo/LogicCircuitHF_4s_6r_SIL/models/generated_2025-12-08 14:55:20.pth.pth
