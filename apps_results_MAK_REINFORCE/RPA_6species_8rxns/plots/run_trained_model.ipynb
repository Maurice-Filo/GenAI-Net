# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/RPA_6species_8rxns'
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Working directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Target directory set to: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/RPA_6species_8rxns

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import dynamic_tracking_error

# %%
# Filename for loading the agent checkpoint
# load_path = '/local0/rossin/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/RPA_3species_5rxns/models/' 
# get directory of this script (must work in a jupyter notebook as well)
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/RPA_6species_8rxns/models

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=[], product_labels=['Z_1'], input_channels=['u_1'], params=[1.], params_controllability=[True])
r2 = MassAction(reactant_labels=['X_1'], product_labels=[], input_channels=['u_2'], params=[1.], params_controllability=[True])
r3 = MassAction(reactant_labels=['X_1'], product_labels=['X_1', 'X_2'], input_channels=[None], params=[1.], params_controllability=[True])
r4 = MassAction(reactant_labels=['X_2'], product_labels=[], input_channels=['u_3'], params=[1.], params_controllability=[True])
crn_template = IOCRN([r1, r2, r3, r4], output_labels=['X_2'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X_1', 'X_2', 'Z_1', 'Z_2', 'Z_3', 'Z_4']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['X_1', 'X_2', 'Z_1']
# Output Species: ['X_2']
# ∅ ----> Z_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1.0, u_2)]
# X_1 ----> X_1 + X_2;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0, u_3)]
# Library of possible reactions:
# Number of reactions: 757
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X_1;  [MAK(None)]
# R2: ∅ ----> X_2;  [MAK(None)]
# R3: ∅ ----> Z_1;  [MAK(None)]
# R4: ∅ ----> Z_2;  [MAK(None)]
# R5: ∅ ----> Z_3;  [MAK(None)]
# R6: ∅ ----> Z_4;  [MAK(None)]
# R7: ∅ ----> X_1 + X_1;  [MAK(None)]
# R8: ∅ ----> X_1 + X_2;  [MAK(None)]
# R9: ∅ ----> X_1 + Z_1;  [MAK(None)]
# R10: ∅ ----> X_1 + Z_2;  [MAK(None)]
# R11: ∅ ----> X_1 + Z_3;  [MAK(None)]
# R12: ∅ ----> X_1 + Z_4;  [MAK(None)]
# R13: ∅ ----> X_2 + X_2;  [MAK(None)]
# R14: ∅ ----> X_2 + Z_1;  [MAK(None)]
# R15: ∅ ----> X_2 + Z_2;  [MAK(None)]
# R16: ∅ ----> X_2 + Z_3;  [MAK(None)]
# R17: ∅ ----> X_2 + Z_4;  [MAK(None)]
# R18: ∅ ----> Z_1 + Z_1;  [MAK(None)]
# R19: ∅ ----> Z_1 + Z_2;  [MAK(None)]
# R20: ∅ ----> Z_1 + Z_3;  [MAK(None)]
# R21: ∅ ----> Z_1 + Z_4;  [MAK(None)]
# R22: ∅ ----> Z_2 + Z_2;  [MAK(None)]
# R23: ∅ ----> Z_2 + Z_3;  [MAK(None)]
# R24: ∅ ----> Z_2 + Z_4;  [MAK(None)]
# R25: ∅ ----> Z_3 + Z_3;  [MAK(None)]
# R26: ∅ ----> Z_3 + Z_4;  [MAK(None)]
# R27: ∅ ----> Z_4 + Z_4;  [MAK(None)]
# R28: X_1 ----> ∅;  [MAK(None)]
# R29: X_1 ----> X_2;  [MAK(None)]
# R30: X_1 ----> Z_1;  [MAK(None)]
# R31: X_1 ----> Z_2;  [MAK(None)]
# R32: X_1 ----> Z_3;  [MAK(None)]
# R33: X_1 ----> Z_4;  [MAK(None)]
# R34: X_1 ----> X_1 + X_1;  [MAK(None)]
# R35: X_1 ----> X_1 + X_2;  [MAK(None)]
# R36: X_1 ----> X_1 + Z_1;  [MAK(None)]
# R37: X_1 ----> X_1 + Z_2;  [MAK(None)]
# R38: X_1 ----> X_1 + Z_3;  [MAK(None)]
# R39: X_1 ----> X_1 + Z_4;  [MAK(None)]
# R40: X_1 ----> X_2 + X_2;  [MAK(None)]
# R41: X_1 ----> X_2 + Z_1;  [MAK(None)]
# R42: X_1 ----> X_2 + Z_2;  [MAK(None)]
# R43: X_1 ----> X_2 + Z_3;  [MAK(None)]
# R44: X_1 ----> X_2 + Z_4;  [MAK(None)]
# R45: X_1 ----> Z_1 + Z_1;  [MAK(None)]
# R46: X_1 ----> Z_1 + Z_2;  [MAK(None)]
# R47: X_1 ----> Z_1 + Z_3;  [MAK(None)]
# R48: X_1 ----> Z_1 + Z_4;  [MAK(None)]
# R49: X_1 ----> Z_2 + Z_2;  [MAK(None)]
# R50: X_1 ----> Z_2 + Z_3;  [MAK(None)]
# R51: X_1 ----> Z_2 + Z_4;  [MAK(None)]
# R52: X_1 ----> Z_3 + Z_3;  [MAK(None)]
# R53: X_1 ----> Z_3 + Z_4;  [MAK(None)]
# R54: X_1 ----> Z_4 + Z_4;  [MAK(None)]
# R55: X_2 ----> ∅;  [MAK(None)]
# R56: X_2 ----> X_1;  [MAK(None)]
# R57: X_2 ----> Z_1;  [MAK(None)]
# R58: X_2 ----> Z_2;  [MAK(None)]
# R59: X_2 ----> Z_3;  [MAK(None)]
# R60: X_2 ----> Z_4;  [MAK(None)]
# R61: X_2 ----> X_1 + X_1;  [MAK(None)]
# R62: X_2 ----> X_1 + X_2;  [MAK(None)]
# R63: X_2 ----> X_1 + Z_1;  [MAK(None)]
# R64: X_2 ----> X_1 + Z_2;  [MAK(None)]
# R65: X_2 ----> X_1 + Z_3;  [MAK(None)]
# R66: X_2 ----> X_1 + Z_4;  [MAK(None)]
# R67: X_2 ----> X_2 + X_2;  [MAK(None)]
# R68: X_2 ----> X_2 + Z_1;  [MAK(None)]
# R69: X_2 ----> X_2 + Z_2;  [MAK(None)]
# R70: X_2 ----> X_2 + Z_3;  [MAK(None)]
# R71: X_2 ----> X_2 + Z_4;  [MAK(None)]
# R72: X_2 ----> Z_1 + Z_1;  [MAK(None)]
# R73: X_2 ----> Z_1 + Z_2;  [MAK(None)]
# R74: X_2 ----> Z_1 + Z_3;  [MAK(None)]
# R75: X_2 ----> Z_1 + Z_4;  [MAK(None)]
# R76: X_2 ----> Z_2 + Z_2;  [MAK(None)]
# R77: X_2 ----> Z_2 + Z_3;  [MAK(None)]
# R78: X_2 ----> Z_2 + Z_4;  [MAK(None)]
# R79: X_2 ----> Z_3 + Z_3;  [MAK(None)]
# R80: X_2 ----> Z_3 + Z_4;  [MAK(None)]
# R81: X_2 ----> Z_4 + Z_4;  [MAK(None)]
# R82: Z_1 ----> ∅;  [MAK(None)]
# R83: Z_1 ----> X_1;  [MAK(None)]
# R84: Z_1 ----> X_2;  [MAK(None)]
# R85: Z_1 ----> Z_2;  [MAK(None)]
# R86: Z_1 ----> Z_3;  [MAK(None)]
# R87: Z_1 ----> Z_4;  [MAK(None)]
# R88: Z_1 ----> X_1 + X_1;  [MAK(None)]
# R89: Z_1 ----> X_1 + X_2;  [MAK(None)]
# R90: Z_1 ----> X_1 + Z_1;  [MAK(None)]
# R91: Z_1 ----> X_1 + Z_2;  [MAK(None)]
# R92: Z_1 ----> X_1 + Z_3;  [MAK(None)]
# R93: Z_1 ----> X_1 + Z_4;  [MAK(None)]
# R94: Z_1 ----> X_2 + X_2;  [MAK(None)]
# R95: Z_1 ----> X_2 + Z_1;  [MAK(None)]
# R96: Z_1 ----> X_2 + Z_2;  [MAK(None)]
# R97: Z_1 ----> X_2 + Z_3;  [MAK(None)]
# R98: Z_1 ----> X_2 + Z_4;  [MAK(None)]
# R99: Z_1 ----> Z_1 + Z_1;  [MAK(None)]
# R100: Z_1 ----> Z_1 + Z_2;  [MAK(None)]
# R101: Z_1 ----> Z_1 + Z_3;  [MAK(None)]
# R102: Z_1 ----> Z_1 + Z_4;  [MAK(None)]
# R103: Z_1 ----> Z_2 + Z_2;  [MAK(None)]
# R104: Z_1 ----> Z_2 + Z_3;  [MAK(None)]
# R105: Z_1 ----> Z_2 + Z_4;  [MAK(None)]
# R106: Z_1 ----> Z_3 + Z_3;  [MAK(None)]
# R107: Z_1 ----> Z_3 + Z_4;  [MAK(None)]
# R108: Z_1 ----> Z_4 + Z_4;  [MAK(None)]
# R109: Z_2 ----> ∅;  [MAK(None)]
# R110: Z_2 ----> X_1;  [MAK(None)]
# R111: Z_2 ----> X_2;  [MAK(None)]
# R112: Z_2 ----> Z_1;  [MAK(None)]
# R113: Z_2 ----> Z_3;  [MAK(None)]
# R114: Z_2 ----> Z_4;  [MAK(None)]
# R115: Z_2 ----> X_1 + X_1;  [MAK(None)]
# R116: Z_2 ----> X_1 + X_2;  [MAK(None)]
# R117: Z_2 ----> X_1 + Z_1;  [MAK(None)]
# R118: Z_2 ----> X_1 + Z_2;  [MAK(None)]
# R119: Z_2 ----> X_1 + Z_3;  [MAK(None)]
# R120: Z_2 ----> X_1 + Z_4;  [MAK(None)]
# R121: Z_2 ----> X_2 + X_2;  [MAK(None)]
# R122: Z_2 ----> X_2 + Z_1;  [MAK(None)]
# R123: Z_2 ----> X_2 + Z_2;  [MAK(None)]
# R124: Z_2 ----> X_2 + Z_3;  [MAK(None)]
# R125: Z_2 ----> X_2 + Z_4;  [MAK(None)]
# R126: Z_2 ----> Z_1 + Z_1;  [MAK(None)]
# R127: Z_2 ----> Z_1 + Z_2;  [MAK(None)]
# R128: Z_2 ----> Z_1 + Z_3;  [MAK(None)]
# R129: Z_2 ----> Z_1 + Z_4;  [MAK(None)]
# R130: Z_2 ----> Z_2 + Z_2;  [MAK(None)]
# R131: Z_2 ----> Z_2 + Z_3;  [MAK(None)]
# R132: Z_2 ----> Z_2 + Z_4;  [MAK(None)]
# R133: Z_2 ----> Z_3 + Z_3;  [MAK(None)]
# R134: Z_2 ----> Z_3 + Z_4;  [MAK(None)]
# R135: Z_2 ----> Z_4 + Z_4;  [MAK(None)]
# R136: Z_3 ----> ∅;  [MAK(None)]
# R137: Z_3 ----> X_1;  [MAK(None)]
# R138: Z_3 ----> X_2;  [MAK(None)]
# R139: Z_3 ----> Z_1;  [MAK(None)]
# R140: Z_3 ----> Z_2;  [MAK(None)]
# R141: Z_3 ----> Z_4;  [MAK(None)]
# R142: Z_3 ----> X_1 + X_1;  [MAK(None)]
# R143: Z_3 ----> X_1 + X_2;  [MAK(None)]
# R144: Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R145: Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R146: Z_3 ----> X_1 + Z_3;  [MAK(None)]
# R147: Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R148: Z_3 ----> X_2 + X_2;  [MAK(None)]
# R149: Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R150: Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R151: Z_3 ----> X_2 + Z_3;  [MAK(None)]
# R152: Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R153: Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R154: Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R155: Z_3 ----> Z_1 + Z_3;  [MAK(None)]
# R156: Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R157: Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R158: Z_3 ----> Z_2 + Z_3;  [MAK(None)]
# R159: Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R160: Z_3 ----> Z_3 + Z_3;  [MAK(None)]
# R161: Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R162: Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R163: Z_4 ----> ∅;  [MAK(None)]
# R164: Z_4 ----> X_1;  [MAK(None)]
# R165: Z_4 ----> X_2;  [MAK(None)]
# R166: Z_4 ----> Z_1;  [MAK(None)]
# R167: Z_4 ----> Z_2;  [MAK(None)]
# R168: Z_4 ----> Z_3;  [MAK(None)]
# R169: Z_4 ----> X_1 + X_1;  [MAK(None)]
# R170: Z_4 ----> X_1 + X_2;  [MAK(None)]
# R171: Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R172: Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R173: Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R174: Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R175: Z_4 ----> X_2 + X_2;  [MAK(None)]
# R176: Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R177: Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R178: Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R179: Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R180: Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R181: Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R182: Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R183: Z_4 ----> Z_1 + Z_4;  [MAK(None)]
# R184: Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R185: Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R186: Z_4 ----> Z_2 + Z_4;  [MAK(None)]
# R187: Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R188: Z_4 ----> Z_3 + Z_4;  [MAK(None)]
# R189: Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R190: X_1 + X_1 ----> ∅;  [MAK(None)]
# R191: X_1 + X_1 ----> X_1;  [MAK(None)]
# R192: X_1 + X_1 ----> X_2;  [MAK(None)]
# R193: X_1 + X_1 ----> Z_1;  [MAK(None)]
# R194: X_1 + X_1 ----> Z_2;  [MAK(None)]
# R195: X_1 + X_1 ----> Z_3;  [MAK(None)]
# R196: X_1 + X_1 ----> Z_4;  [MAK(None)]
# R197: X_1 + X_1 ----> X_1 + X_2;  [MAK(None)]
# R198: X_1 + X_1 ----> X_1 + Z_1;  [MAK(None)]
# R199: X_1 + X_1 ----> X_1 + Z_2;  [MAK(None)]
# R200: X_1 + X_1 ----> X_1 + Z_3;  [MAK(None)]
# R201: X_1 + X_1 ----> X_1 + Z_4;  [MAK(None)]
# R202: X_1 + X_1 ----> X_2 + X_2;  [MAK(None)]
# R203: X_1 + X_1 ----> X_2 + Z_1;  [MAK(None)]
# R204: X_1 + X_1 ----> X_2 + Z_2;  [MAK(None)]
# R205: X_1 + X_1 ----> X_2 + Z_3;  [MAK(None)]
# R206: X_1 + X_1 ----> X_2 + Z_4;  [MAK(None)]
# R207: X_1 + X_1 ----> Z_1 + Z_1;  [MAK(None)]
# R208: X_1 + X_1 ----> Z_1 + Z_2;  [MAK(None)]
# R209: X_1 + X_1 ----> Z_1 + Z_3;  [MAK(None)]
# R210: X_1 + X_1 ----> Z_1 + Z_4;  [MAK(None)]
# R211: X_1 + X_1 ----> Z_2 + Z_2;  [MAK(None)]
# R212: X_1 + X_1 ----> Z_2 + Z_3;  [MAK(None)]
# R213: X_1 + X_1 ----> Z_2 + Z_4;  [MAK(None)]
# R214: X_1 + X_1 ----> Z_3 + Z_3;  [MAK(None)]
# R215: X_1 + X_1 ----> Z_3 + Z_4;  [MAK(None)]
# R216: X_1 + X_1 ----> Z_4 + Z_4;  [MAK(None)]
# R217: X_1 + X_2 ----> ∅;  [MAK(None)]
# R218: X_1 + X_2 ----> X_1;  [MAK(None)]
# R219: X_1 + X_2 ----> X_2;  [MAK(None)]
# R220: X_1 + X_2 ----> Z_1;  [MAK(None)]
# R221: X_1 + X_2 ----> Z_2;  [MAK(None)]
# R222: X_1 + X_2 ----> Z_3;  [MAK(None)]
# R223: X_1 + X_2 ----> Z_4;  [MAK(None)]
# R224: X_1 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R225: X_1 + X_2 ----> X_1 + Z_1;  [MAK(None)]
# R226: X_1 + X_2 ----> X_1 + Z_2;  [MAK(None)]
# R227: X_1 + X_2 ----> X_1 + Z_3;  [MAK(None)]
# R228: X_1 + X_2 ----> X_1 + Z_4;  [MAK(None)]
# R229: X_1 + X_2 ----> X_2 + X_2;  [MAK(None)]
# R230: X_1 + X_2 ----> X_2 + Z_1;  [MAK(None)]
# R231: X_1 + X_2 ----> X_2 + Z_2;  [MAK(None)]
# R232: X_1 + X_2 ----> X_2 + Z_3;  [MAK(None)]
# R233: X_1 + X_2 ----> X_2 + Z_4;  [MAK(None)]
# R234: X_1 + X_2 ----> Z_1 + Z_1;  [MAK(None)]
# R235: X_1 + X_2 ----> Z_1 + Z_2;  [MAK(None)]
# R236: X_1 + X_2 ----> Z_1 + Z_3;  [MAK(None)]
# R237: X_1 + X_2 ----> Z_1 + Z_4;  [MAK(None)]
# R238: X_1 + X_2 ----> Z_2 + Z_2;  [MAK(None)]
# R239: X_1 + X_2 ----> Z_2 + Z_3;  [MAK(None)]
# R240: X_1 + X_2 ----> Z_2 + Z_4;  [MAK(None)]
# R241: X_1 + X_2 ----> Z_3 + Z_3;  [MAK(None)]
# R242: X_1 + X_2 ----> Z_3 + Z_4;  [MAK(None)]
# R243: X_1 + X_2 ----> Z_4 + Z_4;  [MAK(None)]
# R244: X_1 + Z_1 ----> ∅;  [MAK(None)]
# R245: X_1 + Z_1 ----> X_1;  [MAK(None)]
# R246: X_1 + Z_1 ----> X_2;  [MAK(None)]
# R247: X_1 + Z_1 ----> Z_1;  [MAK(None)]
# R248: X_1 + Z_1 ----> Z_2;  [MAK(None)]
# R249: X_1 + Z_1 ----> Z_3;  [MAK(None)]
# R250: X_1 + Z_1 ----> Z_4;  [MAK(None)]
# R251: X_1 + Z_1 ----> X_1 + X_1;  [MAK(None)]
# R252: X_1 + Z_1 ----> X_1 + X_2;  [MAK(None)]
# R253: X_1 + Z_1 ----> X_1 + Z_2;  [MAK(None)]
# R254: X_1 + Z_1 ----> X_1 + Z_3;  [MAK(None)]
# R255: X_1 + Z_1 ----> X_1 + Z_4;  [MAK(None)]
# R256: X_1 + Z_1 ----> X_2 + X_2;  [MAK(None)]
# R257: X_1 + Z_1 ----> X_2 + Z_1;  [MAK(None)]
# R258: X_1 + Z_1 ----> X_2 + Z_2;  [MAK(None)]
# R259: X_1 + Z_1 ----> X_2 + Z_3;  [MAK(None)]
# R260: X_1 + Z_1 ----> X_2 + Z_4;  [MAK(None)]
# R261: X_1 + Z_1 ----> Z_1 + Z_1;  [MAK(None)]
# R262: X_1 + Z_1 ----> Z_1 + Z_2;  [MAK(None)]
# R263: X_1 + Z_1 ----> Z_1 + Z_3;  [MAK(None)]
# R264: X_1 + Z_1 ----> Z_1 + Z_4;  [MAK(None)]
# R265: X_1 + Z_1 ----> Z_2 + Z_2;  [MAK(None)]
# R266: X_1 + Z_1 ----> Z_2 + Z_3;  [MAK(None)]
# R267: X_1 + Z_1 ----> Z_2 + Z_4;  [MAK(None)]
# R268: X_1 + Z_1 ----> Z_3 + Z_3;  [MAK(None)]
# R269: X_1 + Z_1 ----> Z_3 + Z_4;  [MAK(None)]
# R270: X_1 + Z_1 ----> Z_4 + Z_4;  [MAK(None)]
# R271: X_1 + Z_2 ----> ∅;  [MAK(None)]
# R272: X_1 + Z_2 ----> X_1;  [MAK(None)]
# R273: X_1 + Z_2 ----> X_2;  [MAK(None)]
# R274: X_1 + Z_2 ----> Z_1;  [MAK(None)]
# R275: X_1 + Z_2 ----> Z_2;  [MAK(None)]
# R276: X_1 + Z_2 ----> Z_3;  [MAK(None)]
# R277: X_1 + Z_2 ----> Z_4;  [MAK(None)]
# R278: X_1 + Z_2 ----> X_1 + X_1;  [MAK(None)]
# R279: X_1 + Z_2 ----> X_1 + X_2;  [MAK(None)]
# R280: X_1 + Z_2 ----> X_1 + Z_1;  [MAK(None)]
# R281: X_1 + Z_2 ----> X_1 + Z_3;  [MAK(None)]
# R282: X_1 + Z_2 ----> X_1 + Z_4;  [MAK(None)]
# R283: X_1 + Z_2 ----> X_2 + X_2;  [MAK(None)]
# R284: X_1 + Z_2 ----> X_2 + Z_1;  [MAK(None)]
# R285: X_1 + Z_2 ----> X_2 + Z_2;  [MAK(None)]
# R286: X_1 + Z_2 ----> X_2 + Z_3;  [MAK(None)]
# R287: X_1 + Z_2 ----> X_2 + Z_4;  [MAK(None)]
# R288: X_1 + Z_2 ----> Z_1 + Z_1;  [MAK(None)]
# R289: X_1 + Z_2 ----> Z_1 + Z_2;  [MAK(None)]
# R290: X_1 + Z_2 ----> Z_1 + Z_3;  [MAK(None)]
# R291: X_1 + Z_2 ----> Z_1 + Z_4;  [MAK(None)]
# R292: X_1 + Z_2 ----> Z_2 + Z_2;  [MAK(None)]
# R293: X_1 + Z_2 ----> Z_2 + Z_3;  [MAK(None)]
# R294: X_1 + Z_2 ----> Z_2 + Z_4;  [MAK(None)]
# R295: X_1 + Z_2 ----> Z_3 + Z_3;  [MAK(None)]
# R296: X_1 + Z_2 ----> Z_3 + Z_4;  [MAK(None)]
# R297: X_1 + Z_2 ----> Z_4 + Z_4;  [MAK(None)]
# R298: X_1 + Z_3 ----> ∅;  [MAK(None)]
# R299: X_1 + Z_3 ----> X_1;  [MAK(None)]
# R300: X_1 + Z_3 ----> X_2;  [MAK(None)]
# R301: X_1 + Z_3 ----> Z_1;  [MAK(None)]
# R302: X_1 + Z_3 ----> Z_2;  [MAK(None)]
# R303: X_1 + Z_3 ----> Z_3;  [MAK(None)]
# R304: X_1 + Z_3 ----> Z_4;  [MAK(None)]
# R305: X_1 + Z_3 ----> X_1 + X_1;  [MAK(None)]
# R306: X_1 + Z_3 ----> X_1 + X_2;  [MAK(None)]
# R307: X_1 + Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R308: X_1 + Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R309: X_1 + Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R310: X_1 + Z_3 ----> X_2 + X_2;  [MAK(None)]
# R311: X_1 + Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R312: X_1 + Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R313: X_1 + Z_3 ----> X_2 + Z_3;  [MAK(None)]
# R314: X_1 + Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R315: X_1 + Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R316: X_1 + Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R317: X_1 + Z_3 ----> Z_1 + Z_3;  [MAK(None)]
# R318: X_1 + Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R319: X_1 + Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R320: X_1 + Z_3 ----> Z_2 + Z_3;  [MAK(None)]
# R321: X_1 + Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R322: X_1 + Z_3 ----> Z_3 + Z_3;  [MAK(None)]
# R323: X_1 + Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R324: X_1 + Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R325: X_1 + Z_4 ----> ∅;  [MAK(None)]
# R326: X_1 + Z_4 ----> X_1;  [MAK(None)]
# R327: X_1 + Z_4 ----> X_2;  [MAK(None)]
# R328: X_1 + Z_4 ----> Z_1;  [MAK(None)]
# R329: X_1 + Z_4 ----> Z_2;  [MAK(None)]
# R330: X_1 + Z_4 ----> Z_3;  [MAK(None)]
# R331: X_1 + Z_4 ----> Z_4;  [MAK(None)]
# R332: X_1 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R333: X_1 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R334: X_1 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R335: X_1 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R336: X_1 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R337: X_1 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R338: X_1 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R339: X_1 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R340: X_1 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R341: X_1 + Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R342: X_1 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R343: X_1 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R344: X_1 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R345: X_1 + Z_4 ----> Z_1 + Z_4;  [MAK(None)]
# R346: X_1 + Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R347: X_1 + Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R348: X_1 + Z_4 ----> Z_2 + Z_4;  [MAK(None)]
# R349: X_1 + Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R350: X_1 + Z_4 ----> Z_3 + Z_4;  [MAK(None)]
# R351: X_1 + Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R352: X_2 + X_2 ----> ∅;  [MAK(None)]
# R353: X_2 + X_2 ----> X_1;  [MAK(None)]
# R354: X_2 + X_2 ----> X_2;  [MAK(None)]
# R355: X_2 + X_2 ----> Z_1;  [MAK(None)]
# R356: X_2 + X_2 ----> Z_2;  [MAK(None)]
# R357: X_2 + X_2 ----> Z_3;  [MAK(None)]
# R358: X_2 + X_2 ----> Z_4;  [MAK(None)]
# R359: X_2 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R360: X_2 + X_2 ----> X_1 + X_2;  [MAK(None)]
# R361: X_2 + X_2 ----> X_1 + Z_1;  [MAK(None)]
# R362: X_2 + X_2 ----> X_1 + Z_2;  [MAK(None)]
# R363: X_2 + X_2 ----> X_1 + Z_3;  [MAK(None)]
# R364: X_2 + X_2 ----> X_1 + Z_4;  [MAK(None)]
# R365: X_2 + X_2 ----> X_2 + Z_1;  [MAK(None)]
# R366: X_2 + X_2 ----> X_2 + Z_2;  [MAK(None)]
# R367: X_2 + X_2 ----> X_2 + Z_3;  [MAK(None)]
# R368: X_2 + X_2 ----> X_2 + Z_4;  [MAK(None)]
# R369: X_2 + X_2 ----> Z_1 + Z_1;  [MAK(None)]
# R370: X_2 + X_2 ----> Z_1 + Z_2;  [MAK(None)]
# R371: X_2 + X_2 ----> Z_1 + Z_3;  [MAK(None)]
# R372: X_2 + X_2 ----> Z_1 + Z_4;  [MAK(None)]
# R373: X_2 + X_2 ----> Z_2 + Z_2;  [MAK(None)]
# R374: X_2 + X_2 ----> Z_2 + Z_3;  [MAK(None)]
# R375: X_2 + X_2 ----> Z_2 + Z_4;  [MAK(None)]
# R376: X_2 + X_2 ----> Z_3 + Z_3;  [MAK(None)]
# R377: X_2 + X_2 ----> Z_3 + Z_4;  [MAK(None)]
# R378: X_2 + X_2 ----> Z_4 + Z_4;  [MAK(None)]
# R379: X_2 + Z_1 ----> ∅;  [MAK(None)]
# R380: X_2 + Z_1 ----> X_1;  [MAK(None)]
# R381: X_2 + Z_1 ----> X_2;  [MAK(None)]
# R382: X_2 + Z_1 ----> Z_1;  [MAK(None)]
# R383: X_2 + Z_1 ----> Z_2;  [MAK(None)]
# R384: X_2 + Z_1 ----> Z_3;  [MAK(None)]
# R385: X_2 + Z_1 ----> Z_4;  [MAK(None)]
# R386: X_2 + Z_1 ----> X_1 + X_1;  [MAK(None)]
# R387: X_2 + Z_1 ----> X_1 + X_2;  [MAK(None)]
# R388: X_2 + Z_1 ----> X_1 + Z_1;  [MAK(None)]
# R389: X_2 + Z_1 ----> X_1 + Z_2;  [MAK(None)]
# R390: X_2 + Z_1 ----> X_1 + Z_3;  [MAK(None)]
# R391: X_2 + Z_1 ----> X_1 + Z_4;  [MAK(None)]
# R392: X_2 + Z_1 ----> X_2 + X_2;  [MAK(None)]
# R393: X_2 + Z_1 ----> X_2 + Z_2;  [MAK(None)]
# R394: X_2 + Z_1 ----> X_2 + Z_3;  [MAK(None)]
# R395: X_2 + Z_1 ----> X_2 + Z_4;  [MAK(None)]
# R396: X_2 + Z_1 ----> Z_1 + Z_1;  [MAK(None)]
# R397: X_2 + Z_1 ----> Z_1 + Z_2;  [MAK(None)]
# R398: X_2 + Z_1 ----> Z_1 + Z_3;  [MAK(None)]
# R399: X_2 + Z_1 ----> Z_1 + Z_4;  [MAK(None)]
# R400: X_2 + Z_1 ----> Z_2 + Z_2;  [MAK(None)]
# R401: X_2 + Z_1 ----> Z_2 + Z_3;  [MAK(None)]
# R402: X_2 + Z_1 ----> Z_2 + Z_4;  [MAK(None)]
# R403: X_2 + Z_1 ----> Z_3 + Z_3;  [MAK(None)]
# R404: X_2 + Z_1 ----> Z_3 + Z_4;  [MAK(None)]
# R405: X_2 + Z_1 ----> Z_4 + Z_4;  [MAK(None)]
# R406: X_2 + Z_2 ----> ∅;  [MAK(None)]
# R407: X_2 + Z_2 ----> X_1;  [MAK(None)]
# R408: X_2 + Z_2 ----> X_2;  [MAK(None)]
# R409: X_2 + Z_2 ----> Z_1;  [MAK(None)]
# R410: X_2 + Z_2 ----> Z_2;  [MAK(None)]
# R411: X_2 + Z_2 ----> Z_3;  [MAK(None)]
# R412: X_2 + Z_2 ----> Z_4;  [MAK(None)]
# R413: X_2 + Z_2 ----> X_1 + X_1;  [MAK(None)]
# R414: X_2 + Z_2 ----> X_1 + X_2;  [MAK(None)]
# R415: X_2 + Z_2 ----> X_1 + Z_1;  [MAK(None)]
# R416: X_2 + Z_2 ----> X_1 + Z_2;  [MAK(None)]
# R417: X_2 + Z_2 ----> X_1 + Z_3;  [MAK(None)]
# R418: X_2 + Z_2 ----> X_1 + Z_4;  [MAK(None)]
# R419: X_2 + Z_2 ----> X_2 + X_2;  [MAK(None)]
# R420: X_2 + Z_2 ----> X_2 + Z_1;  [MAK(None)]
# R421: X_2 + Z_2 ----> X_2 + Z_3;  [MAK(None)]
# R422: X_2 + Z_2 ----> X_2 + Z_4;  [MAK(None)]
# R423: X_2 + Z_2 ----> Z_1 + Z_1;  [MAK(None)]
# R424: X_2 + Z_2 ----> Z_1 + Z_2;  [MAK(None)]
# R425: X_2 + Z_2 ----> Z_1 + Z_3;  [MAK(None)]
# R426: X_2 + Z_2 ----> Z_1 + Z_4;  [MAK(None)]
# R427: X_2 + Z_2 ----> Z_2 + Z_2;  [MAK(None)]
# R428: X_2 + Z_2 ----> Z_2 + Z_3;  [MAK(None)]
# R429: X_2 + Z_2 ----> Z_2 + Z_4;  [MAK(None)]
# R430: X_2 + Z_2 ----> Z_3 + Z_3;  [MAK(None)]
# R431: X_2 + Z_2 ----> Z_3 + Z_4;  [MAK(None)]
# R432: X_2 + Z_2 ----> Z_4 + Z_4;  [MAK(None)]
# R433: X_2 + Z_3 ----> ∅;  [MAK(None)]
# R434: X_2 + Z_3 ----> X_1;  [MAK(None)]
# R435: X_2 + Z_3 ----> X_2;  [MAK(None)]
# R436: X_2 + Z_3 ----> Z_1;  [MAK(None)]
# R437: X_2 + Z_3 ----> Z_2;  [MAK(None)]
# R438: X_2 + Z_3 ----> Z_3;  [MAK(None)]
# R439: X_2 + Z_3 ----> Z_4;  [MAK(None)]
# R440: X_2 + Z_3 ----> X_1 + X_1;  [MAK(None)]
# R441: X_2 + Z_3 ----> X_1 + X_2;  [MAK(None)]
# R442: X_2 + Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R443: X_2 + Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R444: X_2 + Z_3 ----> X_1 + Z_3;  [MAK(None)]
# R445: X_2 + Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R446: X_2 + Z_3 ----> X_2 + X_2;  [MAK(None)]
# R447: X_2 + Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R448: X_2 + Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R449: X_2 + Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R450: X_2 + Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R451: X_2 + Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R452: X_2 + Z_3 ----> Z_1 + Z_3;  [MAK(None)]
# R453: X_2 + Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R454: X_2 + Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R455: X_2 + Z_3 ----> Z_2 + Z_3;  [MAK(None)]
# R456: X_2 + Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R457: X_2 + Z_3 ----> Z_3 + Z_3;  [MAK(None)]
# R458: X_2 + Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R459: X_2 + Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R460: X_2 + Z_4 ----> ∅;  [MAK(None)]
# R461: X_2 + Z_4 ----> X_1;  [MAK(None)]
# R462: X_2 + Z_4 ----> X_2;  [MAK(None)]
# R463: X_2 + Z_4 ----> Z_1;  [MAK(None)]
# R464: X_2 + Z_4 ----> Z_2;  [MAK(None)]
# R465: X_2 + Z_4 ----> Z_3;  [MAK(None)]
# R466: X_2 + Z_4 ----> Z_4;  [MAK(None)]
# R467: X_2 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R468: X_2 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R469: X_2 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R470: X_2 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R471: X_2 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R472: X_2 + Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R473: X_2 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R474: X_2 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R475: X_2 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R476: X_2 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R477: X_2 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R478: X_2 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R479: X_2 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R480: X_2 + Z_4 ----> Z_1 + Z_4;  [MAK(None)]
# R481: X_2 + Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R482: X_2 + Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R483: X_2 + Z_4 ----> Z_2 + Z_4;  [MAK(None)]
# R484: X_2 + Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R485: X_2 + Z_4 ----> Z_3 + Z_4;  [MAK(None)]
# R486: X_2 + Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R487: Z_1 + Z_1 ----> ∅;  [MAK(None)]
# R488: Z_1 + Z_1 ----> X_1;  [MAK(None)]
# R489: Z_1 + Z_1 ----> X_2;  [MAK(None)]
# R490: Z_1 + Z_1 ----> Z_1;  [MAK(None)]
# R491: Z_1 + Z_1 ----> Z_2;  [MAK(None)]
# R492: Z_1 + Z_1 ----> Z_3;  [MAK(None)]
# R493: Z_1 + Z_1 ----> Z_4;  [MAK(None)]
# R494: Z_1 + Z_1 ----> X_1 + X_1;  [MAK(None)]
# R495: Z_1 + Z_1 ----> X_1 + X_2;  [MAK(None)]
# R496: Z_1 + Z_1 ----> X_1 + Z_1;  [MAK(None)]
# R497: Z_1 + Z_1 ----> X_1 + Z_2;  [MAK(None)]
# R498: Z_1 + Z_1 ----> X_1 + Z_3;  [MAK(None)]
# R499: Z_1 + Z_1 ----> X_1 + Z_4;  [MAK(None)]
# R500: Z_1 + Z_1 ----> X_2 + X_2;  [MAK(None)]
# R501: Z_1 + Z_1 ----> X_2 + Z_1;  [MAK(None)]
# R502: Z_1 + Z_1 ----> X_2 + Z_2;  [MAK(None)]
# R503: Z_1 + Z_1 ----> X_2 + Z_3;  [MAK(None)]
# R504: Z_1 + Z_1 ----> X_2 + Z_4;  [MAK(None)]
# R505: Z_1 + Z_1 ----> Z_1 + Z_2;  [MAK(None)]
# R506: Z_1 + Z_1 ----> Z_1 + Z_3;  [MAK(None)]
# R507: Z_1 + Z_1 ----> Z_1 + Z_4;  [MAK(None)]
# R508: Z_1 + Z_1 ----> Z_2 + Z_2;  [MAK(None)]
# R509: Z_1 + Z_1 ----> Z_2 + Z_3;  [MAK(None)]
# R510: Z_1 + Z_1 ----> Z_2 + Z_4;  [MAK(None)]
# R511: Z_1 + Z_1 ----> Z_3 + Z_3;  [MAK(None)]
# R512: Z_1 + Z_1 ----> Z_3 + Z_4;  [MAK(None)]
# R513: Z_1 + Z_1 ----> Z_4 + Z_4;  [MAK(None)]
# R514: Z_1 + Z_2 ----> ∅;  [MAK(None)]
# R515: Z_1 + Z_2 ----> X_1;  [MAK(None)]
# R516: Z_1 + Z_2 ----> X_2;  [MAK(None)]
# R517: Z_1 + Z_2 ----> Z_1;  [MAK(None)]
# R518: Z_1 + Z_2 ----> Z_2;  [MAK(None)]
# R519: Z_1 + Z_2 ----> Z_3;  [MAK(None)]
# R520: Z_1 + Z_2 ----> Z_4;  [MAK(None)]
# R521: Z_1 + Z_2 ----> X_1 + X_1;  [MAK(None)]
# R522: Z_1 + Z_2 ----> X_1 + X_2;  [MAK(None)]
# R523: Z_1 + Z_2 ----> X_1 + Z_1;  [MAK(None)]
# R524: Z_1 + Z_2 ----> X_1 + Z_2;  [MAK(None)]
# R525: Z_1 + Z_2 ----> X_1 + Z_3;  [MAK(None)]
# R526: Z_1 + Z_2 ----> X_1 + Z_4;  [MAK(None)]
# R527: Z_1 + Z_2 ----> X_2 + X_2;  [MAK(None)]
# R528: Z_1 + Z_2 ----> X_2 + Z_1;  [MAK(None)]
# R529: Z_1 + Z_2 ----> X_2 + Z_2;  [MAK(None)]
# R530: Z_1 + Z_2 ----> X_2 + Z_3;  [MAK(None)]
# R531: Z_1 + Z_2 ----> X_2 + Z_4;  [MAK(None)]
# R532: Z_1 + Z_2 ----> Z_1 + Z_1;  [MAK(None)]
# R533: Z_1 + Z_2 ----> Z_1 + Z_3;  [MAK(None)]
# R534: Z_1 + Z_2 ----> Z_1 + Z_4;  [MAK(None)]
# R535: Z_1 + Z_2 ----> Z_2 + Z_2;  [MAK(None)]
# R536: Z_1 + Z_2 ----> Z_2 + Z_3;  [MAK(None)]
# R537: Z_1 + Z_2 ----> Z_2 + Z_4;  [MAK(None)]
# R538: Z_1 + Z_2 ----> Z_3 + Z_3;  [MAK(None)]
# R539: Z_1 + Z_2 ----> Z_3 + Z_4;  [MAK(None)]
# R540: Z_1 + Z_2 ----> Z_4 + Z_4;  [MAK(None)]
# R541: Z_1 + Z_3 ----> ∅;  [MAK(None)]
# R542: Z_1 + Z_3 ----> X_1;  [MAK(None)]
# R543: Z_1 + Z_3 ----> X_2;  [MAK(None)]
# R544: Z_1 + Z_3 ----> Z_1;  [MAK(None)]
# R545: Z_1 + Z_3 ----> Z_2;  [MAK(None)]
# R546: Z_1 + Z_3 ----> Z_3;  [MAK(None)]
# R547: Z_1 + Z_3 ----> Z_4;  [MAK(None)]
# R548: Z_1 + Z_3 ----> X_1 + X_1;  [MAK(None)]
# R549: Z_1 + Z_3 ----> X_1 + X_2;  [MAK(None)]
# R550: Z_1 + Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R551: Z_1 + Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R552: Z_1 + Z_3 ----> X_1 + Z_3;  [MAK(None)]
# R553: Z_1 + Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R554: Z_1 + Z_3 ----> X_2 + X_2;  [MAK(None)]
# R555: Z_1 + Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R556: Z_1 + Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R557: Z_1 + Z_3 ----> X_2 + Z_3;  [MAK(None)]
# R558: Z_1 + Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R559: Z_1 + Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R560: Z_1 + Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R561: Z_1 + Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R562: Z_1 + Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R563: Z_1 + Z_3 ----> Z_2 + Z_3;  [MAK(None)]
# R564: Z_1 + Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R565: Z_1 + Z_3 ----> Z_3 + Z_3;  [MAK(None)]
# R566: Z_1 + Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R567: Z_1 + Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R568: Z_1 + Z_4 ----> ∅;  [MAK(None)]
# R569: Z_1 + Z_4 ----> X_1;  [MAK(None)]
# R570: Z_1 + Z_4 ----> X_2;  [MAK(None)]
# R571: Z_1 + Z_4 ----> Z_1;  [MAK(None)]
# R572: Z_1 + Z_4 ----> Z_2;  [MAK(None)]
# R573: Z_1 + Z_4 ----> Z_3;  [MAK(None)]
# R574: Z_1 + Z_4 ----> Z_4;  [MAK(None)]
# R575: Z_1 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R576: Z_1 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R577: Z_1 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R578: Z_1 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R579: Z_1 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R580: Z_1 + Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R581: Z_1 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R582: Z_1 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R583: Z_1 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R584: Z_1 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R585: Z_1 + Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R586: Z_1 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R587: Z_1 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R588: Z_1 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R589: Z_1 + Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R590: Z_1 + Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R591: Z_1 + Z_4 ----> Z_2 + Z_4;  [MAK(None)]
# R592: Z_1 + Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R593: Z_1 + Z_4 ----> Z_3 + Z_4;  [MAK(None)]
# R594: Z_1 + Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R595: Z_2 + Z_2 ----> ∅;  [MAK(None)]
# R596: Z_2 + Z_2 ----> X_1;  [MAK(None)]
# R597: Z_2 + Z_2 ----> X_2;  [MAK(None)]
# R598: Z_2 + Z_2 ----> Z_1;  [MAK(None)]
# R599: Z_2 + Z_2 ----> Z_2;  [MAK(None)]
# R600: Z_2 + Z_2 ----> Z_3;  [MAK(None)]
# R601: Z_2 + Z_2 ----> Z_4;  [MAK(None)]
# R602: Z_2 + Z_2 ----> X_1 + X_1;  [MAK(None)]
# R603: Z_2 + Z_2 ----> X_1 + X_2;  [MAK(None)]
# R604: Z_2 + Z_2 ----> X_1 + Z_1;  [MAK(None)]
# R605: Z_2 + Z_2 ----> X_1 + Z_2;  [MAK(None)]
# R606: Z_2 + Z_2 ----> X_1 + Z_3;  [MAK(None)]
# R607: Z_2 + Z_2 ----> X_1 + Z_4;  [MAK(None)]
# R608: Z_2 + Z_2 ----> X_2 + X_2;  [MAK(None)]
# R609: Z_2 + Z_2 ----> X_2 + Z_1;  [MAK(None)]
# R610: Z_2 + Z_2 ----> X_2 + Z_2;  [MAK(None)]
# R611: Z_2 + Z_2 ----> X_2 + Z_3;  [MAK(None)]
# R612: Z_2 + Z_2 ----> X_2 + Z_4;  [MAK(None)]
# R613: Z_2 + Z_2 ----> Z_1 + Z_1;  [MAK(None)]
# R614: Z_2 + Z_2 ----> Z_1 + Z_2;  [MAK(None)]
# R615: Z_2 + Z_2 ----> Z_1 + Z_3;  [MAK(None)]
# R616: Z_2 + Z_2 ----> Z_1 + Z_4;  [MAK(None)]
# R617: Z_2 + Z_2 ----> Z_2 + Z_3;  [MAK(None)]
# R618: Z_2 + Z_2 ----> Z_2 + Z_4;  [MAK(None)]
# R619: Z_2 + Z_2 ----> Z_3 + Z_3;  [MAK(None)]
# R620: Z_2 + Z_2 ----> Z_3 + Z_4;  [MAK(None)]
# R621: Z_2 + Z_2 ----> Z_4 + Z_4;  [MAK(None)]
# R622: Z_2 + Z_3 ----> ∅;  [MAK(None)]
# R623: Z_2 + Z_3 ----> X_1;  [MAK(None)]
# R624: Z_2 + Z_3 ----> X_2;  [MAK(None)]
# R625: Z_2 + Z_3 ----> Z_1;  [MAK(None)]
# R626: Z_2 + Z_3 ----> Z_2;  [MAK(None)]
# R627: Z_2 + Z_3 ----> Z_3;  [MAK(None)]
# R628: Z_2 + Z_3 ----> Z_4;  [MAK(None)]
# R629: Z_2 + Z_3 ----> X_1 + X_1;  [MAK(None)]
# R630: Z_2 + Z_3 ----> X_1 + X_2;  [MAK(None)]
# R631: Z_2 + Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R632: Z_2 + Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R633: Z_2 + Z_3 ----> X_1 + Z_3;  [MAK(None)]
# R634: Z_2 + Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R635: Z_2 + Z_3 ----> X_2 + X_2;  [MAK(None)]
# R636: Z_2 + Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R637: Z_2 + Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R638: Z_2 + Z_3 ----> X_2 + Z_3;  [MAK(None)]
# R639: Z_2 + Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R640: Z_2 + Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R641: Z_2 + Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R642: Z_2 + Z_3 ----> Z_1 + Z_3;  [MAK(None)]
# R643: Z_2 + Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R644: Z_2 + Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R645: Z_2 + Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R646: Z_2 + Z_3 ----> Z_3 + Z_3;  [MAK(None)]
# R647: Z_2 + Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R648: Z_2 + Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R649: Z_2 + Z_4 ----> ∅;  [MAK(None)]
# R650: Z_2 + Z_4 ----> X_1;  [MAK(None)]
# R651: Z_2 + Z_4 ----> X_2;  [MAK(None)]
# R652: Z_2 + Z_4 ----> Z_1;  [MAK(None)]
# R653: Z_2 + Z_4 ----> Z_2;  [MAK(None)]
# R654: Z_2 + Z_4 ----> Z_3;  [MAK(None)]
# R655: Z_2 + Z_4 ----> Z_4;  [MAK(None)]
# R656: Z_2 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R657: Z_2 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R658: Z_2 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R659: Z_2 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R660: Z_2 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R661: Z_2 + Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R662: Z_2 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R663: Z_2 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R664: Z_2 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R665: Z_2 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R666: Z_2 + Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R667: Z_2 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R668: Z_2 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R669: Z_2 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R670: Z_2 + Z_4 ----> Z_1 + Z_4;  [MAK(None)]
# R671: Z_2 + Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R672: Z_2 + Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R673: Z_2 + Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R674: Z_2 + Z_4 ----> Z_3 + Z_4;  [MAK(None)]
# R675: Z_2 + Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R676: Z_3 + Z_3 ----> ∅;  [MAK(None)]
# R677: Z_3 + Z_3 ----> X_1;  [MAK(None)]
# R678: Z_3 + Z_3 ----> X_2;  [MAK(None)]
# R679: Z_3 + Z_3 ----> Z_1;  [MAK(None)]
# R680: Z_3 + Z_3 ----> Z_2;  [MAK(None)]
# R681: Z_3 + Z_3 ----> Z_3;  [MAK(None)]
# R682: Z_3 + Z_3 ----> Z_4;  [MAK(None)]
# R683: Z_3 + Z_3 ----> X_1 + X_1;  [MAK(None)]
# R684: Z_3 + Z_3 ----> X_1 + X_2;  [MAK(None)]
# R685: Z_3 + Z_3 ----> X_1 + Z_1;  [MAK(None)]
# R686: Z_3 + Z_3 ----> X_1 + Z_2;  [MAK(None)]
# R687: Z_3 + Z_3 ----> X_1 + Z_3;  [MAK(None)]
# R688: Z_3 + Z_3 ----> X_1 + Z_4;  [MAK(None)]
# R689: Z_3 + Z_3 ----> X_2 + X_2;  [MAK(None)]
# R690: Z_3 + Z_3 ----> X_2 + Z_1;  [MAK(None)]
# R691: Z_3 + Z_3 ----> X_2 + Z_2;  [MAK(None)]
# R692: Z_3 + Z_3 ----> X_2 + Z_3;  [MAK(None)]
# R693: Z_3 + Z_3 ----> X_2 + Z_4;  [MAK(None)]
# R694: Z_3 + Z_3 ----> Z_1 + Z_1;  [MAK(None)]
# R695: Z_3 + Z_3 ----> Z_1 + Z_2;  [MAK(None)]
# R696: Z_3 + Z_3 ----> Z_1 + Z_3;  [MAK(None)]
# R697: Z_3 + Z_3 ----> Z_1 + Z_4;  [MAK(None)]
# R698: Z_3 + Z_3 ----> Z_2 + Z_2;  [MAK(None)]
# R699: Z_3 + Z_3 ----> Z_2 + Z_3;  [MAK(None)]
# R700: Z_3 + Z_3 ----> Z_2 + Z_4;  [MAK(None)]
# R701: Z_3 + Z_3 ----> Z_3 + Z_4;  [MAK(None)]
# R702: Z_3 + Z_3 ----> Z_4 + Z_4;  [MAK(None)]
# R703: Z_3 + Z_4 ----> ∅;  [MAK(None)]
# R704: Z_3 + Z_4 ----> X_1;  [MAK(None)]
# R705: Z_3 + Z_4 ----> X_2;  [MAK(None)]
# R706: Z_3 + Z_4 ----> Z_1;  [MAK(None)]
# R707: Z_3 + Z_4 ----> Z_2;  [MAK(None)]
# R708: Z_3 + Z_4 ----> Z_3;  [MAK(None)]
# R709: Z_3 + Z_4 ----> Z_4;  [MAK(None)]
# R710: Z_3 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R711: Z_3 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R712: Z_3 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R713: Z_3 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R714: Z_3 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R715: Z_3 + Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R716: Z_3 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R717: Z_3 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R718: Z_3 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R719: Z_3 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R720: Z_3 + Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R721: Z_3 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R722: Z_3 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R723: Z_3 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R724: Z_3 + Z_4 ----> Z_1 + Z_4;  [MAK(None)]
# R725: Z_3 + Z_4 ----> Z_2 + Z_2;  [MAK(None)]
# R726: Z_3 + Z_4 ----> Z_2 + Z_3;  [MAK(None)]
# R727: Z_3 + Z_4 ----> Z_2 + Z_4;  [MAK(None)]
# R728: Z_3 + Z_4 ----> Z_3 + Z_3;  [MAK(None)]
# R729: Z_3 + Z_4 ----> Z_4 + Z_4;  [MAK(None)]
# R730: Z_4 + Z_4 ----> ∅;  [MAK(None)]
# R731: Z_4 + Z_4 ----> X_1;  [MAK(None)]
# R732: Z_4 + Z_4 ----> X_2;  [MAK(None)]
# R733: Z_4 + Z_4 ----> Z_1;  [MAK(None)]
# R734: Z_4 + Z_4 ----> Z_2;  [MAK(None)]
# R735: Z_4 + Z_4 ----> Z_3;  [MAK(None)]
# R736: Z_4 + Z_4 ----> Z_4;  [MAK(None)]
# R737: Z_4 + Z_4 ----> X_1 + X_1;  [MAK(None)]
# R738: Z_4 + Z_4 ----> X_1 + X_2;  [MAK(None)]
# R739: Z_4 + Z_4 ----> X_1 + Z_1;  [MAK(None)]
# R740: Z_4 + Z_4 ----> X_1 + Z_2;  [MAK(None)]
# R741: Z_4 + Z_4 ----> X_1 + Z_3;  [MAK(None)]
# R742: Z_4 + Z_4 ----> X_1 + Z_4;  [MAK(None)]
# R743: Z_4 + Z_4 ----> X_2 + X_2;  [MAK(None)]
# R744: Z_4 + Z_4 ----> X_2 + Z_1;  [MAK(None)]
# R745: Z_4 + Z_4 ----> X_2 + Z_2;  [MAK(None)]
# R746: Z_4 + Z_4 ----> X_2 + Z_3;  [MAK(None)]
# R747: Z_4 + Z_4 ----> X_2 + Z_4;  [MAK(None)]
# R748: Z_4 + Z_4 ----> Z_1 + Z_1;  [MAK(None)]
# R749: Z_4 + Z_4 ----> Z_1 + Z_2;  [MAK(None)]
# R750: Z_4 + Z_4 ----> Z_1 + Z_3;  [MAK(None)]
# R751: Z_4 + Z_4 ----> Z_1 + Z_4;  [MAK(None)]
#