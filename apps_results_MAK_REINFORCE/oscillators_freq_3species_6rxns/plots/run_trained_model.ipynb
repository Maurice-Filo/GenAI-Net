# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/'
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Working directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Target directory set to: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import oscillation_error

# %%
# Filename for loading the agent checkpoint
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/models

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=[], product_labels=['X_1'], input_channels=['u_1'], params=[1.], params_controllability=[True])
r2 = MassAction(reactant_labels=['X_1'], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True])
r3 = MassAction(reactant_labels=['X_2'], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True])
r4 = MassAction(reactant_labels=['X_3'], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True])
crn_template = IOCRN([r1, r2, r3, r4], output_labels=['X_3'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X_1', 'X_2', 'X_3']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_3 ----> ∅;  [MAK(1.0)]
# Library of possible reactions:
# Number of reactions: 91
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X_1;  [MAK(None)]
# R2: ∅ ----> X_2;  [MAK(None)]
# R3: ∅ ----> X_3;  [MAK(None)]
# R4: ∅ ----> X_1 + X_1;  [MAK(None)]
# R5: ∅ ----> X_1 + X_2;  [MAK(None)]
# R6: ∅ ----> X_1 + X_3;  [MAK(None)]
# R7: ∅ ----> X_2 + X_2;  [MAK(None)]
# R8: ∅ ----> X_2 + X_3;  [MAK(None)]
# R9: ∅ ----> X_3 + X_3;  [MAK(None)]
# R10: X_1 ----> ∅;  [MAK(None)]
# R11: X_1 ----> X_2;  [MAK(None)]
# R12: X_1 ----> X_3;  [MAK(None)]
# R13: X_1 ----> X_1 + X_1;  [MAK(None)]
# R14: X_1 ----> X_1 + X_2;  [MAK(None)]
# R15: X_1 ----> X_1 + X_3;  [MAK(None)]
# R16: X_1 ----> X_2 + X_2;  [MAK(None)]
# R17: X_1 ----> X_2 + X_3;  [MAK(None)]
# R18: X_1 ----> X_3 + X_3;  [MAK(None)]
# R19: X_2 ----> ∅;  [MAK(None)]
# R20: X_2 ----> X_1;  [MAK(None)]
# R21: X_2 ----> X_3;  [MAK(None)]
# R22: X_2 ----> X_1 + X_1;  [MAK(None)]
# R23: X_2 ----> X_1 + X_2;  [MAK(None)]
# R24: X_2 ----> X_1 + X_3;  [MAK(None)]
# R25: X_2 ----> X_2 + X_2;  [MAK(None)]
# R26: X_2 ----> X_2 + X_3;  [MAK(None)]
# R27: X_2 ----> X_3 + X_3;  [MAK(None)]
# R28: X_3 ----> ∅;  [MAK(None)]
# R29: X_3 ----> X_1;  [MAK(None)]
# R30: X_3 ----> X_2;  [MAK(None)]
# R31: X_3 ----> X_1 + X_1;  [MAK(None)]
# R32: X_3 ----> X_1 + X_2;  [MAK(None)]
# R33: X_3 ----> X_1 + X_3;  [MAK(None)]
# R34: X_3 ----> X_2 + X_2;  [MAK(None)]
# R35: X_3 ----> X_2 + X_3;  [MAK(None)]
# R36: X_3 ----> X_3 + X_3;  [MAK(None)]
# R37: X_1 + X_1 ----> ∅;  [MAK(None)]
# R38: X_1 + X_1 ----> X_1;  [MAK(None)]
# R39: X_1 + X_1 ----> X_2;  [MAK(None)]
# R40: X_1 + X_1 ----> X_3;  [MAK(None)]
# R41: X_1 + X_1 ----> X_1 + X_2;  [MAK(None)]
# R42: X_1 + X_1 ----> X_1 + X_3;  [MAK(None)]
# R43: X_1 + X_1 ----> X_2 + X_2;  [MAK(None)]
# R44: X_1 + X_1 ----> X_2 + X_3;  [MAK(None)]
# R45: X_1 + X_1 ----> X_3 + X_3;  [MAK(None)]
# R46: X_1 + X_2 ----> ∅;  [MAK(None)]
# R47: X_1 + X_2 ----> X_1;  [MAK(None)]
# R48: X_1 + X_2 ----> X_2;  [MAK(None)]
# R49: X_1 + X_2 ----> X_3;  [MAK(None)]
# R50: X_1 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R51: X_1 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R52: X_1 + X_2 ----> X_2 + X_2;  [MAK(None)]
# R53: X_1 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R54: X_1 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R55: X_1 + X_3 ----> ∅;  [MAK(None)]
# R56: X_1 + X_3 ----> X_1;  [MAK(None)]
# R57: X_1 + X_3 ----> X_2;  [MAK(None)]
# R58: X_1 + X_3 ----> X_3;  [MAK(None)]
# R59: X_1 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R60: X_1 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R61: X_1 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R62: X_1 + X_3 ----> X_2 + X_3;  [MAK(None)]
# R63: X_1 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R64: X_2 + X_2 ----> ∅;  [MAK(None)]
# R65: X_2 + X_2 ----> X_1;  [MAK(None)]
# R66: X_2 + X_2 ----> X_2;  [MAK(None)]
# R67: X_2 + X_2 ----> X_3;  [MAK(None)]
# R68: X_2 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R69: X_2 + X_2 ----> X_1 + X_2;  [MAK(None)]
# R70: X_2 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R71: X_2 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R72: X_2 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R73: X_2 + X_3 ----> ∅;  [MAK(None)]
# R74: X_2 + X_3 ----> X_1;  [MAK(None)]
# R75: X_2 + X_3 ----> X_2;  [MAK(None)]
# R76: X_2 + X_3 ----> X_3;  [MAK(None)]
# R77: X_2 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R78: X_2 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R79: X_2 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R80: X_2 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R81: X_2 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R82: X_3 + X_3 ----> ∅;  [MAK(None)]
# R83: X_3 + X_3 ----> X_1;  [MAK(None)]
# R84: X_3 + X_3 ----> X_2;  [MAK(None)]
# R85: X_3 + X_3 ----> X_3;  [MAK(None)]
# R86: X_3 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R87: X_3 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R88: X_3 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R89: X_3 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R90: X_3 + X_3 ----> X_2 + X_3;  [MAK(None)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Using device: cuda
# Number of CPUs available: 128

# %%
# Hyperparameters
max_added_reactions = 6                                 # Maximum number of reactions
N_CPUs = os.cpu_count()                                 # Number of CPUs          
N = 10*N_CPUs                                           # Number of samples (batch size)    
width = 1024                                            # Width of the neural networks  
depth = 5                                               # Depth of the neural networks 
deep_layer_size = 1024*10                               # Size of the deep layer encoding the CRNs
allow_input_influence = False                           # Allow input influence in the policy
learning_rate = 1e-3                                    # Learning rate for the optimizer 
hall_of_fame_size = 30                                  # Size of the hall of fame  
entropy_scheduler = {                                   # Entropy scheduler parameters 
    'entropy_weight': 1e-2 ,                            # Global entropy weight
    'entropy_weight_structure_head': 1.0,               # Entropy weight for the structure head
    'entropy_weight_continuous_head': 0.1,              # Entropy weight for the continuous parameters head
    'topk_entropy_weight': 1.0,                         # Entropy weight for the top-k actions
    'remainder_entropy_weight': 1.0,                    # Entropy weight for the remainder actions
    'entropy_update_coefficient': 1,                    # Entropy update coefficient (multiplicative)
    'entropy_schedule': 1000,                           # Entropy schedule (in epochs) 
    'minimum_entropy_weight': 0.0                       # Minimum entropy weight
}
structure_head_temperature = {
    'target_entropy_ratio_to_max': np.log(5)/np.log(M), 
    'initial_temperature': 1.0, 
    'rate': 0.0, 
    'current_temperature': 1.0}
risk_scheduler = {                                      # Risk scheduler parameters
    'risk': 0.9,                                        # Percentage of worst samples to disregard when computing the reward
    'risk_update': 0.0,                                 # Risk update coefficient (additive)
    'max_risk': 1.0,                                    # Maximum risk
    'risk_schedule': 1000                               # Risk schedule (in epochs)
}
epoch_num = 1000                                         # Number of epochs for training
render_schedule = 50                                    # Render every # of epochs
render_mode = {                                         # Mode of the experiment
    'style': 'logger',                                  
    'task': 'transients', 
    'format': 'image',
    'topology': True,
    'bounds': [2.5]
}
render_n_best = 10                                      # Number of best CRNs to plot responses for
render_disregard_percentage = risk_scheduler['risk']    # Percentage of worst CRNs to disregard in the responses plotting
sil_settings = {
    'sil_loss_weight': 1.0
}

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_1D'}        

# Time horizon for the simulation
t_f = 100                                               # Final time for the simulation
N_t = 1000                                              # Number of time steps in the simulation
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
periods = [10, 15, 20]
u_list = [np.array([1/p]) for p in periods]

# Construct the frequency list
f_list = u_list

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01, 0.01, 0.01]])

# Weight on the damping metric and initial time for peak detection
w = [0/10, 6/10, 1/10, 3/10]                              # [mean, frequency, damping, periodicity index]
t0 = 20.

# Rendering mode
mode = {                                           
    'style': 'logger', 
    'task': 'transients + frequency content', 
    'format': 'image',
    'bounds': [100.0], 
    'bounds_freq': [[1.5, 1]], 
    't0': t0, 
    'scale': 'linear'
}

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list, x0_list, time_horizon, f_list=f_list, mean_list=None, w=w, t0=t0, LARGE_NUMBER=1e4)

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
entropy_weights_per_head = {'structure': entropy_scheduler['entropy_weight_structure_head'], 'continuous': entropy_scheduler['entropy_weight_continuous_head'], 'discrete': 0.0, 'input_influence': 0.0} 
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=allow_input_influence, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=allow_input_influence, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device)

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library, allow_input_observation=allow_input_influence)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Test the model
from tqdm import tqdm
sorted_crns_rewards_list = []
for p in tqdm(input_paths):
    agent.policy.load_state_dict(torch.load(p, map_location=device))

    agent.policy.eval()
    mult_env.reset()
    for j in range(max_added_reactions):
        observations = mult_env.observe(observer, tensorizer)
        actions, raw_actions = agent.act(observations, actuator)
        out = mult_env.step(actions, stepper, raw_actions=raw_actions)

    rewards = mult_env.get_reward(compute_reward)

    # Gather the CRNs from the environments
    crns = mult_env.gather()

    # Sort the CRNs by rewards
    sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])
    sorted_crns_rewards_list.append(sorted_crns_rewards)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [cvHandleFailure, Error: -15] At t = 19.7182724251538, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.4175276900542, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2484967267222, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.4287914956443, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.79172262173078, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.0786394214929, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.3290286490479, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 70.255889950242 and h = 2.0252622378944, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 22.9192998724568, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.4463338619401, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.3575713932045, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.3209755661235, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.8003379643502, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 41.9226687753984, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.5096871002467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.754060291434, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.6214937639093, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 67.9083074094254, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.6684395451277, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.13754645491949, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.9008973491213, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 56.3755325025644 and h = 1.71781193891969, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 65.6560009995996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.7579574153808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.104309122976, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 87.6015421033873, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 95.2719376818785, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.9667967780337, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.2865502710777, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.411795540495, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.095607386384, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.43287162046555, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.3648675436875, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.6239730407584, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.99385227653471, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.8927598874828, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.0811179152148, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.580862556435, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.248456656428, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.9380012624795, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.6327217459872, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.46234187449156, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.1791476596151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.5161350207056, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.8863966909251, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 52.9374501019981 and h = 1.17407554701198, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 6.11077892256472, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2517152759238, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.368303944182, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.4112001800556, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.569061353229, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.72256475777394, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.475209059258, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.0493140706213, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.1376044690418, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.3656181183361, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.2515335071934, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.5138484850808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.1802167761424, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.0023419292765, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.9991261368875, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 64.3443173344643, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.9848028942909, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.0835907053859, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.6389432697808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.3280111797809, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.6318020534789, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.7705976607382, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 99.7691418968029, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 74.1747665583183, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.1777025645808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.9086012913442, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.4754613628364, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.3772223771619, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.9647371450428, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.835920741544, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.1508953983257, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.1037655611294, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 69.5805154071996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.3741820066247, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.28303141567649, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.4412995790936, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.3462700377521, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.9461577406633, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.3732985442094, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.6693298178064, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.1172616239177, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.8305976234815, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.1988042448913, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.4868622267302, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.8600502513559, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.6021438377254, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.0681608953921, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.8137320646887, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.7603193810471, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 89.5694467258963, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.0532974114186, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.1277329161351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.5136557368385, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.9172407578641, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 64.6945118030873, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.1523476798287, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.0450219874204, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.3857703863042, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 94.3050819357257, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 89.3706362129805, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.40627947606351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.3674061184962, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.360061226098, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.8547642834417, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.01100829770425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.5310654789023, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.3225215194047, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.6176316344943, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.7784927059975, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 93.6003980114623, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 94.6768454355004, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.7216876142759, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 99.6240961093866, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.3273213433129, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.7422316468526, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.221627925643, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.5475070246314, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.0864455885425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 49.487954774631, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.6625429196519, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 98.4303019846983, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.680956953351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.04590830677232, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.0402359833262, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.9395779865399, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.6417439308922, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.81632464510996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.7886313345848, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.50634058571057, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 90.9096591223897, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.0784913503898, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.64274758146, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.21066711456019, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.2044748339836, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.0970736069137, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.23559755463625, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.0787292923067, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.1282724739998, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.3262748001242, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.6227472989353, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.3759943001103, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.0091515611387, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.2264553137444, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.712471030985, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.3604080124202, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.50346212985982, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 93.2780405255738, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.5213255754977, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 25.5904947089997, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.2196634943473, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 6.44113429611443, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.0792637929944, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.93388401830516, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.2017794699673, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.9940149996078, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 69.8307716597703, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.9698207461326, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.9283991246759, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.9471454262584, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.8213730569395, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.0515937123947, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.46060783292395, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.5094144732467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.9495650329615, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.6657803303399, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 95.1260779949243, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.1047555104581, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.03377426744174, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 54.9134276666277, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 66.9006536293866, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.1880106560474, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.2962862533495, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 89.5778337762614, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.8634885522234, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.8499602542289, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.6837283643442, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.43523329278173, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.06453596682315, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.9690724934105, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 97.5829976116938, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.4344160955397, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 69.0178076150439, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.2714194980821, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.5622253769764, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.1036098847387, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 67.2868175932508, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.7615605329769, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.655119926783, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 72.6081940441528 and h = 2.51804857211596, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 33.4335405701604, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 82.8309560044178, unable to satisfy inequality constraints.
#  33%|███▎      | 1/3 [00:16<00:33, 16.52s/it]
# [cvHandleFailure, Error: -15] At t = 26.3229370852117, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.4342933041742, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.90087014875431, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.4244695402073, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.40791878495697, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.2733681822422, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.7215674633112, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.6134116071323, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.2480857785391, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.6255126246953, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.5516071828269, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.1034170350988, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.3111591899086, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.3950533097156, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.5225540808911, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.306225634986, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.6528651580504, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.9529008899856, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 91.7323293673105, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.29702664652327, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.8957116772474, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 87.3253204704225, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.4904824257238, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.3389618919631, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.2446983981516, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.7816363576247, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.6974650054719, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.1033116802709, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.4124388449708, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.7112610687942, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.6090834745435, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.187346812583, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.0474750887998, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.3826112350264, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.92500228370332, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 42.3821306053308 and h = 1.94138851859573, the corrector convergence test failed repeatedly or with |h| = hmin.
#  67%|██████▋   | 2/3 [00:29<00:14, 14.33s/it]
# [cvHandleFailure, Error: -15] At t = 2.48938939429686, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.59247428919928, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.51384021372524, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.01638980661617, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.4949617695832, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.4324225567533, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 58.8544903205007 and h = 1.61621733465218, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 16.9016537981321, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6734554864897, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.20057958345694, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.74789647958031, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.1137170638163, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.49267226144164, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 80.2071992337385, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.0542972862309, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.7514522373815, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 4.80683212852471 and h = 0.754378083965351, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 56.2522538229646, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 68.0778561844313, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.8085191184444, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.98451591394937, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.7644225420321, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.4934297544225, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.6622904235455, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.8864361173712, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.9099680161966, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.60565961291804, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.50380048617331, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 45.2402682202284 and h = 0.986914903422445, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 6.31574602908125, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.897543128995, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.0586515577598, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 70.2822875412031 and h = 0.554827975812616, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 94.1794008455538, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.8459790608689, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.14989528658869, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.00668911999496, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.7148590261228, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.7561454581336, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.3366657298439, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.8370343765828, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.0737689187419, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.8565140099914, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.0380389218224, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 5.47398749422649 and h = 1.44397083932285, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 4.13100918067779, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.2296361746504, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.23585995040023, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.70608740507151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.7001584576235, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.47961009956152, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.5104811573542, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.7162457782072, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.940826678248, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.2483433718099, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.1657169354438, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.9367542518368, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 15.719720965887 and h = 1.09528021715786, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 16.111311467237, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.0210040901721, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.38873088955543, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 91.268343607335 and h = 4.07400666043627, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 5.25241417132142, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.627849723544, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.7894636039002, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.2719017008807, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 41.9935947790426, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.4953185544415, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.9250859762201, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 63.7549000861065, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 87.2876597256351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.8344899195208, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.5249144052907, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.17657674869163, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.1959889557134, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 78.2470886710113, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.0198293070222, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 4.64843574749931 and h = 0.151380167613012, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 34.1421732817581, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.1415562751427, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.38646119824413, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.1188159816765, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 70.8728505951825 and h = 1.37709523876499, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 51.6456146881404, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.4444651119606, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.7402990333892, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.6300690273914, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 12.0409399195452 and h = 0.761937622416326, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 78.9976462613438, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.3166379510004, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 6.2750501356142 and h = 65.0612761252704, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 2.81624615608418, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.83136682294426, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.2069154258883, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.8749799782559, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.2270935533532, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.8228667423251, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.4048036519079, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.8726735708703, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.5309076407653, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.0112598008807, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.7218222483796, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.2017417439787, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.2925399329187, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.9961401399516, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.2567833571638, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.3364932570514, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 78.8962886722814, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.2694224579073, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.7790846409449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.7054391012176, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.02158080512403, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.6212413500044, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.6892442831284, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.6428476821669, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.5697397028708, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.4198891641532, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.3785119404627, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 69.1323307545797, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 82.8304436571893, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.7225397370637, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.4469459352571, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 18.6166262674039 and h = 0.428145754275165, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 96.148235664841, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 15.4997351061083 and h = 0.181239814790456, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 31.3261141993163, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.9176913875698, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.8454148830886, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.6009707467094, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.55241543158, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 97.2155799730173, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.6114061565392, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 87.3001259527925, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 80.94957707563 and h = 2.0270377371343, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 22.8299907180107, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.913485504211, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.49953062312021, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.3131822355523, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 45.816156148017, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 4.10336726366557, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.81212691785349, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.3031302328507, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.4795335185216, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.3418579436891, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.5184388070068, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.1064641261131, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.5695371077887, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.0975284129348, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.7721956531968, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.93475297520613, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.9731003039903, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 91.8427286833682, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.30157096103154, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.6678938099522, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.0336843662546, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 65.2276466648686, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.0418589717425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 68.4498926864761, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.8952621754018, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.09355490437529, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 93.6648825124147, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.343780730992, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 91.7102241752944, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.5740844359015, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 68.2668971269095, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.8324459535636, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.0522019868075, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.0215852619656, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.5521608867381, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.5277300100467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.5623211573244, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.0644776603993, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 95.2035200329173 and h = 1.09442842660984, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 48.3240043350899, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.2103401152229, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.6900718630998, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.05932868838452, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.2668415774826, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.5885442619514, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.6721736591751, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.5002446637469, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.77631342384489, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.7860298635254, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.8563991018817, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.8488111852878, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.4896944117052, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.38276811210857, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.82671925882745, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.7727238259528, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.3282524062934, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.5251116356785, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.6895035836515, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.8842417717529, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.7468606681615, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.5484446843032, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.1882200306735, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.334259028062, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.59858565115182, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.3548711018181, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.8126415274253, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.9195767844245, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 84.8880193922332, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 26.3458786235412, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 80.8047532977303, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 94.8037918397425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.1296838584703, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.6815342228334, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.5622369137155, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.0590035543172, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.99738994526979, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.0989226322227, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.965904938613, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.0100826804667, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 63.9476421385329, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 53.1564226294869, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.8147642693524, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.0296294752305, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 80.5302999230639, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.7177142135032, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.4979902436259, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 51.4167960097959, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.0919488170994, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.4163728656613, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6229893817346, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.3337398206445, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.1509756697002, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.1504719911408, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.3765558633542, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 97.4884511038747, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.8352720432469, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.1921009361372, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.0847130341753, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.5027685528963, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.3689747985864, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.17039998800135, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.956042282203, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.95530099668562, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.8314298213074, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.73597325794043, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.6461942808144, unable to satisfy inequality constraints.
#
#
# ...
#
#
# [cvHandleFailure, Error: -15] At t = 76.3587646873463, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.1817959384292, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 9.51746702780542, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -4] At t = 2.98236946256837 and h = 0.432868196254564, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 61.5265414668452, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.8234958080936, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.134482876318, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.26175234350118, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.6612147597846, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.1823077214218, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 68.5208073778099, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.7586739625115, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.3900487833307, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.00323137919603, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.9484327868225, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 90.7641349428535, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 88.874314195618, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 24.1313952856766, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.5590635414832, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.3413253831942, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.1097031358729, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.7145938774704, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.0785516746824, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.3468485873953, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.2944358134245, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.45455466828989, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.96613393435355, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.5646277054996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.93732354545303, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.704140420558, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.08261623850535, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.7579067089598, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.70525873656, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.71973435945058, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.5406761151138, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 26.3585849197347, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 92.4702708357281, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.7653494872654, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.4604875751362, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.2875065916509, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.86955869137864, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.5648485787243, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 70.4783076304469, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 69.5890683534121 and h = 0.523138426049607, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 75.5065990300313, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.3584180380761, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.1905477329244, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.2182091510128, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.3617682507177, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.0385288992811, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.4966377983353, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.20711602631, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 49.7978686807647, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.483363803575, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.35326221131166, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.9945272243865, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.9699218414808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.4818276569743, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.756593593353, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.4996661627514, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.2822457183351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.7642093863838, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.51106347677996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.31866186437881, unable to satisfy inequality constraints.
#
# [cvHandleFailure, Error: -15] At t = 19.4127371112402, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 4.52294280830511, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 45.6471607128173 and h = 84.5350386376208, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 27.2125142810668, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.5172076399119, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.6793730046898, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.7349891604639, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.6807883664664, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 97.6669954879694, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.07945417609838, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.6495976952786, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 83.1589009400705, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.24236938836122, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.2209688932935, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.4243209620523, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.70826491058446, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.2501654057515, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.3801540627234, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.6873384119364, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.7970222350537, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.885299058689, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.5898290132246, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.6754307104243, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.9296915949123, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.3922380677859, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.4906246837138, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.7982336208226, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 52.2921311467554 and h = 0.31016644965659, the corrector convergence test failed repeatedly or with |h| = hmin.
#
# [cvHandleFailure, Error: -15] At t = 62.7775240238409, unable to satisfy inequality constraints.
#
#
#
# [cvHandleFailure, Error: -15] At t = 29.117063417574, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.6305155481679, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.6366523329694, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.4773621974284, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.4069412799446, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 41.5757359773431, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.2041756265646, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 74.401627539357, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.7653891379087, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.163877045393, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.2158387055485, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.9064631789578, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.1972328183347, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.8141039452645, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.7194236341463, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.97493562667531, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 41.781823343441, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.1174039199516, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.4026620738567, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.6307452468081, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.6680673425342, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.37233473209612, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.42667010393, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 93.9796955718368, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.1503729891084, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.8315048305359, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.93990132601759, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.17103028326394, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.405774827334, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.6583739508328, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.9384549288887, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.76953413002587, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.672699513846, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 15.3924830776828 and h = 0.819367197952327, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 11.091536573896, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.25558085031702, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.7603921942646, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.1360414157084, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.7304241279761, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.35492245387991, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.59496432034268, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 74.8384922962545, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 97.5493676109489 and h = 0.653959422029871, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 43.1737863722576, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.8814523817208, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.2561371187944, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 80.1336197451507, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.4081135493029, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 97.6062995647062, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 96.6837785943555 and h = 1.11530405980182, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 13.7634715744969, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.3823352850599, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 26.5438673824156 and h = 2.40955451254425, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 35.4681741404351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.1323122021121, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.300167683728, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.1898001410688, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 51.4899371056823, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.106974522238, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.9255560061761, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.2619089240065, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 42.9267248695928 and h = 0.510502867317342, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 87.0485862627177, unable to satisfy inequality constraints.
# 100%|██████████| 3/3 [00:41<00:00, 13.93s/it]

# %%
# Plot the results
for  j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
    n_plot = 100
    ax = None
    for i in range(n_plot):
        x0_list = ic.get_ic(sorted_crns_rewards[i][0])
        time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
        fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
        model_name = os.path.basename(input_paths[j]).replace('.pth','')
        ax[0].set_title(f'Top IOCRNs from model {model_name} - Setpoint tracking responses')
        # print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
        # print(sorted_crns_rewards[i][0])

# %%
if save_flag:
    for j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
        load_filename = os.path.basename(input_paths[j]).replace('.pth','')
        output_path = os.path.join(target_directory, 'models', 'generated_' + load_filename + '.pth')
        print('Saving generated CRNs to file:','generated_' + output_path + '.pth')
        sorted_crns = [crn for crn, _ in sorted_crns_rewards]
        torch.save(sorted_crns, output_path)
# Out:
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/models/generated_2026-01-14 10:55:31.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/models/generated_2026-01-14 16:39:34.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns_final/models/generated_2026-01-02 08:55:10.pth.pth
