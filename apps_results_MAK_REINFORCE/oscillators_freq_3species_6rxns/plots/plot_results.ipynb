# %%
# Set up the file path, import packages, and define device
# Set up the file path
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)

# Specify the target directory
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/'

# Import general packages
import torch
import numpy as np
from itertools import product, combinations_with_replacement
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.utils.ic import IC

# Import Reward packages
from RL4CRN.rewards.deterministic import oscillation_error

# Import Visualization packages
from RL4CRN.utils.visualizations import plot_reactant_product_heatmap, plot_reactant_product_scatter, topology_graph
from RL4CRN.utils.visualizations import visualize_crn_diversity

# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
N_CPUs = os.cpu_count() if os.cpu_count() is not None else 1
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Using device: cuda
# Number of CPUs available: 128

# %%
# Flag to save generated figures
save_figures_flag = True

# Flag to resimulate the IOCRN dynamics of the halls of fame
resimulate_flag = True

# Flag to load generated IOCRNs from trained models
generated_flag = True

# Flag for filtering out repeated IOCRN topologies
filter_flag = True
num_reactions_template = 4

# Parallel simulation flag
parallel_flag = True

# Set number of inputs and species labels
p = 1                                                       # Number of inputs
species_labels = ['X_1', 'X_2', 'X_3']                      # Species labels
mak_order = 2                                               # Maximum order of the mass-action reactions

# Time horizon for the simulation
t_plot_max = 100.0                                          # Maximum time for plotting the dynamics
t_f = 500.0                                                 # Final time for the simulation
N_t = 10000                                                 # Number of time steps in the simulation
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
periods = [10, 15, 20]
u_list = [np.array([1/p]) for p in periods]

# Construct the frequency list
f_list = u_list

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01, 0.01, 0.01]])

# Weight on the damping metric and initial time for peak detection
w = [0/10, 6/10, 1/10, 3/10]                              # [mean, frequency, damping, periodicity index]
t0 = 20.

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list, x0_list, time_horizon, f_list=f_list, mean_list=None, w=w, t0=t0, LARGE_NUMBER=1e4)                                              

# Define path for the directories: hall of fame and models
base_path_hof = os.path.abspath(os.path.join(target_directory, 'hof'))
base_path_models = os.path.abspath(os.path.join(target_directory, 'models'))
print(f"Current working directory: {os.getcwd()}")
print(f"Base path for halls of fame: {base_path_hof}")
print(f"Base path for models: {base_path_models}")
# Out:
# Current working directory: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/plots
# Base path for halls of fame: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/hof
# Base path for models: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/models

# %%
# Collect IOCRNs from halls of fame and those generated by trained models
# Get list of hall of fame files
hof_files = [f for f in os.listdir(base_path_hof) if f.startswith('hall_of_fame_') and f.endswith('.pth')]
print(f"Found {len(hof_files)} hall of fame files:")
for file in hof_files:
    print(f"- {file}")
print("-" * 40)

# Get list of generated files
generated_files = [f for f in os.listdir(base_path_models) if f.startswith('generated') and f.endswith('.pth')]
print(f"Found {len(generated_files)} generated files:")
for file in generated_files:
    print(f"- {file}")
print("-" * 40)

# Load the list of IOCRNs from each hall of fame file
hof_data = {}
for file in hof_files:
    file_path = os.path.join(base_path_hof, file)
    hof_data[file] = torch.load(file_path, weights_only=False)
    print(f"Loaded {file} with {len(hof_data[file])} entries.")

# Collect all IOCRNs from the halls of fame into a single list
hof_iocrns = []
for file, iocrn_list in hof_data.items():
    hof_iocrns.extend(iocrn_list)
print("-" * 40)
print(f"Total IOCRNs collected from all halls of fame: {len(hof_iocrns)}")
print("-" * 40)

if generated_flag:
    # Load the list of generated IOCRNs
    generated_data = {}
    for file in generated_files:
        file_path = os.path.join(base_path_models, file)
        generated_data[file] = torch.load(file_path, weights_only=False)
        print(f"Loaded {file} with {len(generated_data[file])} entries.")

    # Collect all IOCRNs from the generated files into a single list
    generated_iocrns = []
    for file, iocrn_list in generated_data.items():
        generated_iocrns.extend(iocrn_list)
    print("-" * 40)
    print(f"IOCRNs collected from all generated files: {len(generated_iocrns)}")

# Collect all IOCRNs into a single list
all_iocrns = hof_iocrns.copy()
if generated_flag:
    all_iocrns.extend(generated_iocrns)
print("-" * 40)
print(f"Total IOCRNs: {len(all_iocrns)}")
# Out:
# Found 3 hall of fame files:
# - hall_of_fame_2026-01-14 16:39:34.pth
# - hall_of_fame_2026-01-02 08:55:10.pth
# - hall_of_fame_2026-01-14 10:55:31.pth
# ----------------------------------------
# Found 3 generated files:
# - generated_2026-01-14 16:39:34.pth
# - generated_2026-01-14 10:55:31.pth
# - generated_2026-01-02 08:55:10.pth
# ----------------------------------------
# Loaded hall_of_fame_2026-01-14 16:39:34.pth with 30 entries.
# Loaded hall_of_fame_2026-01-02 08:55:10.pth with 30 entries.
# Loaded hall_of_fame_2026-01-14 10:55:31.pth with 30 entries.
# ----------------------------------------
# Total IOCRNs collected from all halls of fame: 90
# ----------------------------------------
# Loaded generated_2026-01-14 16:39:34.pth with 1280 entries.
# Loaded generated_2026-01-14 10:55:31.pth with 1280 entries.
# Loaded generated_2026-01-02 08:55:10.pth with 1280 entries.
# ----------------------------------------
# IOCRNs collected from all generated files: 3840
# ----------------------------------------
# Total IOCRNs: 3930

# %%
# Resimulate the dynamics of each IOCRN if the flag is set
if resimulate_flag:
    print("Resimulating IOCRN dynamics...")

    # Reset all IOCRNs
    for iocrn in all_iocrns:
        iocrn.reset()
        iocrn.atol = 1e-9
        iocrn.rtol = 1e-9

    # Simulate each IOCRN
    if parallel_flag:
        results = Parallel(n_jobs=N_CPUs)(delayed(compute_reward)(iocrn) for iocrn in all_iocrns) 
    else:
        results = []
        for iocrn in all_iocrns:
            results.append(compute_reward(iocrn))

    # Unzip the results
    rewards_list, last_task_info_list = zip(*results)
    rewards_list = list(rewards_list)
    last_task_info_list = list(last_task_info_list)

    # Update the last task info in each IOCRN since running in parallel does not modify the IOCRNs themselves
    for i, iocrn in enumerate(all_iocrns):
        iocrn.last_task_info = last_task_info_list[i]
# Out:
# Resimulating IOCRN dynamics...
#
# [cvHandleFailure, Error: -15] At t = 8.91033583656702, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.6838493936884, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.36299621910738, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.5194281174208, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 216.090528245778, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 334.821929091014, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.0151891510466, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.8271527641602, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 110.792609823245, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.8090634334211, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.5168686112222, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 43.1769495222158, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.5987501838015, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.6434886966099, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 105.914905263843, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.96662334950177, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 254.1590403673, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 116.943735154434, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 191.59653208051, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.32859775006227, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 100.939952443177, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.5312706867924, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 140.963683030647, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.54478612214906, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 238.067926107507, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 169.758661660333, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.0038491072908, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 306.046383199008, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.939134254592, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.2806091287757, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 90.1052866029996, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.58718126063555, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 116.384560600971, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.64462086733338, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 117.883373390696, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 146.175154820649, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 308.694670473049, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 121.905959118063, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 65.749803659553, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.8933336981711, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 211.070862520995, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 238.038440239987, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 373.961738093833, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 67.677153658099, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.18151327182226, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.17301776245736, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.1361923385066, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 188.590824221849, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.8373142781744, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.9543558476297, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.49838005156187, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 144.698623736096, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 89.6828613023643, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.195732306219, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 115.384824324169, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.91186788942709, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 118.376396557874, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 100.810916479581, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.2823325486624, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 140.369473955808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.565793202789, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 127.316305418675, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 491.232879060189, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.3302471992362, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 253.807158717808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 228.459141728521, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 142.215911197294, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 182.044761430331, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.530647310548, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 255.812741521503, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 105.613677739682, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 190.088080244752, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 82.9962284638256, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 425.72969322799, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 56.1924585951523, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 8.630608921866, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 321.152430689059, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 132.370738642603, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.6625097838449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 81.6251435530862, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.5616401693474, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.9361707979111, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.8033037894525, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.8303316691024, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.4729053385415, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.07099469282663, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.0015978047615, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.0146522607332, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 168.747565082013, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.42862174805082, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 63.6338019286735, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 319.366034139494, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 129.232364471766, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.4197429547074, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 35.0289367554073, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 129.981810184594, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.3242363487509, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.6846118833519, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.87038090170283, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 65.1291946107528, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.6067611525245, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 229.702584684498 and h = 3.06392138811268, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 4.83468007694543, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.4664069752858, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.90381092425528, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.706635847348, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.662083158229, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.258033000792, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.21610896892249, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.84935407927826, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.02541300308045, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.70747467759291, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.7216672100836, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 95.6578902792123, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.7044110451832, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.2486501415197, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.4049951022843, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.49855594002594, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.20657625829334, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.8260074002173, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 3.79986008716878 and h = 1.98826859517877, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 4.46923979594381, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.2942378655436, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.8935777352311, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.74705062362866, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 121.997701394051, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 202.905563543032, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.4238883548514, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.4356013269877, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.69463693477279, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 192.767696794444, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.0666926698369, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.81410472812998, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 62.218690749351, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 466.752912802237, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 232.308895520871, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.0075450672985, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 288.763432306608, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 120.938208424873, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 279.55662937172, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.9952007937626, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.7554312265175, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.4413421082335, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 141.507037850893, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.42773838078062, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 111.506539837403, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.78271062984775, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.19708314707237, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.413734613744, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 2.07177676452618, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 124.993115988117, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 457.566293326374, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.5169755676112, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 135.61270123896, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 169.892653342282, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 199.021378514703, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.3639731043006, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 7.82927679742052, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 7.17885299108119, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 104.076609183242, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.10502201788019, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.8119234685511, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 366.280672275256, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.4306270932612, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 9.2605682991735, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 449.92385256838, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.0156550045323, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.3319284167008, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.78966537612058, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 260.820303782867, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.2102558071197, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.7204560388159, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 491.679608306275, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 114.928746608292, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 262.399409578111, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 127.466116795406, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 181.889346175878, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 336.335494724465, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 268.152244781191, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 202.584640418319, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 140.497815160826, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.853885535547, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.61615906724062, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 378.391788185021, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.6454792001414, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.0770331608576, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.74610825922445, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.3263815790522, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 74.0622092079497, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.23035161405883, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 3.87399575725571, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 3.65459564641203, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.60552103752552, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.3923127632937, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 74.2669007614875, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.0837141130808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 76.51013878831, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.21906483749792, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.6275678950596, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.03586516306, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 6.5742036724593, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 54.8237963888949, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 6.23812683533852, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 214.392974398798, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.30946467990974, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.36575696790027, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.3345838028053, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 7.77878550294092, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 51.9184202004815, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.87070007862605, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 120.04499914732, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 221.178765491845, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.90118749569248, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.3574995279285, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.2039644088792, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.9855184273203, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.2722255361287, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.1879662885933, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.57891267215141, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.4589146088941, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 355.702651827181, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.2149323405688, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.8666718391155, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.07119770505206, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.7868654897085, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 33.0692530484911, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 98.3484626048197, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 67.8197299623471, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 15.2615757460842, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 4.71673593281457, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.7215484755467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.93369358829908, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 161.112866715903, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.7867045755843, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 63.8984869931455, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 137.059488054998, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 56.3825354210466, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.725297321289, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.6108030429129, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 138.986879488458, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 64.5521896509772, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.70138751329789, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.7910640105232, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.7643793776355, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.1839138319649, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 127.008647163405, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.5470154819737, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 243.73178945626, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.8379919299605, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 346.438002200277, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.9928418223976, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 489.184713278202, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 239.273137739325, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.44043707007964, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.13025189823627, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.4132434142497, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.6218436316012, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 357.562043876807, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 305.077963044942, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.7266925839941, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.0746679388438, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 94.5766991429758, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.52237922589108, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 15.5621564066793, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 20.6354500084114, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 255.660690374511 and h = 1.58665577487457, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -4] At t = 79.2263708203577 and h = 1.3687695853959, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 5.77432670309609, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 113.366165709777, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.59522395989546, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.6090221018954, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 165.09176036034, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.497549572327, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.8247268632798, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 236.784812975913, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 135.799937953196, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 238.487780164941, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.01563638696286, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.51524217483835, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.9426360410073, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 360.981737229838, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.9983749849689, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 60.4264058249477, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.0776831802629, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.5751853316177, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 15.1474326126787, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 86.5183973921632, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 310.253544999705, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 333.720693072745, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 141.475722829444, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 94.8333849461211, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.961233522735, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 3.34039685755287, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 3.36807347094072, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.8468266136311, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.6061090141743, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 3.29823655233123, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 46.2782525854869, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 385.849958208333, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 151.285642346114, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.3945156375588, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.3214879926275, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.74208394057488, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 4.05876991526849, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -4] At t = 4.42348365574128 and h = 1.22906329699066, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 2.93773511467378, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 2.68744722226629, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 4.4503955582769, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 95.1808665697577, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 2.03049777477622, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 54.4113750130173, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.05389144747685, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.9638913459822, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 3.26210074409971, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 2.29170088357595, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 4.94643914173248, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.5493489458796, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 104.539360564872, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.425992092664, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 178.001712828065, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.28999622329605, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.0429311585937, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.5818026192494, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 80.4525419117784, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 169.383987337865, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.0236303343523, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.1172398108038, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.8078099209746, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 61.5388573149339, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.68968719752703, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.0350051380406, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 173.487404492297, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.0147814435917, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.2221222621791, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.0427316027436, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 272.741225773038, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 224.693832524883, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 127.259711069263, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.3478528248422, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.9059808173866, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 52.597755761512, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.9730761524362, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.5147639401437, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.6609069052083, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 210.765930708604, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 182.480990252736, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.5878223364691, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.3431807442781, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 110.426491419151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.3024451227534, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 318.747062101984, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 217.537885561042, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 196.416074528766, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.2089638774306, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 75.4533025255989, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 106.623670826013, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.41334030890336, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 59.2338993658631, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 3.82092307247118 and h = 0.445379460902503, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 24.3587766281465, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 105.741222823694, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 262.680576779287, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 266.12864859121, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 145.621152939845, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 310.206474230063, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 213.845433573426, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 29.5891903689553, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 56.055794286986, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.8497041154493, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 308.980749078623, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.562679531809, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.3424293852684, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.9185979096567, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 134.802842413658, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.7637030601537, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.350855149532, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.2808859089425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.60251247208612, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.8965636237551, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 58.2155174435708, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.0088447755586, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.2304283495663, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 310.545475924967, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 323.046380793209, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.0668545219068, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 32.3937032876246, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 54.4504709495547, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 5.82956910175461, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 9.1804902774364, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 205.042815364055, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 144.583972100275, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.8685263052964, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 92.1761394004207, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.847302149201, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.5757888668292, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.6370635468112, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.5523078192405, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.24242223360592, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 93.7247671580393, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 84.4793827997486, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 64.6798368784212, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.6343471057017, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.68989110917556, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 103.236864410698, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.3417244572166, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.68570438574818, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 47.7466652875214, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.3012888254473, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.92402773185145, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 263.290156900061, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 414.657464397428, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 46.1793070587439, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 48.2508832248857, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.776393343244, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.16372802827111, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.30860095902937, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 499.790672626899, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.5281393738742, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 63.5337526462825, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 73.9729758107787, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.5584679239806, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.39014293213099, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 99.6045600150299, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 344.912874298014, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.1919904297387, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 222.31288100619, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 328.935102728151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.1391742801479, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 40.7922236590871, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2302750337448, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 332.886905503044, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 219.285259748035, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 185.469222733176, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 2.01823486852877, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 5.78311063851765, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 79.1168133241812, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 277.728485601836, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 175.348916816161, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 260.997771351864, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.676935277378, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.0373174897055, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 119.19861955984, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 462.513545303562, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 38.9168330780393, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 474.617587627167, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 353.517695767252, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.9058582479008, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.58836128511479, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.09731710948467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 362.995702656214, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 90.7089724580194, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 159.038182202138, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.6763602127516, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.634651305206, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 154.090910973715, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.6738740137873, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 105.411371474685, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.87330939510871, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 109.02582051637, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.6544719838778, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.1446894865225, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.3599627244852, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 400.770614040043, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 223.422557026233, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 292.500762725229, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.15148945374356, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.07014230551309, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 140.606528266224, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.2777760592846, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.8935690744449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 56.1004907952264, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 420.379237129742, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 389.948672686449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 101.805200745743, unable to satisfy inequality constraints.

# %%
def plot_unique_rewards(all_iocrns, filter_flag=True, top_percentile=100, figsize=(14, 6)):
    """
    Sorts IOCRNs by reward (loss), optionally filters for topological uniqueness, 
    and plots the reward distribution.

    Args:
        all_iocrns (list): List of IOCRN objects. Each must have .last_task_info['reward'] 
                           and .is_topologically_equal().
        filter_flag (bool): If True, removes topologically duplicate CRNs, keeping the 
                            best-performing version of each topology.
        top_percentile (float): If < 100, restricts the "Unique" plot to the top X% 
                                of topologies. (e.g., 10 = top 10%).
        figsize (tuple): Figure size for the plot.
    """
    
    # 1. Sort all IOCRNs by reward/loss.
    # User Request: "Plotting a loss" -> "Lower values on the left".
    # This implies Ascending Order (Smallest/Best -> Largest/Worst).
    all_iocrns_sorted = sorted(all_iocrns, key=lambda iocrn: iocrn.last_task_info['reward'], reverse=False)

    # 2. Filter topologically unique IOCRNs
    if filter_flag:
        print("Filtering topologically unique IOCRNs...")
        all_iocrns_sorted_filtered = []
        
        if all_iocrns_sorted:
            # The list is sorted [Best, ..., Worst].
            # To keep the BEST version of each topology, we iterate FORWARD.
            # The first time we see a topology, it is the best one (lowest index in sorted list).
            unique_indices = []
            seen_topologies = []
            
            for i in range(len(all_iocrns_sorted)):
                candidate = all_iocrns_sorted[i]
                is_new = True
                for seen in seen_topologies:
                    if candidate.is_topologically_equal(seen):
                        is_new = False
                        break
                
                if is_new:
                    seen_topologies.append(candidate)
                    unique_indices.append(i)
            
            all_iocrns_sorted_filtered = [all_iocrns_sorted[i] for i in unique_indices]
            
        print(f"Number of topologically unique IOCRNs: {len(all_iocrns_sorted_filtered)} out of {len(all_iocrns_sorted)} total IOCRNs.")

    else:
        all_iocrns_sorted_filtered = all_iocrns_sorted

    # 3. Apply Percentile Cutoff (to the Filtered list)
    if top_percentile < 100:
        n_total = len(all_iocrns_sorted_filtered)
        n_keep = max(1, int(n_total * (top_percentile / 100.0)))
        
        # Keep the FIRST n_keep items (Lowest Loss / Best Performance)
        all_iocrns_sorted_filtered = all_iocrns_sorted_filtered[:n_keep]
        title_suffix = f" (Top {top_percentile}%)"
    else:
        title_suffix = ""

    # 4. Extract Rewards
    rewards_sorted = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted]
    rewards_sorted_filtered = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted_filtered]

    # 5. Plotting
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)

    # Left Plot: All IOCRNs
    ax1.plot(rewards_sorted, marker='o', markersize=2, linestyle='-', linewidth=0.5, alpha=0.7)
    ax1.set_yscale('symlog') # symlog handles negative rewards better than log
    ax1.set_xlabel('IOCRN Index (Sorted by Loss Ascending)')
    ax1.set_ylabel('Loss (SymLog Scale)')
    ax1.set_title(f'Losses of All IOCRNs (N={len(rewards_sorted)})')
    ax1.grid(True, which="both", ls="--", alpha=0.3)

    # Right Plot: Unique / Top Percentile
    ax2.plot(rewards_sorted_filtered, marker='o', color='orange', markersize=2, linestyle='-', linewidth=0.8)
    ax2.set_yscale('symlog') # Kept as symlog
    ax2.set_xlabel('IOCRN Index (Sorted & Filtered)')
    ax2.set_ylabel('Loss (SymLog Scale)')
    ax2.set_title(f'Losses of Unique IOCRNs{title_suffix} (N={len(rewards_sorted_filtered)})')
    ax2.grid(True, which="both", ls="--", alpha=0.3)
    
    # Ensure tick labels are visible on Y axis
    ax2.yaxis.set_minor_formatter(plt.ScalarFormatter())

    plt.tight_layout()
    plt.show()

    return all_iocrns_sorted, all_iocrns_sorted_filtered

# Plot the rewards with filtering and top percentile options
all_iocrns_sorted, all_iocrns_sorted_filtered = plot_unique_rewards(all_iocrns, filter_flag=filter_flag, top_percentile=10, figsize=(14, 6))
# Out:
# Filtering topologically unique IOCRNs...
# Number of topologically unique IOCRNs: 768 out of 3930 total IOCRNs.

# %%
from scipy.signal import find_peaks
# Index of IOCRN
i = 20

# Extract the simulation info
info = all_iocrns_sorted_filtered[i].last_task_info
t = info["time_horizon"]
outs = info["outputs"]
reward = info["reward"]
print(f"Reward for IOCRN index {i}: {reward}")

# Focus only on t >= t0
mask = t >= t0

# Get the sampling time and number of samples
dt = float(np.mean(np.diff(t[mask])))
N = int(mask.sum())
Npad = 8*N

# Construct the frequency axis
freqs = np.fft.rfftfreq(Npad, d=dt)

ylim = [2, 3.5, 5]
fig, axes = plt.subplots(nrows=len(f_list), ncols=2, figsize=(6, 2*len(f_list)), sharex='col')
for j in range(len(f_list)):

    # Mask out the signal
    y = outs[j][0, mask]

    # Remove the mean
    y_mean = np.mean(y)
    y = y - y_mean

    # Compute the FFT and its magnitude
    Y = np.fft.rfft(y, n=Npad)
    mag = np.abs(Y)

    # Compute peaks in time domain
    dyn = float(np.max(y) - np.min(y)) 
    prom = max(0.01, 0.05 * dyn)
    peaks_idx = find_peaks(y, prominence=prom)[0]
    peaks_time = t[mask][peaks_idx]
    peaks = y[peaks_idx] + y_mean

    # Estimate Frequency from peaks
    periods = np.diff(peaks_time)
    avg_period = np.mean(periods)
    estimated_frequency = 1.0 / avg_period

    # Plot the frequency contents and time response
    axes[j, 0].plot(t, outs[j][0, :])
    axes[j, 0].plot(peaks_time, peaks, "x")
    axes[j, 0].axvline(x=t0, color="black", ls="--")
    axes[j, 0].set_ylim(0, ylim[j])
    axes[j, 0].set_xlabel('Time')
    axes[j, 1].plot(freqs, mag)
    axes[j, 1].axvline(x=estimated_frequency, color="red", ls="--")
    axes[j, 1].set_xlim(0, 0.5)
    axes[j, 1].set_title(f'Target Freq: {f_list[j][0]:.3f}, Freq: {estimated_frequency:.3f}', fontsize=8)
# Out:
# Reward for IOCRN index 20: 0.021940243116967066

# %%
# Select the top IOCRNs and top topologically unique IOCRNs to visualize
n_unfiltered = 100
n_filtered = 60

# %%
# Plot the responses of the top IOCRNs (topologically not unique)
ax = None
print("sorting...")
all_iocrns_sorted = sorted(all_iocrns, key=lambda iocrn: iocrn.last_task_info['reward'], reverse=False)
print("done ... ")
for i in range(n_unfiltered):
    x0_list = ic.get_ic(all_iocrns_sorted[i])
    fig, ax = all_iocrns_sorted[i].plot_transient_response(axes=ax, alpha=0.1)
ax[0].set_title(ax[0].get_title() + ' - Unfiltered')
print(f'Unfiltered: IOCRN # {0} has a reward of {all_iocrns_sorted[0].last_task_info["reward"]}')
print(f'Unfiltered: IOCRN # {n_unfiltered} has a reward of {all_iocrns_sorted[n_unfiltered-1].last_task_info["reward"]}')

# Plot the responses of the top topologically unique IOCRNs
ax = None
for i in range(n_filtered):
    x0_list = ic.get_ic(all_iocrns_sorted_filtered[i])
    fig, ax = all_iocrns_sorted_filtered[i].plot_transient_response(axes=ax)
ax[0].set_title(ax[0].get_title() + ' - Topologically Unique')
print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')
# Out:
# sorting...
# done ...
# Unfiltered: IOCRN # 0 has a reward of 0.01483259875882589
# Unfiltered: IOCRN # 100 has a reward of 0.05215095890366547
# Filtered: IOCRN # 0 has a reward of 0.01483259875882589
# Filtered: IOCRN # 60 has a reward of 0.04117443212258497

# %%
# Plot the reactant-product scatter for the top unfiltered IOCRNs
rewards_sorted = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted]
rewards_sorted_filtered = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted_filtered]

plot_reactant_product_scatter(
    all_iocrns_sorted_filtered[0:n_filtered],
    perf=rewards_sorted_filtered[0:n_filtered],
    species_labels=species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="viridis",
    max_ticks=30,
    figsize=(6, 5),
    jitter_scale=0.45,
    use_plotly=True  # ENABLE INTERACTIVE PLOTTING WITH PLOTLY
)

# Plot the reactant-product heatmap for the top filtered IOCRNs (topologically unique)
plot_reactant_product_heatmap(
    all_iocrns_sorted_filtered[0:n_filtered],
    species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="YlGnBu",
    max_ticks=30,
    figsize=(7, 6),
)

# %%
# Visualize the diversity of the top filtered IOCRNs (topologically unique)
visualize_crn_diversity(all_iocrns_sorted_filtered[:n_filtered], perf=rewards_sorted_filtered[:n_filtered], k=None, t=12, layout_method="mds", label_percentile=50, alpha=10.0, unique=True)  # <--- ENABLE REWARD-WEIGHTED TOPOLOGY WITH ALPHA=10.0
# Out:
# Applied reward weighting (alpha=10.0). Edges stretched by fitness gaps.
# Computing layout (mds)...
# Dual Coloring: Face=Loss (Greyscale), Edge=Cluster (Rainbow) with Black Separator

# %%
# Select three IOCRNs to highlight their responses
iocrn_indices_to_highlight = [0, 1, 50]

# Print the highlighted IOCRNs and their rewards
for idx in iocrn_indices_to_highlight:
    iocrn = all_iocrns_sorted_filtered[idx]
    reward = iocrn.last_task_info['reward']
    print(f'IOCRN {idx} (Loss: {reward}):')
    print(iocrn)
    print('-'*40)
# Out:
# IOCRN 0 (Loss: 0.01483259875882589):
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_3 ----> ∅;  [MAK(1.0)]
# X_3 ----> X_1 + X_3;  [MAK(2.568507432937622)]
# X_1 + X_1 ----> X_3 + X_3;  [MAK(3.148474931716919)]
# X_1 + X_2 ----> X_2;  [MAK(1.979343295097351)]
# X_2 + X_3 ----> X_2;  [MAK(2.6373043060302734)]
# X_2 + X_3 ----> X_2 + X_2;  [MAK(4.803155899047852)]
# X_3 + X_3 ----> X_1 + X_3;  [MAK(2.106203317642212)]
# ----------------------------------------
# IOCRN 1 (Loss: 0.01675984928190334):
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_2 ----> X_1;  [MAK(1.776307225227356)]
# X_3 ----> ∅;  [MAK(1.0)]
# X_3 ----> X_3 + X_3;  [MAK(1.7230067253112793)]
# X_1 + X_1 ----> X_2 + X_2;  [MAK(3.3261616230010986)]
# X_1 + X_2 ----> X_2 + X_2;  [MAK(7.203413963317871)]
# X_2 + X_3 ----> X_2;  [MAK(4.2009501457214355)]
# X_2 + X_3 ----> X_1 + X_2;  [MAK(2.1913084983825684)]
# ----------------------------------------
# IOCRN 50 (Loss: 0.03092348301187601):
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_3 ----> ∅;  [MAK(1.0)]
# X_3 ----> X_1 + X_1;  [MAK(1.3968629837036133)]
# X_3 ----> X_1 + X_3;  [MAK(2.7928595542907715)]
# X_1 + X_1 ----> X_3 + X_3;  [MAK(3.0582115650177)]
# X_1 + X_3 ----> X_1 + X_1;  [MAK(2.903942346572876)]
# X_2 + X_3 ----> X_2 + X_2;  [MAK(3.602842330932617)]
# X_3 + X_3 ----> X_1 + X_3;  [MAK(4.524388313293457)]
# ----------------------------------------

# %%
# Plot the responses (all species) of the following selected IOCRNs
fig, ax = plt.subplots(len(species_labels), len(iocrn_indices_to_highlight), figsize=(8, 2*len(species_labels)), sharex=True)

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    trajectories = info["trajectories"]
    ax[0, i].set_title(f'IOCRN #{iocrn_indices_to_highlight[i]} (Loss: {info["reward"]})', fontsize=6)
    for j in range(len(species_labels)):
        if i == 0:
            ax[j, i].set_ylabel(species_labels[j])
        for k in range(len(trajectories)):
            try:
                ax[j, i].plot(t, trajectories[k][j, :], alpha=0.7, linewidth=0.1)
            except Exception:
                continue

# %%
# Transient dynamics plot
Normalize = False
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
axins = inset_axes(
    ax,
    width="100%",   # can be percent or inches (e.g. 1.5)
    height="100%",
    bbox_to_anchor=(0.1, 0.65, 0.45, 0.28),
    bbox_transform=ax.transAxes,
    loc="lower left",
    borderpad=1
)

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces
time_shift = 0      # shift time 

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"] + time_shift
    outs = info["outputs"]
    mask = t >= t0

    for j in range(len(outs)):
        peak = np.max(outs[j][0, mask])
        if Normalize:
            outs[j][0, :] = outs[j][0, :] / peak
        ax.plot(t, outs[j][0, :],
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)
        # axins.plot(
        #     t, outs[j][0, :],
        #     color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"] + time_shift
    outs = info["outputs"]
    mask = t >= t0

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        peak = np.max(outs[j][0, mask])
        if Normalize:
            outs[j][0, :] = outs[j][0, :] / peak
        ax.plot(
            t, outs[j][0, :],
            color=color, linewidth=lw_hi,
            zorder=3,
            alpha=0.5 + 0.5*(j/len(outs)),
            label=label if j == 0 else None   # label once per i
        )
        axins.plot(
            t, outs[j][0, :],
            color=color, linewidth=lw_hi,
            zorder=3,
            alpha=0.5 + 0.5*(j/len(outs)),
            label=label if j == 0 else None   # label once per i
        )

# --------- Axes cosmetics ----------
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))
axins.xaxis.set_major_locator(MaxNLocator(nbins=4))
axins.yaxis.set_major_locator(MaxNLocator(nbins=4))

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
axins.grid(True, which="major", linewidth=0.6, alpha=0.25)
axins.spines["top"].set_visible(False)
axins.spines["right"].set_visible(False)

# --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
ax.set_xscale("linear")
if Normalize:
    ax.set_yscale("linear")
    ax.set_ylim(0, 1.1)
# ax.set_ylim(0, 5)
ax.set_xlim(time_shift, t_plot_max + time_shift)


# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
color_labels  = [f"I/O CRN {i+1}" for i in iocrn_indices_to_highlight]

# Dashed Line for Setpoint
setpoint_handle = Line2D([0], [0], color="0.2", lw=0.9, ls="--")
handles = color_handles #  + [setpoint_handle]
labels  = color_labels #+ ["Setpoint"]

# ax.set_xticks(np.array([0, 10, 100]) + time_shift)
# ax.set_xticklabels(ax.get_xticks() - time_shift, rotation=0)

ax.legend(handles=handles, labels=labels, frameon=True, loc="upper right", handlelength=2)
axins.set_ylim(0, 6)
axins.set_xlim(25, 55)
axins.set_xticklabels([])
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec="0.4", zorder=5, linestyle="--")
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_transient_dynamics.pdf"))
# Out:
# Filtered: IOCRN # 0 has a reward of 0.01483259875882589
# Filtered: IOCRN # 59 has a reward of 0.04117443212258497

# %%
# Frequency contents plot
Normalize = False
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]
    mask = t >= t0
    dt = float(np.mean(np.diff(t[mask])))
    N = int(mask.sum())
    Npad = 8*N
    freqs = np.fft.rfftfreq(Npad, d=dt)

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        ax.plot(freqs, mag, 
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        ax.plot(
            freqs, mag, 
            color=color, linewidth=lw_hi,
            zorder=3,
            label=label if j == 0 else None   # label once per i
        )

# --------- Axes cosmetics ----------
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
ax.set_xscale("linear")
# ax.set_ylim(0, 1.01)
ax.set_xlim(0, 0.5)
# ax.set_xlim(time_shift, t_f + time_shift)

# Desired frequencies
for desired_freq in f_list:
    ax.axvline(x=desired_freq, color="0.2", lw=lw_hi, ls="--", zorder=2)

# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
color_handles += [Line2D([0], [0], color="0.2", lw=lw_hi, ls="--")]
color_labels  = [f"I/O CRN {i}" for i in iocrn_indices_to_highlight]
color_labels += ["Target frequencies"]

ax.legend(handles=color_handles, labels=color_labels, frameon=True, loc="upper right", handlelength=2)
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_fourier.pdf"))
# Out:
# Filtered: IOCRN # 0 has a reward of 0.01483259875882589
# Filtered: IOCRN # 59 has a reward of 0.04117443212258497

# %%
# Frequency contents plots
Normalize = True
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, axes = plt.subplots(nrows=len(f_list), ncols=1, figsize=(2.5, 5), constrained_layout=True, sharex=True) 

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]
    mask = t >= t0
    dt = float(np.mean(np.diff(t[mask])))
    N = int(mask.sum())
    Npad = 8*N
    freqs = np.fft.rfftfreq(Npad, d=dt)

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        axes[j].plot(freqs, mag, 
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

f = np.zeros((len(iocrn_indices_to_highlight), len(f_list)))
for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        axes[j].plot(
            freqs, mag, 
            color=color, linewidth=lw_hi,
            zorder=3,
            label=label if j == 0 else None   # label once per i
        )

        # Compute peaks in time domain
        dyn = float(np.max(y) - np.min(y)) 
        prom = max(0.01, 0.05 * dyn)
        peaks_idx = find_peaks(y, prominence=prom)[0]
        peaks_time = t[mask][peaks_idx]
        peaks = y[peaks_idx] + y_mean

        # Estimate Frequency from peaks
        periods = np.diff(peaks_time)
        avg_period = np.mean(periods)
        estimated_frequency = 1.0 / avg_period
        f[i,j] = round(estimated_frequency, 3)
        
# --------- Axes cosmetics ----------
for ax in axes:
    ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
    ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

    ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    # --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
    ax.set_xscale("linear")
    # ax.set_yscale('log')
    # ax.set_ylim(0, 1.01)
    ax.set_xlim(0, 0.5)
    # ax.set_ylim(1e-1, 1e3)
    # ax.set_xlim(time_shift, t_f + time_shift)

# Desired frequencies
for j in range(len(f_list)):
    desired_freq = f_list[j]
    axes[j].axvline(x=desired_freq, color="0.2", lw=lw_hi, ls="--", zorder=3)

# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
    color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
    color_handles += [Line2D([0], [0], color="0.2", lw=lw_hi, ls="--")]
    color_labels  = [f"I/O CRN {i+1}, f = {f[k][j]:.3f}" for i, k in zip(iocrn_indices_to_highlight, range(len(iocrn_indices_to_highlight)))]
    color_labels += ["target frequency"]
    axes[j].legend(handles=color_handles, labels=color_labels, frameon=True, loc="upper right", handlelength=2)

for j in range(len(f_list)):
    axes[j].set_ylabel(f'normalized magnitude \n u = 1/{1/f_list[j][0]:.0f} = {f_list[j][0]:.3f}')

axes[-1].set_xlabel('frequency')
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_fourier_3inputs.pdf"))
# Out:
# Filtered: IOCRN # 0 has a reward of 0.01483259875882589
# Filtered: IOCRN # 59 has a reward of 0.04117443212258497

# %%
# Reactant-Product Scatter Plot
plot_dic = {
        "font.size": 6,
        "axes.labelsize": 6,
        "axes.titlesize": 6,
        "legend.fontsize": 6,
        "xtick.labelsize": 6,
        "ytick.labelsize": 6,
        "axes.linewidth": 0.2,
        "lines.linewidth": 1.2,
        "figure.dpi": 120,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
    }

fig = plot_reactant_product_scatter(
    all_iocrns_sorted_filtered[0:n_filtered],
    perf=rewards_sorted_filtered[0:n_filtered],
    species_labels=species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="viridis",
    max_ticks=30,
    figsize=(2, 1.55),
    jitter_scale=0.45,
    use_plotly=False,
    plot_dic=plot_dic,
    marker_size=4
)

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_reactant_product_scatter.pdf"))

# %%
# Topological diversity graph
plot_dic = {
        "font.size": 6,
        "axes.labelsize": 6,
        "axes.titlesize": 6,
        "legend.fontsize": 6,
        "xtick.labelsize": 6,
        "ytick.labelsize": 6,
        "axes.linewidth": 0.8,
        "lines.linewidth": 1.2,
        "figure.dpi": 120,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
    }

graph_dic = {
        "fontsize": 3,                  # font size for node labels 
        "edgewidth": 0.1,               # width of the edges in the graph
        "nodesize_multiplier":10,       # multiplier for node sizes
        "nodesize_offset": 0,           # offset for node sizes
        "show_colorbar": False,         # whether to show colorbar for node colors
        "innersize_ratio": 3,           # ratio for inner size of nodes
        "inner_node_linewidth": 0.1,    # width of the inner node borders 
        "outer_node_linewidth": 3.0,     # width of the outer node borders
        "print_labels": False            # whether to print labels on nodes
    }

fig = visualize_crn_diversity(
    all_iocrns_sorted_filtered[:n_filtered], 
    perf=rewards_sorted_filtered[:n_filtered], 
    k=None, 
    t=12, 
    layout_method="mds", 
    label_percentile=50, 
    alpha=10.0, 
    unique=True, 
    plot_dic=plot_dic,
    graph_dic=graph_dic,
    figsize=(2, 2)
)

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_topological_diversity.pdf"))
# Out:
# Applied reward weighting (alpha=10.0). Edges stretched by fitness gaps.
# Computing layout (mds)...
# Dual Coloring: Face=Loss (Greyscale), Edge=Cluster (Rainbow) with Black Separator

# %%
# Construct the new set of IOCRN inputs
periods_new = np.linspace(10, 20, num=100)
u_list_new = [np.array([1/p]) for p in periods_new]

# Construct the frequency list
f_list_new = u_list_new

# %%
# Resimulate the dynamics of the top filtered IOCRNs with the new inputs
parallel_flag = True

# Construct the compute reward routine with the new inputs and target frequencies
def compute_reward_new(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list_new, x0_list, time_horizon, f_list=f_list_new, mean_list=None, w=w, t0=t0, LARGE_NUMBER=1e4)  

iocrns_resimulated = []
iocrns_resimulated_old = [] # Old input frequencies
# Deepcopy and reset all IOCRNs
for iocrn in all_iocrns_sorted_filtered[0:n_filtered]:
    iocrn_copy = iocrn.clone()
    iocrn_copy.reset()
    iocrn_copy.atol = 1e-9
    iocrn_copy.rtol = 1e-9
    iocrns_resimulated.append(iocrn_copy)
# Simulate each IOCRN
if parallel_flag:
    results = Parallel(n_jobs=N_CPUs)(delayed(compute_reward_new)(iocrn) for iocrn in iocrns_resimulated)
else:
    results = []
    for iocrn in iocrns_resimulated:
        results.append(compute_reward_new(iocrn))

# Unzip the results
rewards_list_new, last_task_info_list_new = zip(*results)
rewards_list_new = list(rewards_list_new)
last_task_info_list_new = list(last_task_info_list_new)

# Update the last task info in each IOCRN since running in parallel does not modify the IOCRNs themselves
for i, iocrn in enumerate(iocrns_resimulated):
    iocrn.last_task_info = last_task_info_list_new[i]

# %%
# Plot the new rewards after resimulation with new inputs and for previous inputs
rewards_sorted_new = [iocrn.last_task_info['reward'] for iocrn in iocrns_resimulated]

plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5*0.8, 1.85*0.8), constrained_layout=True) 
ax.plot(range(1, n_filtered+1), rewards_sorted_new, marker='o', color='green', markersize=4, linestyle='-', linewidth=0.8, alpha=0.7, label='New ICs')
ax.plot(range(1, n_filtered+1), rewards_sorted_filtered[0:n_filtered], marker='o', color='orange', markersize=4, linestyle='--', linewidth=0.8, alpha=0.5, label='Original ICs')
ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xlim(1, n_filtered)
# ax.set_ylim(0, 0.09)
ax.set_xticks([1 if x == 0 else x for x in ax.get_xticks()])
ax.legend()

plt.show()

# %%
# Plot the input to frequency mapping
from RL4CRN.utils.utils import compute_frequency_damping

f_estimated_new = []
damping_estimated_new = []
for iocrn in iocrns_resimulated:
    f, d = compute_frequency_damping(iocrn.last_task_info["outputs"], iocrn.last_task_info["time_horizon"], t0=t0)
    f_estimated_new.append(f)
    damping_estimated_new.append(d)

f_estimated_highlighted = []
damping_estimated_highlighted = []
for i in iocrn_indices_to_highlight:
    iocrn = iocrns_resimulated[i]
    f, d = compute_frequency_damping(iocrn.last_task_info["outputs"], iocrn.last_task_info["time_horizon"], t0=t0)
    f_estimated_highlighted.append(f)
    damping_estimated_highlighted.append(d)

plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
for i in range(0, n_filtered):
    ax.plot(u_list_new, f_estimated_new[i], linestyle='-', color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)
ax.plot(u_list_new, u_list_new, linestyle='--', color='black', label='Ideal', zorder=3)
ax.scatter(u_list, f_list, color='black', marker='x', label='Target Frequencies', zorder=2)

for i in range(len(iocrn_indices_to_highlight)):
    ax.plot(u_list_new, f_estimated_highlighted[i], linestyle='-', color=f"C{i}", linewidth=lw_hi, label=f'I/O CRN {iocrn_indices_to_highlight[i]+1}', zorder=6)

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend()
plt.show()

# %%
# Plot the damping vs inputs
fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
for i in range(0, n_filtered):
    ax.plot(u_list_new, damping_estimated_new[i], linestyle='-', color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

for i in range(len(iocrn_indices_to_highlight)):
    ax.plot(u_list_new, damping_estimated_highlighted[i], linestyle='-', color=f"C{i}", linewidth=lw_hi, label=f'I/O CRN {iocrn_indices_to_highlight[i]+1}', zorder=6)

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend()
plt.show()
