# %%
# Set up the file path, import packages, and define device
# Set up the file path
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)

# Specify the target directory
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/'

# Import general packages
import torch
import numpy as np
from itertools import product, combinations_with_replacement
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.utils.ic import IC

# Import Reward packages
from RL4CRN.rewards.deterministic import oscillation_error

# Import Visualization packages
from RL4CRN.utils.visualizations import plot_reactant_product_heatmap, plot_reactant_product_scatter, topology_graph
from RL4CRN.utils.visualizations import visualize_crn_diversity

# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
N_CPUs = os.cpu_count() if os.cpu_count() is not None else 1
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Using device: cuda
# Number of CPUs available: 128

# %%
# Flag to save generated figures
save_figures_flag = True

# Flag to resimulate the IOCRN dynamics of the halls of fame
resimulate_flag = True

# Flag to load generated IOCRNs from trained models
generated_flag = True

# Flag for filtering out repeated IOCRN topologies
filter_flag = True
num_reactions_template = 4

# Parallel simulation flag
parallel_flag = True

# Set number of inputs and species labels
p = 1                                                       # Number of inputs
species_labels = ['X_1', 'X_2', 'X_3']                      # Species labels
mak_order = 2                                               # Maximum order of the mass-action reactions

# Time horizon for the simulation
t_plot_max = 100.0                                          # Maximum time for plotting the dynamics
t_f = 500.0                                                 # Final time for the simulation
N_t = 10000                                                 # Number of time steps in the simulation
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
periods = [10, 15, 20]
u_list = [np.array([1/p]) for p in periods]

# Construct the frequency list
f_list = u_list

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01, 0.01, 0.01]])

# Weight on the damping metric and initial time for peak detection
w = [0/10, 6/10, 1/10, 3/10]                              # [mean, frequency, damping, periodicity index]
t0 = 20.

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list, x0_list, time_horizon, f_list=f_list, mean_list=None, w=w, t0=t0, LARGE_NUMBER=1e4)                                              

# Define path for the directories: hall of fame and models
base_path_hof = os.path.abspath(os.path.join(target_directory, 'hof'))
base_path_models = os.path.abspath(os.path.join(target_directory, 'models'))
print(f"Current working directory: {os.getcwd()}")
print(f"Base path for halls of fame: {base_path_hof}")
print(f"Base path for models: {base_path_models}")
# Out:
# Current working directory: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/plots
# Base path for halls of fame: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/hof
# Base path for models: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_freq_3species_6rxns/models

# %%
# Collect IOCRNs from halls of fame and those generated by trained models
# Get list of hall of fame files
hof_files = [f for f in os.listdir(base_path_hof) if f.startswith('hall_of_fame_') and f.endswith('.pth')]
print(f"Found {len(hof_files)} hall of fame files:")
for file in hof_files:
    print(f"- {file}")
print("-" * 40)

# Get list of generated files
generated_files = [f for f in os.listdir(base_path_models) if f.startswith('generated') and f.endswith('.pth')]
print(f"Found {len(generated_files)} generated files:")
for file in generated_files:
    print(f"- {file}")
print("-" * 40)

# Load the list of IOCRNs from each hall of fame file
hof_data = {}
for file in hof_files:
    file_path = os.path.join(base_path_hof, file)
    hof_data[file] = torch.load(file_path, weights_only=False)
    print(f"Loaded {file} with {len(hof_data[file])} entries.")

# Collect all IOCRNs from the halls of fame into a single list
hof_iocrns = []
for file, iocrn_list in hof_data.items():
    hof_iocrns.extend(iocrn_list)
print("-" * 40)
print(f"Total IOCRNs collected from all halls of fame: {len(hof_iocrns)}")
print("-" * 40)

if generated_flag:
    # Load the list of generated IOCRNs
    generated_data = {}
    for file in generated_files:
        file_path = os.path.join(base_path_models, file)
        generated_data[file] = torch.load(file_path, weights_only=False)
        print(f"Loaded {file} with {len(generated_data[file])} entries.")

    # Collect all IOCRNs from the generated files into a single list
    generated_iocrns = []
    for file, iocrn_list in generated_data.items():
        generated_iocrns.extend(iocrn_list)
    print("-" * 40)
    print(f"IOCRNs collected from all generated files: {len(generated_iocrns)}")

# Collect all IOCRNs into a single list
all_iocrns = hof_iocrns.copy()
if generated_flag:
    all_iocrns.extend(generated_iocrns)
print("-" * 40)
print(f"Total IOCRNs: {len(all_iocrns)}")
# Out:
# Found 3 hall of fame files:
# - hall_of_fame_2026-01-14 16:39:34.pth
# - hall_of_fame_2026-01-02 08:55:10.pth
# - hall_of_fame_2026-01-14 10:55:31.pth
# ----------------------------------------
# Found 3 generated files:
# - generated_2026-01-14 16:39:34.pth
# - generated_2026-01-14 10:55:31.pth
# - generated_2026-01-02 08:55:10.pth
# ----------------------------------------
# Loaded hall_of_fame_2026-01-14 16:39:34.pth with 30 entries.
# Loaded hall_of_fame_2026-01-02 08:55:10.pth with 30 entries.
# Loaded hall_of_fame_2026-01-14 10:55:31.pth with 30 entries.
# ----------------------------------------
# Total IOCRNs collected from all halls of fame: 90
# ----------------------------------------
# Loaded generated_2026-01-14 16:39:34.pth with 1280 entries.
# Loaded generated_2026-01-14 10:55:31.pth with 1280 entries.
# Loaded generated_2026-01-02 08:55:10.pth with 1280 entries.
# ----------------------------------------
# IOCRNs collected from all generated files: 3840
# ----------------------------------------
# Total IOCRNs: 3930

# %%
# Resimulate the dynamics of each IOCRN if the flag is set
if resimulate_flag:
    print("Resimulating IOCRN dynamics...")

    # Reset all IOCRNs
    for iocrn in all_iocrns:
        iocrn.reset()

    # Simulate each IOCRN
    if parallel_flag:
        results = Parallel(n_jobs=N_CPUs)(delayed(compute_reward)(iocrn) for iocrn in all_iocrns) 
    else:
        results = []
        for iocrn in all_iocrns:
            results.append(compute_reward(iocrn))

    # Unzip the results
    rewards_list, last_task_info_list = zip(*results)
    rewards_list = list(rewards_list)
    last_task_info_list = list(last_task_info_list)

    # Update the last task info in each IOCRN since running in parallel does not modify the IOCRNs themselves
    for i, iocrn in enumerate(all_iocrns):
        iocrn.last_task_info = last_task_info_list[i]
# Out:
# Resimulating IOCRN dynamics...
#
# [cvHandleFailure, Error: -15] At t = 52.0509386012101, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 232.399713951058 and h = 2.14319629780027, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 77.0625953135329, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 362.942711825863, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 11.4610799663655 and h = 1.28309731313608, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 116.296442130609, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 491.70572640922, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 359.283105751151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 452.536646497712, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 169.096282831552, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 86.49749078049, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 496.637428830129 and h = 11.3799756281483, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 67.4974169080953, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 108.544808070803, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.9977863622951, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 182.902629568834, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 384.11487055809, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 436.114273012667, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 296.138495704278, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 294.92743902429, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 105.926933459399, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 323.975838022024, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 68.0573449944563, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 479.159219085221, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 77.7485952941528, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 479.523003292891, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.3670517868214, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 121.257081412341, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 268.341445626405, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 168.191393206449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 123.052185627266, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 304.628767250066, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 178.713534350722, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 63.7935948432259, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 65.0310970361626, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 286.53910014096, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 390.103355302091, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 454.297662452864, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.4816893428402, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 108.195410887153, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 167.340468727435, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 234.429875110509, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 373.088014724937, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 380.185461856337, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 90.7440087920644, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 386.229416490568, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t =
unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 216.244434628026 and h = 1.261675609345, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 69.4981474809686, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 67.1049998496263, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.62048974610548, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 261.581470217328, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.48889103972702, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 309.971004815048, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 157.344418665322, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.7972893902272, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 208.256209208054, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.17913555820232, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.9520380624359, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 91.4976632900431, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 12.1611031644875 and h = 1.35802311014466, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 4.95088900299654, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.2731072581656, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.0542399111813, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 99.3256580234525, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.28754088685037, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.2558802134442, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 88.7347395156646, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.720933504663, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 119.488940694195, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 50.6857574338106 and h = 0.668389142006848, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 128.53836222778, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 180.287126752146 and h = 0.66558967288273, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 107.763418566241, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 101.729738851803, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 36.7323198448085, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.595617179115, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 89.1066576754268, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 129.709177623032 and h = 0.617882688680917, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 13.6476566265964, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.55111354944697, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 326.758839235297, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.8130992133195, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.9128275237025, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 123.476191849868, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 64.696236671285 and h = 0.90442772878183, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 91.0162470988881, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.67987779016612, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 216.385551746342, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.31975078658071, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 306.868989654789 and h = 0.850562197758814, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 128.094344488085, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 103.721984781221, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.15735575449785, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 85.3939583770043, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 35.6250556095716 and h = 1.00978374788879, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 1.43049842292918, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 98.1135210842906, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 498.957880276826, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.4749235816327, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 424.366153189208 and h = 1.50923481405567, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 71.6092840456773, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 364.121165456735, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.29425697020616, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 388.216039091391, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 115.185936364125, unable to satisfy inequality constraints.

# %%
def plot_unique_rewards(all_iocrns, filter_flag=True, top_percentile=100, figsize=(14, 6)):
    """
    Sorts IOCRNs by reward (loss), optionally filters for topological uniqueness, 
    and plots the reward distribution.

    Args:
        all_iocrns (list): List of IOCRN objects. Each must have .last_task_info['reward'] 
                           and .is_topologically_equal().
        filter_flag (bool): If True, removes topologically duplicate CRNs, keeping the 
                            best-performing version of each topology.
        top_percentile (float): If < 100, restricts the "Unique" plot to the top X% 
                                of topologies. (e.g., 10 = top 10%).
        figsize (tuple): Figure size for the plot.
    """
    
    # 1. Sort all IOCRNs by reward/loss.
    # User Request: "Plotting a loss" -> "Lower values on the left".
    # This implies Ascending Order (Smallest/Best -> Largest/Worst).
    all_iocrns_sorted = sorted(all_iocrns, key=lambda iocrn: iocrn.last_task_info['reward'], reverse=False)

    # 2. Filter topologically unique IOCRNs
    if filter_flag:
        print("Filtering topologically unique IOCRNs...")
        all_iocrns_sorted_filtered = []
        
        if all_iocrns_sorted:
            # The list is sorted [Best, ..., Worst].
            # To keep the BEST version of each topology, we iterate FORWARD.
            # The first time we see a topology, it is the best one (lowest index in sorted list).
            unique_indices = []
            seen_topologies = []
            
            for i in range(len(all_iocrns_sorted)):
                candidate = all_iocrns_sorted[i]
                is_new = True
                for seen in seen_topologies:
                    if candidate.is_topologically_equal(seen):
                        is_new = False
                        break
                
                if is_new:
                    seen_topologies.append(candidate)
                    unique_indices.append(i)
            
            all_iocrns_sorted_filtered = [all_iocrns_sorted[i] for i in unique_indices]
            
        print(f"Number of topologically unique IOCRNs: {len(all_iocrns_sorted_filtered)} out of {len(all_iocrns_sorted)} total IOCRNs.")

    else:
        all_iocrns_sorted_filtered = all_iocrns_sorted

    # 3. Apply Percentile Cutoff (to the Filtered list)
    if top_percentile < 100:
        n_total = len(all_iocrns_sorted_filtered)
        n_keep = max(1, int(n_total * (top_percentile / 100.0)))
        
        # Keep the FIRST n_keep items (Lowest Loss / Best Performance)
        all_iocrns_sorted_filtered = all_iocrns_sorted_filtered[:n_keep]
        title_suffix = f" (Top {top_percentile}%)"
    else:
        title_suffix = ""

    # 4. Extract Rewards
    rewards_sorted = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted]
    rewards_sorted_filtered = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted_filtered]

    # 5. Plotting
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)

    # Left Plot: All IOCRNs
    ax1.plot(rewards_sorted, marker='o', markersize=2, linestyle='-', linewidth=0.5, alpha=0.7)
    ax1.set_yscale('symlog') # symlog handles negative rewards better than log
    ax1.set_xlabel('IOCRN Index (Sorted by Loss Ascending)')
    ax1.set_ylabel('Loss (SymLog Scale)')
    ax1.set_title(f'Losses of All IOCRNs (N={len(rewards_sorted)})')
    ax1.grid(True, which="both", ls="--", alpha=0.3)

    # Right Plot: Unique / Top Percentile
    ax2.plot(rewards_sorted_filtered, marker='o', color='orange', markersize=2, linestyle='-', linewidth=0.8)
    ax2.set_yscale('symlog') # Kept as symlog
    ax2.set_xlabel('IOCRN Index (Sorted & Filtered)')
    ax2.set_ylabel('Loss (SymLog Scale)')
    ax2.set_title(f'Losses of Unique IOCRNs{title_suffix} (N={len(rewards_sorted_filtered)})')
    ax2.grid(True, which="both", ls="--", alpha=0.3)
    
    # Ensure tick labels are visible on Y axis
    ax2.yaxis.set_minor_formatter(plt.ScalarFormatter())

    plt.tight_layout()
    plt.show()

    return all_iocrns_sorted, all_iocrns_sorted_filtered

# Plot the rewards with filtering and top percentile options
all_iocrns_sorted, all_iocrns_sorted_filtered = plot_unique_rewards(all_iocrns, filter_flag=filter_flag, top_percentile=10, figsize=(14, 6))

# %%
from scipy.signal import find_peaks
# Index of IOCRN
i = 20

# Extract the simulation info
info = all_iocrns_sorted_filtered[i].last_task_info
t = info["time_horizon"]
outs = info["outputs"]
reward = info["reward"]
print(f"Reward for IOCRN index {i}: {reward}")

# Focus only on t >= t0
mask = t >= t0

# Get the sampling time and number of samples
dt = float(np.mean(np.diff(t[mask])))
N = int(mask.sum())
Npad = 8*N

# Construct the frequency axis
freqs = np.fft.rfftfreq(Npad, d=dt)

ylim = [2, 3.5, 5]
fig, axes = plt.subplots(nrows=len(f_list), ncols=2, figsize=(6, 2*len(f_list)), sharex='col')
for j in range(len(f_list)):

    # Mask out the signal
    y = outs[j][0, mask]

    # Remove the mean
    y_mean = np.mean(y)
    y = y - y_mean

    # Compute the FFT and its magnitude
    Y = np.fft.rfft(y, n=Npad)
    mag = np.abs(Y)

    # Compute peaks in time domain
    dyn = float(np.max(y) - np.min(y)) 
    prom = max(0.01, 0.05 * dyn)
    peaks_idx = find_peaks(y, prominence=prom)[0]
    peaks_time = t[mask][peaks_idx]
    peaks = y[peaks_idx] + y_mean

    # Estimate Frequency from peaks
    periods = np.diff(peaks_time)
    avg_period = np.mean(periods)
    estimated_frequency = 1.0 / avg_period

    # Plot the frequency contents and time response
    axes[j, 0].plot(t, outs[j][0, :])
    axes[j, 0].plot(peaks_time, peaks, "x")
    axes[j, 0].axvline(x=t0, color="black", ls="--")
    axes[j, 0].set_ylim(0, ylim[j])
    axes[j, 0].set_xlabel('Time')
    axes[j, 1].plot(freqs, mag)
    axes[j, 1].axvline(x=estimated_frequency, color="red", ls="--")
    axes[j, 1].set_xlim(0, 0.5)
    axes[j, 1].set_title(f'Target Freq: {f_list[j][0]:.3f}, Freq: {estimated_frequency:.3f}', fontsize=8)

# %%
# Select the top IOCRNs and top topologically unique IOCRNs to visualize
n_unfiltered = 100
n_filtered = 60

# %%
# Plot the responses of the top IOCRNs (topologically not unique)
ax = None
print("sorting...")
all_iocrns_sorted = sorted(all_iocrns, key=lambda iocrn: iocrn.last_task_info['reward'], reverse=False)
print("done ... ")
for i in range(n_unfiltered):
    x0_list = ic.get_ic(all_iocrns_sorted[i])
    fig, ax = all_iocrns_sorted[i].plot_transient_response(axes=ax, alpha=0.1)
ax[0].set_title(ax[0].get_title() + ' - Unfiltered')
print(f'Unfiltered: IOCRN # {0} has a reward of {all_iocrns_sorted[0].last_task_info["reward"]}')
print(f'Unfiltered: IOCRN # {n_unfiltered} has a reward of {all_iocrns_sorted[n_unfiltered-1].last_task_info["reward"]}')

# Plot the responses of the top topologically unique IOCRNs
ax = None
for i in range(n_filtered):
    x0_list = ic.get_ic(all_iocrns_sorted_filtered[i])
    fig, ax = all_iocrns_sorted_filtered[i].plot_transient_response(axes=ax)
ax[0].set_title(ax[0].get_title() + ' - Topologically Unique')
print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# %%
# Plot the reactant-product scatter for the top unfiltered IOCRNs
rewards_sorted = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted]
rewards_sorted_filtered = [iocrn.last_task_info['reward'] for iocrn in all_iocrns_sorted_filtered]

plot_reactant_product_scatter(
    all_iocrns_sorted_filtered[0:n_filtered],
    perf=rewards_sorted_filtered[0:n_filtered],
    species_labels=species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="viridis",
    max_ticks=30,
    figsize=(6, 5),
    jitter_scale=0.45,
    use_plotly=True  # ENABLE INTERACTIVE PLOTTING WITH PLOTLY
)

# Plot the reactant-product heatmap for the top filtered IOCRNs (topologically unique)
plot_reactant_product_heatmap(
    all_iocrns_sorted_filtered[0:n_filtered],
    species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="YlGnBu",
    max_ticks=30,
    figsize=(7, 6),
)

# %%
# Visualize the diversity of the top filtered IOCRNs (topologically unique)
visualize_crn_diversity(all_iocrns_sorted_filtered[:n_filtered], perf=rewards_sorted_filtered[:n_filtered], k=None, t=12, layout_method="mds", label_percentile=50, alpha=10.0, unique=True)  # <--- ENABLE REWARD-WEIGHTED TOPOLOGY WITH ALPHA=10.0

# %%
# Select three IOCRNs to highlight their responses
iocrn_indices_to_highlight = [0, 1, 50]

# Print the highlighted IOCRNs and their rewards
for idx in iocrn_indices_to_highlight:
    iocrn = all_iocrns_sorted_filtered[idx]
    reward = iocrn.last_task_info['reward']
    print(f'IOCRN {idx} (Loss: {reward}):')
    print(iocrn)
    print('-'*40)

# %%
# Plot the responses (all species) of the following selected IOCRNs
fig, ax = plt.subplots(len(species_labels), len(iocrn_indices_to_highlight), figsize=(8, 2*len(species_labels)), sharex=True)

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    trajectories = info["trajectories"]
    ax[0, i].set_title(f'IOCRN #{iocrn_indices_to_highlight[i]} (Loss: {info["reward"]})', fontsize=6)
    for j in range(len(species_labels)):
        if i == 0:
            ax[j, i].set_ylabel(species_labels[j])
        for k in range(len(trajectories)):
            try:
                ax[j, i].plot(t, trajectories[k][j, :], alpha=0.7, linewidth=0.1)
            except Exception:
                continue

# %%
# Transient dynamics plot
Normalize = False
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
axins = inset_axes(
    ax,
    width="100%",   # can be percent or inches (e.g. 1.5)
    height="100%",
    bbox_to_anchor=(0.1, 0.65, 0.45, 0.28),
    bbox_transform=ax.transAxes,
    loc="lower left",
    borderpad=1
)

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces
time_shift = 0      # shift time 

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"] + time_shift
    outs = info["outputs"]
    mask = t >= t0

    for j in range(len(outs)):
        peak = np.max(outs[j][0, mask])
        if Normalize:
            outs[j][0, :] = outs[j][0, :] / peak
        ax.plot(t, outs[j][0, :],
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)
        # axins.plot(
        #     t, outs[j][0, :],
        #     color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"] + time_shift
    outs = info["outputs"]
    mask = t >= t0

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        peak = np.max(outs[j][0, mask])
        if Normalize:
            outs[j][0, :] = outs[j][0, :] / peak
        ax.plot(
            t, outs[j][0, :],
            color=color, linewidth=lw_hi,
            zorder=3,
            alpha=0.5 + 0.5*(j/len(outs)),
            label=label if j == 0 else None   # label once per i
        )
        axins.plot(
            t, outs[j][0, :],
            color=color, linewidth=lw_hi,
            zorder=3,
            alpha=0.5 + 0.5*(j/len(outs)),
            label=label if j == 0 else None   # label once per i
        )

# --------- Axes cosmetics ----------
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))
axins.xaxis.set_major_locator(MaxNLocator(nbins=4))
axins.yaxis.set_major_locator(MaxNLocator(nbins=4))

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
axins.grid(True, which="major", linewidth=0.6, alpha=0.25)
axins.spines["top"].set_visible(False)
axins.spines["right"].set_visible(False)

# --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
ax.set_xscale("linear")
if Normalize:
    ax.set_yscale("linear")
    ax.set_ylim(0, 1.1)
# ax.set_ylim(0, 5)
# ax.set_xlim(time_shift, 100 + time_shift)


# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
color_labels  = [f"I/O CRN {i+1}" for i in iocrn_indices_to_highlight]

# Dashed Line for Setpoint
setpoint_handle = Line2D([0], [0], color="0.2", lw=0.9, ls="--")
handles = color_handles #  + [setpoint_handle]
labels  = color_labels #+ ["Setpoint"]

# ax.set_xticks(np.array([0, 10, 100]) + time_shift)
# ax.set_xticklabels(ax.get_xticks() - time_shift, rotation=0)

ax.legend(handles=handles, labels=labels, frameon=True, loc="upper right", handlelength=2)
axins.set_ylim(0, 6)
axins.set_xlim(25, 55)
axins.set_xticklabels([])
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec="0.4", zorder=5, linestyle="--")
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_transient_dynamics.pdf"))

# %%
# Frequency contents plot
Normalize = False
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]
    mask = t >= t0
    dt = float(np.mean(np.diff(t[mask])))
    N = int(mask.sum())
    Npad = 8*N
    freqs = np.fft.rfftfreq(Npad, d=dt)

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        ax.plot(freqs, mag, 
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        ax.plot(
            freqs, mag, 
            color=color, linewidth=lw_hi,
            zorder=3,
            label=label if j == 0 else None   # label once per i
        )

# --------- Axes cosmetics ----------
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
ax.set_xscale("linear")
# ax.set_ylim(0, 1.01)
ax.set_xlim(0, 0.5)
# ax.set_xlim(time_shift, t_f + time_shift)

# Desired frequencies
for desired_freq in f_list:
    ax.axvline(x=desired_freq, color="0.2", lw=lw_hi, ls="--", zorder=2)

# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
color_handles += [Line2D([0], [0], color="0.2", lw=lw_hi, ls="--")]
color_labels  = [f"I/O CRN {i}" for i in iocrn_indices_to_highlight]
color_labels += ["Target frequencies"]

ax.legend(handles=color_handles, labels=color_labels, frameon=True, loc="upper right", handlelength=2)
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_fourier.pdf"))

# %%
# Frequency contents plots
Normalize = True
plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, axes = plt.subplots(nrows=len(f_list), ncols=1, figsize=(2.5, 5), constrained_layout=True, sharex=True) 

# --------- Plot all traces in light gray (topologically unique) ----------
alpha_bg = 0.3     # transparency for background traces
lw_bg = 0.8         # line width for background traces

for i in range(n_filtered):
    info = all_iocrns_sorted_filtered[i].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]
    mask = t >= t0
    dt = float(np.mean(np.diff(t[mask])))
    N = int(mask.sum())
    Npad = 8*N
    freqs = np.fft.rfftfreq(Npad, d=dt)

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        axes[j].plot(freqs, mag, 
                color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

print(f'Filtered: IOCRN # {0} has a reward of {all_iocrns_sorted_filtered[0].last_task_info["reward"]}')
print(f'Filtered: IOCRN # {n_filtered-1} has a reward of {all_iocrns_sorted_filtered[n_filtered-1].last_task_info["reward"]}')

# --------- Highlight the selected IOCRNs ----------
lw_hi = 1

f = np.zeros((len(iocrn_indices_to_highlight), len(f_list)))
for i in range(len(iocrn_indices_to_highlight)):
    info = all_iocrns_sorted_filtered[iocrn_indices_to_highlight[i]].last_task_info
    t = info["time_horizon"]
    outs = info["outputs"]

    color = f"C{i}"  # Matplotlib standard cycle
    label = f"I/O CRN {i+1}"

    for j in range(len(outs)):
        y = outs[j][0, mask]
        y = y - np.mean(y)
        Y = np.fft.rfft(y, n=Npad)
        mag = np.abs(Y)
        if Normalize:
            mag = mag / (np.max(mag) + 1e-12)
        axes[j].plot(
            freqs, mag, 
            color=color, linewidth=lw_hi,
            zorder=3,
            label=label if j == 0 else None   # label once per i
        )

        # Compute peaks in time domain
        dyn = float(np.max(y) - np.min(y)) 
        prom = max(0.01, 0.05 * dyn)
        peaks_idx = find_peaks(y, prominence=prom)[0]
        peaks_time = t[mask][peaks_idx]
        peaks = y[peaks_idx] + y_mean

        # Estimate Frequency from peaks
        periods = np.diff(peaks_time)
        avg_period = np.mean(periods)
        estimated_frequency = 1.0 / avg_period
        f[i,j] = round(estimated_frequency, 3)
        
# --------- Axes cosmetics ----------
for ax in axes:
    ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
    ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

    ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    # --------- Scales/limits (set before setpoint lines so we know xmin/xmax) ----------
    ax.set_xscale("linear")
    # ax.set_yscale('log')
    # ax.set_ylim(0, 1.01)
    ax.set_xlim(0, 0.5)
    # ax.set_ylim(1e-1, 1e3)
    # ax.set_xlim(time_shift, t_f + time_shift)

# Desired frequencies
for j in range(len(f_list)):
    desired_freq = f_list[j]
    axes[j].axvline(x=desired_freq, color="0.2", lw=lw_hi, ls="--", zorder=3)

# 2) Legend for colored lines should not have alpha:
#    use proxy artists with alpha=1 so legend is fully opaque.
    color_handles = [Line2D([0], [0], color=f"C{i}", lw=lw_hi, alpha=1.0) for i in range(len(iocrn_indices_to_highlight))]
    color_handles += [Line2D([0], [0], color="0.2", lw=lw_hi, ls="--")]
    color_labels  = [f"I/O CRN {i+1}, f = {f[k][j]:.3f}" for i, k in zip(iocrn_indices_to_highlight, range(len(iocrn_indices_to_highlight)))]
    color_labels += ["target frequency"]
    axes[j].legend(handles=color_handles, labels=color_labels, frameon=True, loc="upper right", handlelength=2)

for j in range(len(f_list)):
    axes[j].set_ylabel(f'normalized magnitude \n u = 1/{1/f_list[j][0]:.0f} = {f_list[j][0]:.3f}')

axes[-1].set_xlabel('frequency')
plt.show()

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_fourier_3inputs.pdf"))

# %%
# Reactant-Product Scatter Plot
plot_dic = {
        "font.size": 6,
        "axes.labelsize": 6,
        "axes.titlesize": 6,
        "legend.fontsize": 6,
        "xtick.labelsize": 6,
        "ytick.labelsize": 6,
        "axes.linewidth": 0.2,
        "lines.linewidth": 1.2,
        "figure.dpi": 120,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
    }

fig = plot_reactant_product_scatter(
    all_iocrns_sorted_filtered[0:n_filtered],
    perf=rewards_sorted_filtered[0:n_filtered],
    species_labels=species_labels,
    max_order= mak_order,
    num_reactions_template=num_reactions_template,
    title="",
    cmap_name="viridis",
    max_ticks=30,
    figsize=(2, 1.55),
    jitter_scale=0.45,
    use_plotly=False,
    plot_dic=plot_dic,
    marker_size=4
)

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_reactant_product_scatter.pdf"))

# %%
# Topological diversity graph
plot_dic = {
        "font.size": 6,
        "axes.labelsize": 6,
        "axes.titlesize": 6,
        "legend.fontsize": 6,
        "xtick.labelsize": 6,
        "ytick.labelsize": 6,
        "axes.linewidth": 0.8,
        "lines.linewidth": 1.2,
        "figure.dpi": 120,
        "savefig.dpi": 600,
        "savefig.bbox": "tight",
        "savefig.pad_inches": 0.02,
    }

graph_dic = {
        "fontsize": 3,                  # font size for node labels 
        "edgewidth": 0.1,               # width of the edges in the graph
        "nodesize_multiplier":10,       # multiplier for node sizes
        "nodesize_offset": 0,           # offset for node sizes
        "show_colorbar": False,         # whether to show colorbar for node colors
        "innersize_ratio": 3,           # ratio for inner size of nodes
        "inner_node_linewidth": 0.1,    # width of the inner node borders 
        "outer_node_linewidth": 3.0,     # width of the outer node borders
        "print_labels": False            # whether to print labels on nodes
    }

fig = visualize_crn_diversity(
    all_iocrns_sorted_filtered[:n_filtered], 
    perf=rewards_sorted_filtered[:n_filtered], 
    k=None, 
    t=12, 
    layout_method="mds", 
    label_percentile=50, 
    alpha=10.0, 
    unique=True, 
    plot_dic=plot_dic,
    graph_dic=graph_dic,
    figsize=(2, 2)
)

if save_figures_flag is True:
    fig.savefig(os.path.join(target_directory, 'plots', "oscillators_freq_3species_6rxns_topological_diversity.pdf"))

# %%
# Construct the new set of IOCRN inputs
# periods_new = np.linspace(8, 25, num=100)
periods_new = np.linspace(10, 20, num=100)
u_list_new = [np.array([1/p]) for p in periods_new]

# Construct the frequency list
f_list_new = u_list_new

# Setup the new simulation configurations
t_f = 500.0         
N_t = 10000
time_horizon = np.linspace(0, t_f, N_t)

# %%
# Resimulate the dynamics of the top filtered IOCRNs with the new inputs
parallel_flag = True

# Construct the compute reward routine with the new inputs and target frequencies
def compute_reward_new(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list_new, x0_list, time_horizon, f_list=f_list_new, mean_list=None, w=w, t0=t0, LARGE_NUMBER=1e4)  

iocrns_resimulated = []
iocrns_resimulated_old = [] # Old input frequencies
# Deepcopy and reset all IOCRNs
for iocrn in all_iocrns_sorted_filtered[0:n_filtered]:
    iocrn_copy1 = iocrn.clone()
    iocrn_copy1.reset()
    iocrn_copy1.atol = 1e-9
    iocrn_copy1.rtol = 1e-9
    iocrn_copy2 = iocrn.clone()
    iocrn_copy2.reset()
    iocrn_copy2.atol = 1e-9
    iocrn_copy2.rtol = 1e-9
    iocrns_resimulated.append(iocrn_copy1)
    iocrns_resimulated_old.append(iocrn_copy2)

# Simulate each IOCRN
if parallel_flag:
    results_new = Parallel(n_jobs=N_CPUs)(delayed(compute_reward_new)(iocrn) for iocrn in iocrns_resimulated)
    results_old = Parallel(n_jobs=N_CPUs)(delayed(compute_reward)(iocrn) for iocrn in iocrns_resimulated_old) 
else:
    results_new = []
    results_old = []
    for iocrn in iocrns_resimulated:
        results_new.append(compute_reward_new(iocrn))
    for iocrn in iocrns_resimulated_old:
        results_old.append(compute_reward(iocrn))

# Unzip the results
rewards_list_new, last_task_info_list_new = zip(*results_new)
rewards_list_new = list(rewards_list_new)
last_task_info_list_new = list(last_task_info_list_new)

rewards_list_old, last_task_info_list_old = zip(*results_old)
rewards_list_old = list(rewards_list_old)
last_task_info_list_old = list(last_task_info_list_old)

# Update the last task info in each IOCRN since running in parallel does not modify the IOCRNs themselves
for i, iocrn in enumerate(iocrns_resimulated):
    iocrn.last_task_info = last_task_info_list_new[i] 

for i, iocrn in enumerate(iocrns_resimulated_old):
    iocrn.last_task_info = last_task_info_list_old[i]

# %%
# Plot the new rewards after resimulation with new inputs and for previous inputs
rewards_sorted_new = [iocrn.last_task_info['reward'] for iocrn in iocrns_resimulated]
rewards_sorted_old = [iocrn.last_task_info['reward'] for iocrn in iocrns_resimulated_old]

plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5*0.8, 1.85*0.8), constrained_layout=True) 
ax.plot(range(1, n_filtered+1), rewards_sorted_new, marker='o', color='green', markersize=4, linestyle='-', linewidth=0.8, alpha=0.7, label='New ICs')
ax.plot(range(1, n_filtered+1), rewards_sorted_old, marker='o', color='blue', markersize=4, linestyle='-', linewidth=0.8, alpha=0.7, label='Old ICs')
ax.plot(range(1, n_filtered+1), rewards_sorted_filtered[0:n_filtered], marker='o', color='orange', markersize=4, linestyle='--', linewidth=0.8, alpha=0.5, label='Original ICs')
ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xlim(1, n_filtered)
# ax.set_ylim(0, 0.09)
ax.set_xticks([1 if x == 0 else x for x in ax.get_xticks()])
ax.legend()

plt.show()

# %%
# Plot the input to frequency mapping
from RL4CRN.utils.utils import compute_frequency_damping

f_estimated_new = []
damping_estimated_new = []
for iocrn in iocrns_resimulated:
    f, d = compute_frequency_damping(iocrn.last_task_info["outputs"], iocrn.last_task_info["time_horizon"], t0=t0)
    f_estimated_new.append(f)
    damping_estimated_new.append(d)

f_estimated_highlighted = []
damping_estimated_highlighted = []
for i in iocrn_indices_to_highlight:
    iocrn = iocrns_resimulated[i]
    f, d = compute_frequency_damping(iocrn.last_task_info["outputs"], iocrn.last_task_info["time_horizon"], t0=t0)
    f_estimated_highlighted.append(f)
    damping_estimated_highlighted.append(d)

plt.rcParams.update({
    "font.size": 6,
    "axes.labelsize": 6,
    "axes.titlesize": 6,
    "legend.fontsize": 6,
    "xtick.labelsize": 6,
    "ytick.labelsize": 6,
    "axes.linewidth": 0.8,
    "lines.linewidth": 1.2,
    "figure.dpi": 120,
    "savefig.dpi": 600,
    "savefig.bbox": "tight",
    "savefig.pad_inches": 0.02,
})

fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
for i in range(0, n_filtered):
    ax.plot(u_list_new, f_estimated_new[i], linestyle='-', color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)
ax.plot(u_list_new, u_list_new, linestyle='--', color='black', label='Ideal', zorder=3)
ax.scatter(u_list, f_list, color='black', marker='x', label='Target Frequencies', zorder=2)

for i in range(len(iocrn_indices_to_highlight)):
    ax.plot(u_list_new, f_estimated_highlighted[i], linestyle='-', color=f"C{i}", linewidth=lw_hi, label=f'I/O CRN {iocrn_indices_to_highlight[i]+1}', zorder=6)

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend()
plt.show()

# %%
# Plot the damping vs inputs
fig, ax = plt.subplots(figsize=(2.5, 1.85), constrained_layout=True) 
for i in range(0, n_filtered):
    ax.plot(u_list_new, damping_estimated_new[i], linestyle='-', color="0.6", alpha=alpha_bg, linewidth=lw_bg, zorder=1)

for i in range(len(iocrn_indices_to_highlight)):
    ax.plot(u_list_new, damping_estimated_highlighted[i], linestyle='-', color=f"C{i}", linewidth=lw_hi, label=f'I/O CRN {iocrn_indices_to_highlight[i]+1}', zorder=6)

ax.grid(True, which="major", linewidth=0.6, alpha=0.25)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.legend()
plt.show()
