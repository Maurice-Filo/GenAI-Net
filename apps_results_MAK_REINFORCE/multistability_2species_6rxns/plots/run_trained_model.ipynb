# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns'
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Working directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Target directory set to: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import dynamic_tracking_error

# %%
# Filename for loading the agent checkpoint
# get directory of this script (must work in a jupyter notebook as well)
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns/models

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=['X_1'], product_labels=[], input_channels=['u_1'], params=[1.0], params_controllability=[True])
r2 = MassAction(reactant_labels=['X_2'], product_labels=[], input_channels=[None], params=[1.0], params_controllability=[True])
crn_template = IOCRN([r1, r2], output_labels=['X_1', 'X_2'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X_1', 'X_2']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1']
# Species: ['X_1', 'X_2']
# Output Species: ['X_1', 'X_2']
# X_1 ----> ∅;  [MAK(1.0, u_1)]
# X_2 ----> ∅;  [MAK(1.0)]
# Library of possible reactions:
# Number of reactions: 31
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X_1;  [MAK(None)]
# R2: ∅ ----> X_2;  [MAK(None)]
# R3: ∅ ----> X_1 + X_1;  [MAK(None)]
# R4: ∅ ----> X_1 + X_2;  [MAK(None)]
# R5: ∅ ----> X_2 + X_2;  [MAK(None)]
# R6: X_1 ----> ∅;  [MAK(None)]
# R7: X_1 ----> X_2;  [MAK(None)]
# R8: X_1 ----> X_1 + X_1;  [MAK(None)]
# R9: X_1 ----> X_1 + X_2;  [MAK(None)]
# R10: X_1 ----> X_2 + X_2;  [MAK(None)]
# R11: X_2 ----> ∅;  [MAK(None)]
# R12: X_2 ----> X_1;  [MAK(None)]
# R13: X_2 ----> X_1 + X_1;  [MAK(None)]
# R14: X_2 ----> X_1 + X_2;  [MAK(None)]
# R15: X_2 ----> X_2 + X_2;  [MAK(None)]
# R16: X_1 + X_1 ----> ∅;  [MAK(None)]
# R17: X_1 + X_1 ----> X_1;  [MAK(None)]
# R18: X_1 + X_1 ----> X_2;  [MAK(None)]
# R19: X_1 + X_1 ----> X_1 + X_2;  [MAK(None)]
# R20: X_1 + X_1 ----> X_2 + X_2;  [MAK(None)]
# R21: X_1 + X_2 ----> ∅;  [MAK(None)]
# R22: X_1 + X_2 ----> X_1;  [MAK(None)]
# R23: X_1 + X_2 ----> X_2;  [MAK(None)]
# R24: X_1 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R25: X_1 + X_2 ----> X_2 + X_2;  [MAK(None)]
# R26: X_2 + X_2 ----> ∅;  [MAK(None)]
# R27: X_2 + X_2 ----> X_1;  [MAK(None)]
# R28: X_2 + X_2 ----> X_2;  [MAK(None)]
# R29: X_2 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R30: X_2 + X_2 ----> X_1 + X_2;  [MAK(None)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Using device: cuda
# Number of CPUs available: 128

# %%
# Hyperparameters
max_added_reactions = 6                                 # Maximum number of reactions
N_CPUs = os.cpu_count()                                 # Number of CPUs          
N = 10*N_CPUs                                           # Number of samples (batch size)    
width = 1024                                            # Width of the neural networks  
depth = 5                                               # Depth of the neural networks 
deep_layer_size = 1024*10                               # Size of the deep layer encoding the CRNs
allow_input_influence = False                           # Allow input influence in the policy
learning_rate = 1e-4                                    # Learning rate for the optimizer 
hall_of_fame_size = 10                                  # Size of the hall of fame  
entropy_scheduler = {                                   # Entropy scheduler parameters 
    'entropy_weight': 1e-3 ,                            # Global entropy weight
    'entropy_weight_structure_head': 10.0,              # Entropy weight for the structure head
    'entropy_weight_continuous_head': 0.1,              # Entropy weight for the continuous parameters head
    'topk_entropy_weight': 1.0,                         # Entropy weight for the top-k actions
    'remainder_entropy_weight': 1.0,                    # Entropy weight for the remainder actions
    'entropy_update_coefficient': 1,                    # Entropy update coefficient (multiplicative)
    'entropy_schedule': 1000,                           # Entropy schedule (in epochs) 
    'minimum_entropy_weight': 0.0                       # Minimum entropy weight
}
structure_head_temperature = {
    'target_entropy_ratio_to_max': np.log(5)/np.log(M), 
    'initial_temperature': 1.0, 
    'rate': 0.0, 
    'current_temperature': 1.0}
risk_scheduler = {                                      # Risk scheduler parameters
    'risk': 0.9,                                        # Percentage of worst samples to disregard when computing the reward
    'risk_update': 0.0,                                 # Risk update coefficient (additive)
    'max_risk': 1.0,                                    # Maximum risk
    'risk_schedule': 1000                               # Risk schedule (in epochs)
}
epoch_num = 800                                         # Number of epochs for training
render_schedule = 10                                    # Render every # of epochs
render_mode = {                                         # Mode of the experiment
    'style': 'logger',                                  
    'task': 'phase_plot', 
    'format': 'image',
    'topology': True,
    'bounds': [1.2, 1.2]
}
render_n_best = 10                                      # Number of best CRNs to plot responses for
render_disregard_percentage = risk_scheduler['risk']    # Percentage of worst CRNs to disregard in the responses plotting
sil_settings = {
    'sil_loss_weight': 1.0
}

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_1D'}        

# Time horizon for the simulation
t_f = 100                                               # Final time for the simulation
N_t = 1000                                              # Number of time steps in the simulation
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
u_list = [np.array([1.0])]

# Construct the IOCRN initial conditions
epsilon = 1e-3
ic_values_diagonal_1 = [[x/10, x/10 - 0.3] for x in range(3, 13)]
ic_values_diagonal_2 = [[x/10, x/10 + 0.3] for x in range(0, 10)]
ic_values_cluster_1 = [ [.9, epsilon], [1, epsilon], [1.1, epsilon], 
                        [.9, .1], [1, .1], [1.1, .1]]
ic_values_cluster_2 = [ [epsilon, .9], [epsilon, 1], [epsilon, 1.1], 
                        [.1, .9], [.1, 1], [.1, 1.1]]
ic_values = ic_values_diagonal_1 + ic_values_diagonal_2 + ic_values_cluster_1 + ic_values_cluster_2
ic = IC(names=species_labels, values=ic_values)

# Construct the desired fixed points
r_list = [np.array([1, 0])] * len(ic_values_diagonal_1) + \
         [np.array([0, 1])] * len(ic_values_diagonal_2) + \
         [np.array([1, 0])] * len(ic_values_cluster_1) + \
         [np.array([0, 1])] * len(ic_values_cluster_2)

# Construct the weights for the performance metric
w = np.ones(N_t)
w[(len(w)//5)*4:] = w[(len(w)//5)*4:]*2
w[:(len(w)//5)] = w[:(len(w)//5)]*0.25
w = w[np.newaxis, :]

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return dynamic_tracking_error(state, u_list, x0_list, time_horizon, r_list, w, norm=1, relative=False, LARGE_NUMBER=1e4)

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
entropy_weights_per_head = {'structure': entropy_scheduler['entropy_weight_structure_head'], 'continuous': entropy_scheduler['entropy_weight_continuous_head'], 'discrete': 0.0, 'input_influence': 0.0} 
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=allow_input_influence, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=allow_input_influence, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device, sil_settings=sil_settings)

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library, allow_input_observation=allow_input_influence)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Test the model
from tqdm import tqdm
sorted_crns_rewards_list = []
for p in tqdm(input_paths):
    agent.policy.load_state_dict(torch.load(p, map_location=device))

    agent.policy.eval()
    mult_env.reset()
    for j in range(max_added_reactions):
        observations = mult_env.observe(observer, tensorizer)
        actions, raw_actions = agent.act(observations, actuator)
        out = mult_env.step(actions, stepper, raw_actions=raw_actions)

    rewards = mult_env.get_reward(compute_reward)

    # Gather the CRNs from the environments
    crns = mult_env.gather()

    # Sort the CRNs by rewards
    sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])
    sorted_crns_rewards_list.append(sorted_crns_rewards)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [cvHandleFailure, Error: -15] At t = 1.50928108168052, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.7758221674365, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.95726393885991, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 4.4767823051208 and h = 2.71520677088002, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 19.3196030923402, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.3474046477429, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.86951471765554, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2778976318134, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.3587691895628, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.9853872993922, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 42.4078178339979, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.0677186932454, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.8462800074449, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.63750671570472, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.4807265709542, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.7976670171272, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.66829237113416, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.9537536607196, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.3387044930048, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.2205982081961, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.3820266826375, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.8438010129201, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.709136775804856, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 57.2354671196597, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.5134809269328, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.3497229512417, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.2093401642283, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.2277939948317, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 45.1693878684692, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.7226992547701, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.6365328803137, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.53605493035715, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.5399352293262, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.55084505651765, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.31065308360382, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.72913963561874, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.91015005099009, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.9064379791096, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 25.6281623089201, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.4289568104372, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 6.66575683585516 and h = 19.0313415086621, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 78.3955822165546, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.45735775019706, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.9183497470933, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.979757863221, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.7553893689189, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.1786815560543, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.9494795679141, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.4028185499553, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.86330715687961, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18
unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 39.3135893901728, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.45103052937612, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.04311027652944, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.15615460355206, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.01418075280418, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 0.243127588875058 and h = 0.210139201364962, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 2.09524875598015, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.90327518127851, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.5637011278505, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.75983731270344, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.559219068749659, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.35903242223262, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.72822484036198, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.89544165978881, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.6468423314946, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.4184308386011, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.50276620978413, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 21.6187563786053, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.15090267514743, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.10369753756169, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.28186307484193, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.708801675057331, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.98944267905551, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.51202870696949, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.1344423211102, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.893294662362995, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.83443024685983, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.53908684683335, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.573222024754, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 5.05725862370694 and h = 7.12694231743874, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 3.82852713471397, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.812982358741148, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.8760069191097, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.622593592628, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.993727565386143, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.23501241765835, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.38858854023582, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.98522668980296, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.751945141693175, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.71813649633496, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.9150611476596, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.77818577728879, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.83952677172104, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.21835371307679, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.1285314415174, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.07679211097799, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.97771523039377, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.5078144701626, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.02435800109852, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.1896912761838, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 30.7816394403226, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.467107414036725, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.443255663292322, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.510979720273677, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.9487110961739, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.55796641534997, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.50122019768302, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.907371756749461, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.741429407017802, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.00119935347013, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6266898429706, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.30190262708326, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.193124739783523, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.859160753157026, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.276438560896455, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.287707073277561, unable to satisfy inequality constraints.
# 100%|██████████| 3/3 [00:33<00:00, 11.31s/it]

# %%
# Plot the results
for  j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
    n_plot = 100
    ax = None
    for i in range(n_plot):
        x0_list = ic.get_ic(sorted_crns_rewards[i][0])
        time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
        fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
        model_name = os.path.basename(input_paths[j]).replace('.pth','')
        ax[0].set_title(f'Top IOCRNs from model {model_name} - Setpoint tracking responses')
        # print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
        # print(sorted_crns_rewards[i][0])

# %%
if save_flag:
    for j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
        load_filename = os.path.basename(input_paths[j]).replace('.pth','')
        output_path = os.path.join(target_directory, 'models', 'generated_' + load_filename + '.pth')
        print('Saving generated CRNs to file:','generated_' + output_path + '.pth')
        sorted_crns = [crn for crn, _ in sorted_crns_rewards]
        torch.save(sorted_crns, output_path)
# Out:
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns/models/generated_2025-12-23 20:46:46.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns/models/generated_2025-12-08 07:44:18.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/multistability_2species_6rxns/models/generated_2025-12-22 15:08:28.pth.pth
