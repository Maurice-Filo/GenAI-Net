# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/'
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Working directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Target directory set to: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import oscillation_error

# %%
# Filename for loading the agent checkpoint
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/models

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=[], product_labels=['X_1'], input_channels=['u_1'], params=[1.], params_controllability=[True])
r2 = MassAction(reactant_labels=['X_1'], product_labels=[], input_channels=[None], params=[1], params_controllability=[True])
r3 = MassAction(reactant_labels=['X_2'], product_labels=[], input_channels=[None], params=[1], params_controllability=[True])
r4 = MassAction(reactant_labels=['X_3'], product_labels=[], input_channels=[None], params=[1], params_controllability=[True])
crn_template = IOCRN([r1, r2, r3, r4], output_labels=['X_3'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X_1', 'X_2', 'X_3']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(1)]
# X_2 ----> ∅;  [MAK(1)]
# X_3 ----> ∅;  [MAK(1)]
# Library of possible reactions:
# Number of reactions: 91
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X_1;  [MAK(None)]
# R2: ∅ ----> X_2;  [MAK(None)]
# R3: ∅ ----> X_3;  [MAK(None)]
# R4: ∅ ----> X_1 + X_1;  [MAK(None)]
# R5: ∅ ----> X_1 + X_2;  [MAK(None)]
# R6: ∅ ----> X_1 + X_3;  [MAK(None)]
# R7: ∅ ----> X_2 + X_2;  [MAK(None)]
# R8: ∅ ----> X_2 + X_3;  [MAK(None)]
# R9: ∅ ----> X_3 + X_3;  [MAK(None)]
# R10: X_1 ----> ∅;  [MAK(None)]
# R11: X_1 ----> X_2;  [MAK(None)]
# R12: X_1 ----> X_3;  [MAK(None)]
# R13: X_1 ----> X_1 + X_1;  [MAK(None)]
# R14: X_1 ----> X_1 + X_2;  [MAK(None)]
# R15: X_1 ----> X_1 + X_3;  [MAK(None)]
# R16: X_1 ----> X_2 + X_2;  [MAK(None)]
# R17: X_1 ----> X_2 + X_3;  [MAK(None)]
# R18: X_1 ----> X_3 + X_3;  [MAK(None)]
# R19: X_2 ----> ∅;  [MAK(None)]
# R20: X_2 ----> X_1;  [MAK(None)]
# R21: X_2 ----> X_3;  [MAK(None)]
# R22: X_2 ----> X_1 + X_1;  [MAK(None)]
# R23: X_2 ----> X_1 + X_2;  [MAK(None)]
# R24: X_2 ----> X_1 + X_3;  [MAK(None)]
# R25: X_2 ----> X_2 + X_2;  [MAK(None)]
# R26: X_2 ----> X_2 + X_3;  [MAK(None)]
# R27: X_2 ----> X_3 + X_3;  [MAK(None)]
# R28: X_3 ----> ∅;  [MAK(None)]
# R29: X_3 ----> X_1;  [MAK(None)]
# R30: X_3 ----> X_2;  [MAK(None)]
# R31: X_3 ----> X_1 + X_1;  [MAK(None)]
# R32: X_3 ----> X_1 + X_2;  [MAK(None)]
# R33: X_3 ----> X_1 + X_3;  [MAK(None)]
# R34: X_3 ----> X_2 + X_2;  [MAK(None)]
# R35: X_3 ----> X_2 + X_3;  [MAK(None)]
# R36: X_3 ----> X_3 + X_3;  [MAK(None)]
# R37: X_1 + X_1 ----> ∅;  [MAK(None)]
# R38: X_1 + X_1 ----> X_1;  [MAK(None)]
# R39: X_1 + X_1 ----> X_2;  [MAK(None)]
# R40: X_1 + X_1 ----> X_3;  [MAK(None)]
# R41: X_1 + X_1 ----> X_1 + X_2;  [MAK(None)]
# R42: X_1 + X_1 ----> X_1 + X_3;  [MAK(None)]
# R43: X_1 + X_1 ----> X_2 + X_2;  [MAK(None)]
# R44: X_1 + X_1 ----> X_2 + X_3;  [MAK(None)]
# R45: X_1 + X_1 ----> X_3 + X_3;  [MAK(None)]
# R46: X_1 + X_2 ----> ∅;  [MAK(None)]
# R47: X_1 + X_2 ----> X_1;  [MAK(None)]
# R48: X_1 + X_2 ----> X_2;  [MAK(None)]
# R49: X_1 + X_2 ----> X_3;  [MAK(None)]
# R50: X_1 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R51: X_1 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R52: X_1 + X_2 ----> X_2 + X_2;  [MAK(None)]
# R53: X_1 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R54: X_1 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R55: X_1 + X_3 ----> ∅;  [MAK(None)]
# R56: X_1 + X_3 ----> X_1;  [MAK(None)]
# R57: X_1 + X_3 ----> X_2;  [MAK(None)]
# R58: X_1 + X_3 ----> X_3;  [MAK(None)]
# R59: X_1 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R60: X_1 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R61: X_1 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R62: X_1 + X_3 ----> X_2 + X_3;  [MAK(None)]
# R63: X_1 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R64: X_2 + X_2 ----> ∅;  [MAK(None)]
# R65: X_2 + X_2 ----> X_1;  [MAK(None)]
# R66: X_2 + X_2 ----> X_2;  [MAK(None)]
# R67: X_2 + X_2 ----> X_3;  [MAK(None)]
# R68: X_2 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R69: X_2 + X_2 ----> X_1 + X_2;  [MAK(None)]
# R70: X_2 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R71: X_2 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R72: X_2 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R73: X_2 + X_3 ----> ∅;  [MAK(None)]
# R74: X_2 + X_3 ----> X_1;  [MAK(None)]
# R75: X_2 + X_3 ----> X_2;  [MAK(None)]
# R76: X_2 + X_3 ----> X_3;  [MAK(None)]
# R77: X_2 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R78: X_2 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R79: X_2 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R80: X_2 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R81: X_2 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R82: X_3 + X_3 ----> ∅;  [MAK(None)]
# R83: X_3 + X_3 ----> X_1;  [MAK(None)]
# R84: X_3 + X_3 ----> X_2;  [MAK(None)]
# R85: X_3 + X_3 ----> X_3;  [MAK(None)]
# R86: X_3 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R87: X_3 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R88: X_3 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R89: X_3 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R90: X_3 + X_3 ----> X_2 + X_3;  [MAK(None)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Using device: cuda
# Number of CPUs available: 128

# %%
# Hyperparameters
max_added_reactions = 6                                 # Maximum number of reactions
N_CPUs = os.cpu_count()                                 # Number of CPUs          
N = 10*N_CPUs                                           # Number of samples (batch size)    
width = 1024                                            # Width of the neural networks  
depth = 5                                               # Depth of the neural networks 
deep_layer_size = 1024*10                               # Size of the deep layer encoding the CRNs
allow_input_influence = False                           # Allow input influence in the policy
learning_rate = 1e-4                                    # Learning rate for the optimizer 
hall_of_fame_size = 30                                  # Size of the hall of fame  
entropy_scheduler = {                                   # Entropy scheduler parameters 
    'entropy_weight': 1e-3 ,                            # Global entropy weight
    'entropy_weight_structure_head': 7.5,               # Entropy weight for the structure head
    'entropy_weight_continuous_head': 0.5,              # Entropy weight for the continuous parameters head
    'topk_entropy_weight': 1.0,                         # Entropy weight for the top-k actions
    'remainder_entropy_weight': 1.0,                    # Entropy weight for the remainder actions
    'entropy_update_coefficient': 1,                    # Entropy update coefficient (multiplicative)
    'entropy_schedule': 1000,                           # Entropy schedule (in epochs) 
    'minimum_entropy_weight': 0.0                       # Minimum entropy weight
}
structure_head_temperature = {
    'target_entropy_ratio_to_max': np.log(5)/np.log(M), 
    'initial_temperature': 1.0, 
    'rate': 0.0, 
    'current_temperature': 1.0}
risk_scheduler = {                                      # Risk scheduler parameters
    'risk': 0.95,                                        # Percentage of worst samples to disregard when computing the reward
    'risk_update': 0.0,                                 # Risk update coefficient (additive)
    'max_risk': 1.0,                                    # Maximum risk
    'risk_schedule': 1000                               # Risk schedule (in epochs)
}
epoch_num = 700                                         # Number of epochs for training
render_schedule = 10                                    # Render every # of epochs
render_mode = {                                         # Mode of the experiment
    'style': 'logger',                                  
    'task': 'transients', 
    'format': 'image',
    'topology': True,
    'bounds': [2.5]
}
render_n_best = 10                                      # Number of best CRNs to plot responses for
render_disregard_percentage = risk_scheduler['risk']    # Percentage of worst CRNs to disregard in the responses plotting

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_1D'}        

# Time horizon for the simulation
t_f = 100                                               # Final time for the simulation
N_t = 1000                                              # Number of time steps in the simulation
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
# u_list = [np.array([0.5]), np.array([1.0]), np.array([1.5])]
u_list = [np.array([1.0])]

# Construct the mean levels for the oscillations
mean_list = [np.array([u[0]]) for u in u_list]

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01, 0.01, 0.01]])

# Weight on the damping metric and initial time for peak detection
w = [4/10, 0/10, 2/10, 4/10]                              # [mean, frequency, damping, periodicity index]
t0 = 20.

# Rendering mode
mode = {                                           
    'style': 'logger', 
    'task': 'transients + frequency content', 
    'format': 'image',
    'bounds': [100.0], 
    'bounds_freq': [[1.5, 1]], 
    't0': t0, 
    'scale': 'linear'
}

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list, x0_list, time_horizon, f_list=None, mean_list=mean_list, w=w, t0=t0, LARGE_NUMBER=1e4)

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
entropy_weights_per_head = {'structure': entropy_scheduler['entropy_weight_structure_head'], 'continuous': entropy_scheduler['entropy_weight_continuous_head'], 'discrete': 0.0, 'input_influence': 0.0} 
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=allow_input_influence, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=allow_input_influence, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device)

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library, allow_input_observation=allow_input_influence)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Test the model
from tqdm import tqdm
sorted_crns_rewards_list = []
for p in tqdm(input_paths):
    agent.policy.load_state_dict(torch.load(p, map_location=device))

    agent.policy.eval()
    mult_env.reset()
    for j in range(max_added_reactions):
        observations = mult_env.observe(observer, tensorizer)
        actions, raw_actions = agent.act(observations, actuator)
        out = mult_env.step(actions, stepper, raw_actions=raw_actions)

    rewards = mult_env.get_reward(compute_reward)

    # Gather the CRNs from the environments
    crns = mult_env.gather()

    # Sort the CRNs by rewards
    sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])
    sorted_crns_rewards_list.append(sorted_crns_rewards)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [cvHandleFailure, Error: -15] At t = 39.5234856042929, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.18341220853828, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.3043395475783, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.08546149893669, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.833154602540875, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.6626376479012, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.77543684863829, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.9591550767989, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 34.5173742212679, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 8.72250613667009, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.36514616010967, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 1.29406365943957, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 20.88365746327, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.597186395943, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.8906630624544, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.49368162811987, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.9737531023324, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.46328315779014, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 72.6046761686346, unable to satisfy inequality constraints.
#  33%|███▎      | 1/3 [00:14<00:28, 14.16s/it]
# [cvHandleFailure, Error: -15] At t = 8.06804403319143, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.51568857433724, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.40738351354627, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 22.4776346570583, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.14071255219984, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.91894392782993, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.57465674957246, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.89932939348867, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.8121037115279, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.98252791888378, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.07876706280439, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.46712395174908, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.1689743631716, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 1.18684996478534 and h = 0.876328284252869, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 16.0553530837179, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.07737908635966, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.95079474264196, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.43728247799151, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.6723483055438, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 50.6167878517776, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.32128872291615, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.846088104167, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 4.15200255782877, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.9343949786443, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.50718191853761, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.77175278647123, unable to satisfy inequality constraints.
#  67%|██████▋   | 2/3 [00:24<00:11, 11.87s/it]
# [cvHandleFailure, Error: -15] At t = 0.367877918735061, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.377520881177505, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.620032688205874, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.333095496662694, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.528322836618632, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.664487615099887, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.98445456326815, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.925454954863001, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.617048798007181, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.06719452245209, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.832690343757686, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.350990226621224, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.541721164763751, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.590573283776892, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.492601932466201, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.527399701909816, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.371021760225364, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.793808232470064, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.53034607098203, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 2.46756552724482, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.493069637394559, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.04348911596454, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -4] At t = 2.42088019722876 and h = 0.117615555374517, the corrector convergence test failed repeatedly or with |h| = hmin.
#
#
# [cvHandleFailure, Error: -15] At t = 2.87915512311918, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.350355630523861, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.526701465836693, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.4754835504968, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.326161734233808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.577700260310406, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.365788901488454, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.20116710091409, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.517802916866541, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.855410501428803, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.653774102279844, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.8326904029908, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 0.745644346329983, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.15034307948167, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 1.07290496356869, unable to satisfy inequality constraints.
# 100%|██████████| 3/3 [00:34<00:00, 11.36s/it]

# %%
# Plot the results
for  j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
    n_plot = 100
    ax = None
    for i in range(n_plot):
        x0_list = ic.get_ic(sorted_crns_rewards[i][0])
        time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
        fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
        model_name = os.path.basename(input_paths[j]).replace('.pth','')
        ax[0].set_title(f'Top IOCRNs from model {model_name} - Setpoint tracking responses')
        # print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
        # print(sorted_crns_rewards[i][0])

# %%
if save_flag:
    for j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
        load_filename = os.path.basename(input_paths[j]).replace('.pth','')
        output_path = os.path.join(target_directory, 'models', 'generated_' + load_filename + '.pth')
        print('Saving generated CRNs to file:','generated_' + output_path + '.pth')
        sorted_crns = [crn for crn, _ in sorted_crns_rewards]
        torch.save(sorted_crns, output_path)
# Out:
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/models/generated_2025-12-02 17:51:08.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/models/generated_2025-12-03 07:10:34.pth.pth
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_MAK_REINFORCE/oscillators_lift_3species_6rxns/models/generated_2025-12-03 09:22:55.pth.pth
