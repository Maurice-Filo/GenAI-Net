# %% [markdown]
# # RL4CRN tutorial notebook: Logic Circuit Inference Task (CVODE)
#
# This notebook shows an end-to-end **RL4CRN** workflow:
#
# 1. **Import utilities** and choose a **configuration preset**
# 2. **Build a template IO-CRN** (species, input/output mapping, solver settings)
# 3. **Build a reaction library** (MAK library in this example)
# 4. **Define a task** (here: *Logic Circuit Inference* objective)
# 5. **Configure training**
# 6. **Create a session + trainer** and run training
# 7. **Inspect the best CRN** from the Hall of Fame
#
# > Tip: If you ever see shape-related errors (e.g., ragged arrays), print and validate
# > `template_crn.num_inputs` vs `len(u_list[0])` to ensure input dimension consistency.

# %%
import os, sys, numpy as np

print("Python:", sys.version.split()[0])
print("CWD:", os.getcwd())
# Out:
# Python: 3.10.12
# CWD: /local0/rossin/git/CRN-GenerativeAI/apps

# %% [markdown]
# ## 1) Import RL4CRN helpers
#
# We use the user-facing interface utilities from `RL4CRN.utils.input_interface`:
#
# - `Configurator`: provides presets and override helpers
# - `make_task`: builds a `TaskSpec` with reward function and input scenarios
# - `make_session_and_trainer`: wires up environments, interfaces, policy, and agent
# - `print_task_summary`: quick diagnostic summary for the created task

# %%
from RL4CRN.utils.input_interface import (
    Configurator,
    make_task,
    make_session_and_trainer,
    print_task_summary,
)

# %% [markdown]
# ## 2) Build a template IO/CRN
#
# A **template IO-CRN** defines:
# - the **species** in the model
# - how **inputs** enter the system (via `input_map`)
# - how **dilution** (if any) is applied
# - which species is treated as the **output**
# - the **ODE solver** and its tolerances
#
# Here we use the convenience builder `build_logic_IOCRN`, which provides an easy way to construct a CRN with digital inputs and a single output node.

# %%
from RL4CRN.utils.crn_builders import build_logic_IOCRN

# choose preset
cfg = Configurator.preset("paper")

# select simulator and set tolerances
cfg.solver.algorithm = "CVODE"
cfg.solver.rtol = 1e-10
cfg.solver.atol = 1e-10

# build template IO/CRN
n_inputs = 3
species_labels = ['X_1', 'X_2', 'X_3']
crn, species_labels = build_logic_IOCRN(
    n_inputs=n_inputs,
    include_dilution=False,
    solver = cfg.solver,
)

print("Template CRN built.")
print(" - num_inputs:", crn.num_inputs)
print(" - num_species:", len(species_labels))
print(" - species:", species_labels)
# Out:
# Template CRN built.
#  - num_inputs: 3
#  - num_species: 4
#  - species: ['X_1', 'X_2', 'X_3', 'OUT']

# %% [markdown]
# ## 3) Build the reaction library (MAK)
#
# RL4CRN typically proposes reactions from a **library**.
# This example uses a MAK library of given order (here `order=2`).
#
# The builder returns a tuple `(library, M, K, masks)` that the training pipeline needs.

# %%
from RL4CRN.utils.library_builders import build_MAK_library

# library components
library_components = build_MAK_library(crn, species_labels, order=2)

library, M, K, masks = library_components
print("Library built.")
print(" - M (num reactions in library):", M)
print(" - K (num parameters in library):", K)
# Out:
# Library built.
#  - M (num reactions in library): 211
#  - K (num parameters in library): 211

# %% [markdown]
# ## 4) Define the task: Logic Circuit Inference
#
# We define an **Logic Circuit Inference** task.
#
# - `kind="logic"` selects the reward function based on oscillation frequency
# - The system automatically generates the initial conditions to fully test the table of truth for the target logic function
# - `n_inputs` must match `template_crn.num_inputs`
# - `ic=("constant", 0.01)` sets initial concentrations
#
# We also choose the simulation window `t_f` and resolution `n_t`.
#
# We specify the target logic function (`logic_fn`) as
#
# $$f_{\text{LOGIC}}(\mathbf{X}) = X_1 \land X_2 \land X_3,$$
#
# in this example.

# %%
logic_fn = lambda x: all(x)  # AND logic (X_1 AND X_2 AND X_3)

task = make_task(
    template_crn=crn,
    library_components=library_components,
    kind="logic",
    logic_fn=logic_fn,
    species_labels=species_labels,   # passed again, as the crns are automatically compacted
    n_inputs=n_inputs,                     
    ic=("constant", 0.01),
    t_f=100, n_t=1000
)

print_task_summary(task)

# --- Optional safety checks (recommended) ---
print("Sanity checks:")
print(" - template num_inputs:", crn.num_inputs)
print(" - first u shape:", np.asarray(task.u_list[0]).shape)
print(" - first u length:", len(task.u_list[0]))
assert len(task.u_list[0]) == crn.num_inputs, "Input dimension mismatch: u has wrong length!"
# Out:
# Task: logic
# time_horizon: (1000,) [0..100.0]
# num scenarios: 8
# first 3 u: [array([0., 0., 0.], dtype=float32), array([0., 0., 1.], dtype=float32), array([0., 1., 0.], dtype=float32)]
#
# Sanity checks:
#  - template num_inputs: 3
#  - first u shape: (3,)
#  - first u length: 3

# %% [markdown]
# ## 5) Training configuration
#
# We tune:
# - `max_added_reactions`: episode length (how many reactions the agent can add)
# - `epochs`: training iterations
# - `render_every`: print progress cadence
# - `seed`: reproducibility

# %%
# ---- Train config ----
cfg.train.max_added_reactions = 5
cfg.train.epochs = 5
cfg.train.render_every = 5
cfg.train.seed = 0

# %% [markdown]
# ## 6) Inspect full configuration (optional)
#
# `cfg.describe()` prints a nested configuration dictionary.

# %%
cfg.describe()
# Out:
# {'task': None,
#  'solver': {'algorithm': 'CVODE', 'rtol': 1e-10, 'atol': 1e-10},
#  'train': {'epochs': 5,
#            'max_added_reactions': 5,
#            'render_every': 5,
#            'hall_of_fame_size': 50,
#            'batch_multiplier': 10,
#            'seed': 0,
#            'n_cpus': None,
#            'batch_size': None},
#  'policy': {'width': 1024,
#             'depth': 5,
#             'deep_layer_size': 10240,
#             'continuous_distribution': {'type': 'lognormal_1D'},
#             'entropy_weights_per_head': {'structure': 2.0, 'continuous': 1.0, 'discrete': 0.0, 'input_influence': 0.0},
#             'ordering_enabled': False,
#             'constraint_strength': inf},
#  'agent': {'learning_rate': 0.0001,
#            'entropy_scheduler': {'entropy_weight': 0.001,
#                                  'topk_entropy_weight': 1.0,
#                                  'remainder_entropy_weight': 1.0,
#                                  'entropy_update_coefficient': 1,
#                                  'entropy_schedule': 1000,
#                                  'minimum_entropy_weight': 0.0},
#            'risk_scheduler': {'risk': 0.95, 'risk_update': 0.0, 'max_risk': 1.0, 'risk_schedule': 1000},
#            'sil_settings': {'sil_loss_weight': 1.0}}}

# %% [markdown]
# ## 7) Create session + trainer
#
# This step wires together:
# - parallel environments
# - observer/tensorizer/actuator/stepper interfaces
# - policy + agent
# - the chosen task reward function
#
# The returned objects:
# - `session`: contains all built components
# - `trainer`: runs rollout → reward eval → policy update loops

# %%
trainer = make_session_and_trainer(cfg, task)

# %% [markdown]
# ## 8) Train and save checkpoints
#
# We run for `cfg.train.epochs` epochs and periodically save a checkpoint.

# %%
checkpoint_path = "logic_task_chkpt.pkl"
trainer.run(epochs=cfg.train.epochs, checkpoint_path=checkpoint_path)
# Out:
# [cvHandleFailure, Error: -15] At t = 12.4015418041778, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.210402607717, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.0707965204955, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 17.7373537714688, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.019529677421, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.6044797656618, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.27959634632382, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.9981032240773, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.1345221797166, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.7458424313108, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.8816068667803, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.1023671203776, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.8971321066625, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.5068416683623, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.33936393102997, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 66.8750555613068, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.95359888821257, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.43341622270039, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.95359896366212, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.0877250390534, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.2396646154841, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.80767145535964, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.0161803595259, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.1168925281328, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.0842997034286, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.0600763990377, unable to satisfy inequality constraints.
#
# [epoch 0] best loss=0.1147 | median loss=1.748
# Saved checkpoint: logic_task_chkpt.pkl
#
# [cvHandleFailure, Error: -15] At t = 41.8006213529757, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.0215010973392, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.4107495552583, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.76664591075183, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.5816231459374, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.3019501139213, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.8843220931663, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.39677550953829, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.6915993413888, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.6853160036396, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.1484227720111, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.53092120568363, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.30464403339043, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.6330707809808, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.0625015064288, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 28.146811327342, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 20.9134748394843, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.7232059128344, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 87.4081296747206, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.1151049129435, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 53.3534923614915, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.201290952425, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.80452684678786, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.77882183784468, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.31271468436981, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.3805291245602, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.47926249046842, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.3572169938946, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.4081211960467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.9170591103212, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.7468984848715, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.64799096495502, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.5080879758561, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.2810314967175, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 16.9002072668989, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 9.68737188385233, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.2205684727202, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 12.0104804672694, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 12.024414792948, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 31.5998435846988, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 12.7997859127822, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 18.9322781778579, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.55399147256714, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.8799841301886, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 44.8430328262801, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.48911878674186, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.3133862817997, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 12.1999381996744, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 11.4863906253073, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.7121994289837, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.78167176637539, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 29.9137826209819, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2017158129662, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.5173082429262, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.1652812727907, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 19.5190220794507, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.14324437269526, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 18.2701033392514, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 6.08907410362149, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.2377356611367, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.9635460708463, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.0573393358887, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 23.1873364065521, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.26872701641402, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.4538008181895, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.3936349015142, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.390668804697, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.0318763167839, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.1828214363146, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.5336839702576, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.78320181972676, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.99041474641603, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 5.25369674582079, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.5471067676467, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 10.4519390168196, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.8191762539723, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 12.3751266066711, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6212245099026, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6212244848078, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.35277498718505, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.6973763798696, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.52312705774234, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.697376403277, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 7.52312707318216, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 3.88536585112496, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 14.7338080449975, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 71.4864780130229, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 24.7816917636399, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 9.90765095175996, unable to satisfy inequality constraints.
#
#
# [CVode, Error: -1] At t = 34.7135861726503, mxstep steps taken before reaching tout.
#
#
# [cvHandleFailure, Error: -15] At t = 14.0752258580775, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 16.1157882463569, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 13.078802328757, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 11.6290106027038, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 27.361581783247, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 96.9558287222756, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 37.8154509208849, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.2293851123677, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 55.6849755444442, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 26.2293850686596, unable to satisfy inequality constraints.
#
#
# [cvHandleFailure, Error: -15] At t = 15.9139688260126, unable to satisfy inequality constraints.

# %% [markdown]
# ## 9) Inspect the best CRN
#
# The trainer keeps a **Hall of Fame** of good CRNs found during rollouts.
# We can:
# - plot the best CRN transient response (if supported)
# - print the best loss
# - report Hall of Fame size

# %%
trainer.inspect_best(plot=True)

best = trainer.best_crn()
print("Hall of Fame size:", len(trainer.s.mult_env.hall_of_fame))
if best is not None:
    print("Best loss:", best.last_task_info.get("reward", None))
# Out:
# Best CRN loss: 0.07397101332669119
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['OUT', 'X_1', 'X_2', 'X_3']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# X_1 + X_2 ----> OUT;  [MAK(0.7659051418304443)]
# X_1 + X_3 ----> ∅;  [MAK(0.7443163990974426)]
# OUT + X_1 ----> X_1;  [MAK(0.9148674011230469)]
# OUT + OUT ----> X_1;  [MAK(0.19083274900913239)]
# OUT + OUT ----> X_1 + X_1;  [MAK(0.7699247002601624)]
# Hall of Fame size: 50
# Best loss: 0.07397101332669119

# %% [markdown]
# ## 10) Sample and re-simulate
#
# After training, we can **draw new CRN designs from the learned policy** (sampling runs in evaluation mode, i.e., no gradient updates) and **re-evaluate** them.
#
# This is useful for two reasons:
#
# * **Model exploration:** quickly inspect a diverse set of candidate CRNs generated by the policy, without altering the trained weights.
# * **Controlled re-simulation:** re-run the same sampled CRNs under **modified experimental conditions**, e.g.:
#
#   * a different **input set** (`u_list` or `u_spec`) to test generalization across stimuli,
#   * a different **initial condition** (`ic`) to probe robustness or sensitivity to initialization.
#
# In practice, sampling produces a dedicated **sample Hall-of-Fame** that stores the best `K` sampled environments (lowest loss) for later inspection and checkpointing.

# %%
trainer.sample(10, 10, ic=("constant", 1.0))
# Out:
# [cvHandleFailure, Error: -15] At t = 15.673873259818, unable to satisfy inequality constraints.

# %% [markdown]
# we can so inspect the newly sampled I/O CRNs

# %%
import matplotlib.pyplot as plt

index = 0
print(trainer.get_sampled_crns()[index])
print(trainer.get_sampled_crns()[index].last_task_info.get("reward", None))
trainer.get_sampled_crns()[0].plot_logic_response(); plt.show()
trainer.get_sampled_crns()[0].plot_transient_response(); plt.show()
# Out:
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['OUT', 'X_1', 'X_2', 'X_3']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# X_2 ----> X_1 + X_1;  [MAK(0.36989137530326843)]
# X_2 ----> X_1 + X_2;  [MAK(0.9910580515861511)]
# OUT + X_1 ----> X_2 + X_3;  [MAK(2.084353446960449)]
# X_2 + X_2 ----> X_3 + X_3;  [MAK(0.10925517231225967)]
# OUT + OUT ----> X_1 + X_3;  [MAK(0.750889241695404)]
# 0.13187226139648894

# %% [markdown]
# and save again our results

# %%
# save again
trainer.save(checkpoint_path)
# Out:
# Saved checkpoint: logic_task_chkpt.pkl

# %% [markdown]
# ## 11) Loading a saved Session/Trainer from a checkpoint
#
# the `load_session_and_trainer` makes this task straightforward (a one-liner):

# %%
from RL4CRN.utils.input_interface import load_session_and_trainer

trainer_loaded = load_session_and_trainer("logic_task_chkpt.pkl", device="cuda")
trainer_loaded.inspect_best()
# Out:
# Best CRN loss: 0.07397101332669119
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['OUT', 'X_1', 'X_2', 'X_3']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# X_1 + X_2 ----> OUT;  [MAK(0.7659051418304443)]
# X_1 + X_3 ----> ∅;  [MAK(0.7443163990974426)]
# OUT + X_1 ----> X_1;  [MAK(0.9148674011230469)]
# OUT + OUT ----> X_1;  [MAK(0.19083274900913239)]
# OUT + OUT ----> X_1 + X_1;  [MAK(0.7699247002601624)]

# %%
hof_crns = [item.state for item in trainer.s.mult_env.hall_of_fame]

crns_new = trainer.resimulate(
    hof_crns,
    ic=("constant", 100.05),
    u_spec=("grid", [0.0, 1.0]),
)

trainer.inspect(crns_new[0])
# Out:
# [CVode, Error: -1] At t = 0.0442544480823322, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442536363380471, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0719411356438109, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442544576359502, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.072283480926195, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442536453010427, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0876738576047101, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0719510249857528, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442538209154643, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469875738318741, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0876714348898412, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0722933459362709, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442530072242931, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0876738590282955, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469896909016582, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0719411137533901, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0442538298169261, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0876714383436306, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469968691914006, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0722834974825484, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.044253017062171, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0877466154909994, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469989999842484, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945484723054587, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637533484058134, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0719509863055771, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.095114571188608, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0877441841478837, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.046987592523901, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945484750026097, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637531114173885, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0722933507525025, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0877466187139261, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951357516414713, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469897190175511, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945639004889804, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637556298168554, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0877441865212647, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951272712681457, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0469968933109767, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945639026175241, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637553821962924, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951484786027681, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.046999024429479, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945484723054587, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.063756601366197, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951148334848872, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945484750026097, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637563512940657, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951361879172482, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.063758930507406, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945639004889804, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0951275621081765, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0945639026175241, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0637586723405478, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.095148804064818, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964044093220086, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964932275876117, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476740034763652, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964031995816189, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644343205571589, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476799409120659, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964920074345324, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980691752725587, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644313447030508, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476734624879669, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964044228316278, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715461150961641, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.098069184228171, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644343205571589, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476793960904935, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964932244375286, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715461415747204, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980689804900478, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644313447030508, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476773338058331, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964032158356656, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0711369367463278, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980689685683187, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644332374579291, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476832698549789, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0964920167577026, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980733270571397, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0711369634513113, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644302613853502, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476767897886034, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980733049700576, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715440837652062, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.090185080471094, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644332374579291, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0476827272725481, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.065015600784332, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980730894513376, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715440971457772, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0902898461032022, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0644302613853502, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650156149227211, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0980730747630971, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715944014752234, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0901841918832172, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650264929526136, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0715944089814963, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0902888865606122, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650265042826475, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0901886285420627, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991702681594225, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650155992839454, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.090293301267613, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991704638050901, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650156206715904, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0901877449540709, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991702916254678, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243731286109332, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650265041809247, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0902923540870351, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991704851162921, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243759167762064, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0650265182856739, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991736621149757, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734454542485846, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243703620905655, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991738564243588, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734741480528578, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243731842267041, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0991736869861006, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734454709325327, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243737892599621, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.09917388209628, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734741676135964, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243766250043275, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734466489407411, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243710168166945, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734753433134742, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0243738650499539, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734466689328973, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0734753600973372, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0752816591351673, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0752527520817322, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0756657791686747, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0756176484002987, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961519073655214, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937900692688848, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0565962180344794, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0751370309695079, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961471736794044, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937955805386829, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0565962313840352, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0751004036432105, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.096156696886207, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937900718160112, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0565997927484076, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0754279615027864, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937955821847067, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961519430589744, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.056599804939384, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0753942793991894, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937874498327481, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961519721314788, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0565988834076283, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.093792928202929, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961472566414798, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0565988964736907, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937874515062488, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961568015966558, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0566024620452626, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0937929289334127, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0961520422207729, mxstep steps taken before reaching tout.
#
#
# [CVode, Error: -1] At t = 0.0566024712370683, mxstep steps taken before reaching tout.
#
# CRN loss: 0.11478723662308941
# Inputs: ['u_1', 'u_2', 'u_3']
# Species: ['OUT', 'X_1', 'X_2', 'X_3']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# X_1 + X_2 ----> OUT;  [MAK(0.7659051418304443)]
# X_1 + X_3 ----> ∅;  [MAK(0.7443163990974426)]
# OUT + X_1 ----> X_1;  [MAK(0.9148674011230469)]
# OUT + OUT ----> X_1;  [MAK(0.19083274900913239)]
# OUT + OUT ----> X_1 + X_1;  [MAK(0.7699247002601624)]

# %%
crns_new[0].plot_transient_response(); plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
