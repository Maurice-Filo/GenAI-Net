# %%
# Set up the file path
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(parent_dir)

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import oscillation_error

# %%
# Set the logger to use Comet
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
api_key = "o77J6VCMDamustkfJuMXZ2jdV"
logger = CometLogger(
    api_key=api_key,
    project="oscillators_3species_6rxns_MAK_REINFORCE",        
    workspace="maurice-filo", 
    name=f'oscillators_3species_6rxns_MAK_REINFORCE_{timestamp}',
)
logger = logger.experiment
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/maurice-filo/oscillators-3species-6rxns-mak-reinforce/c05b31d11560441f9b0dd6e2cea891de

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=[], product_labels=['X_1'], input_channels=['u_1'], params=[1.], params_controllability=[True])
r2 = MassAction(reactant_labels=['X_1'], product_labels=[], input_channels=[None], params=[0.1], params_controllability=[True])
r3 = MassAction(reactant_labels=['X_2'], product_labels=[], input_channels=[None], params=[0.1], params_controllability=[True])
r4 = MassAction(reactant_labels=['X_3'], product_labels=[], input_channels=[None], params=[0.1], params_controllability=[True])
crn_template = IOCRN([r1, r2, r3, r4], output_labels=['X_3'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X_1', 'X_2', 'X_3']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# Library of possible reactions:
# Number of reactions: 91
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X_1;  [MAK(None)]
# R2: ∅ ----> X_2;  [MAK(None)]
# R3: ∅ ----> X_3;  [MAK(None)]
# R4: ∅ ----> X_1 + X_1;  [MAK(None)]
# R5: ∅ ----> X_1 + X_2;  [MAK(None)]
# R6: ∅ ----> X_1 + X_3;  [MAK(None)]
# R7: ∅ ----> X_2 + X_2;  [MAK(None)]
# R8: ∅ ----> X_2 + X_3;  [MAK(None)]
# R9: ∅ ----> X_3 + X_3;  [MAK(None)]
# R10: X_1 ----> ∅;  [MAK(None)]
# R11: X_1 ----> X_2;  [MAK(None)]
# R12: X_1 ----> X_3;  [MAK(None)]
# R13: X_1 ----> X_1 + X_1;  [MAK(None)]
# R14: X_1 ----> X_1 + X_2;  [MAK(None)]
# R15: X_1 ----> X_1 + X_3;  [MAK(None)]
# R16: X_1 ----> X_2 + X_2;  [MAK(None)]
# R17: X_1 ----> X_2 + X_3;  [MAK(None)]
# R18: X_1 ----> X_3 + X_3;  [MAK(None)]
# R19: X_2 ----> ∅;  [MAK(None)]
# R20: X_2 ----> X_1;  [MAK(None)]
# R21: X_2 ----> X_3;  [MAK(None)]
# R22: X_2 ----> X_1 + X_1;  [MAK(None)]
# R23: X_2 ----> X_1 + X_2;  [MAK(None)]
# R24: X_2 ----> X_1 + X_3;  [MAK(None)]
# R25: X_2 ----> X_2 + X_2;  [MAK(None)]
# R26: X_2 ----> X_2 + X_3;  [MAK(None)]
# R27: X_2 ----> X_3 + X_3;  [MAK(None)]
# R28: X_3 ----> ∅;  [MAK(None)]
# R29: X_3 ----> X_1;  [MAK(None)]
# R30: X_3 ----> X_2;  [MAK(None)]
# R31: X_3 ----> X_1 + X_1;  [MAK(None)]
# R32: X_3 ----> X_1 + X_2;  [MAK(None)]
# R33: X_3 ----> X_1 + X_3;  [MAK(None)]
# R34: X_3 ----> X_2 + X_2;  [MAK(None)]
# R35: X_3 ----> X_2 + X_3;  [MAK(None)]
# R36: X_3 ----> X_3 + X_3;  [MAK(None)]
# R37: X_1 + X_1 ----> ∅;  [MAK(None)]
# R38: X_1 + X_1 ----> X_1;  [MAK(None)]
# R39: X_1 + X_1 ----> X_2;  [MAK(None)]
# R40: X_1 + X_1 ----> X_3;  [MAK(None)]
# R41: X_1 + X_1 ----> X_1 + X_2;  [MAK(None)]
# R42: X_1 + X_1 ----> X_1 + X_3;  [MAK(None)]
# R43: X_1 + X_1 ----> X_2 + X_2;  [MAK(None)]
# R44: X_1 + X_1 ----> X_2 + X_3;  [MAK(None)]
# R45: X_1 + X_1 ----> X_3 + X_3;  [MAK(None)]
# R46: X_1 + X_2 ----> ∅;  [MAK(None)]
# R47: X_1 + X_2 ----> X_1;  [MAK(None)]
# R48: X_1 + X_2 ----> X_2;  [MAK(None)]
# R49: X_1 + X_2 ----> X_3;  [MAK(None)]
# R50: X_1 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R51: X_1 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R52: X_1 + X_2 ----> X_2 + X_2;  [MAK(None)]
# R53: X_1 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R54: X_1 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R55: X_1 + X_3 ----> ∅;  [MAK(None)]
# R56: X_1 + X_3 ----> X_1;  [MAK(None)]
# R57: X_1 + X_3 ----> X_2;  [MAK(None)]
# R58: X_1 + X_3 ----> X_3;  [MAK(None)]
# R59: X_1 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R60: X_1 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R61: X_1 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R62: X_1 + X_3 ----> X_2 + X_3;  [MAK(None)]
# R63: X_1 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R64: X_2 + X_2 ----> ∅;  [MAK(None)]
# R65: X_2 + X_2 ----> X_1;  [MAK(None)]
# R66: X_2 + X_2 ----> X_2;  [MAK(None)]
# R67: X_2 + X_2 ----> X_3;  [MAK(None)]
# R68: X_2 + X_2 ----> X_1 + X_1;  [MAK(None)]
# R69: X_2 + X_2 ----> X_1 + X_2;  [MAK(None)]
# R70: X_2 + X_2 ----> X_1 + X_3;  [MAK(None)]
# R71: X_2 + X_2 ----> X_2 + X_3;  [MAK(None)]
# R72: X_2 + X_2 ----> X_3 + X_3;  [MAK(None)]
# R73: X_2 + X_3 ----> ∅;  [MAK(None)]
# R74: X_2 + X_3 ----> X_1;  [MAK(None)]
# R75: X_2 + X_3 ----> X_2;  [MAK(None)]
# R76: X_2 + X_3 ----> X_3;  [MAK(None)]
# R77: X_2 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R78: X_2 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R79: X_2 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R80: X_2 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R81: X_2 + X_3 ----> X_3 + X_3;  [MAK(None)]
# R82: X_3 + X_3 ----> ∅;  [MAK(None)]
# R83: X_3 + X_3 ----> X_1;  [MAK(None)]
# R84: X_3 + X_3 ----> X_2;  [MAK(None)]
# R85: X_3 + X_3 ----> X_3;  [MAK(None)]
# R86: X_3 + X_3 ----> X_1 + X_1;  [MAK(None)]
# R87: X_3 + X_3 ----> X_1 + X_2;  [MAK(None)]
# R88: X_3 + X_3 ----> X_1 + X_3;  [MAK(None)]
# R89: X_3 + X_3 ----> X_2 + X_2;  [MAK(None)]
# R90: X_3 + X_3 ----> X_2 + X_3;  [MAK(None)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Flags and filenames
save_flag = False                                                # Save the agent checkpoint
load_flag = True                                               # Load the agent checkpoint 
train_flag = False                                               # Train the agent
save_sheet_flag = False                                          # Save the configuration to an Excel sheet

save_filename = timestamp + '.pth'                              # Filename for saving the agent checkpoint
load_filename = '2025-10-27 19:10:39'                                              # Filename for loading the agent checkpoint
file_name = "oscillators_3species_6rxns_MAK_REINFORCE.xlsx"             # Filename for saving the Excel sheet

# %%
# Hyperparameters
max_added_reactions = 6                             # Maximum number of reactions
N_CPUs = os.cpu_count()                             # Number of CPUs          
N = 20*N_CPUs                                       # Number of samples (batch size)    
width = 1024                                        # Width of the neural networks  
depth = 5                                           # Depth of the neural networks 
deep_layer_size = 1024*10                           # Size of the deep layer encoding the CRNs
allow_input_influence = False                       # Allow input influence in the policy
learning_rate = 1e-5                                # Learning rate for the optimizer 
hall_of_fame_size = 1                               # Size of the hall of fame  
entropy_scheduler = {                               # Entropy scheduler parameters TODO: entropy_weight should factor in batch size and expected reward scale
    'entropy_weight': 1.0, 
    'entropy_update_coefficient': 1, 
    'entropy_schedule': 1000, 
    'minimum_entropy_weight': 1.0
}
risk_scheduler = {                                  # Risk scheduler parameters
    'risk': 0.99, 
    'risk_update': 0.0, 
    'max_risk': 1.0, 
    'risk_schedule': 1000
}
epoch_num = 250                                     # Number of epochs for training

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_1D'}

# Time horizon for the simulation
t_f = 200                                           # Final time for the simulation
N_t = 1000                                          # Number of time steps
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
periods = [10, 15, 20]
u_list = [np.array([1/p]) for p in periods]

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0., 0., 0.]])

# Weight on the damping metric and initial time for peak detection
w = [0/10, 0/10, 10/10]
t0 = 50.

# Construct the compute reward routine
def compute_reward(state):
    f_list = u_list
    x0_list = ic.get_ic(state)
    return oscillation_error(state, u_list, x0_list, time_horizon, f_list, w, t0, LARGE_NUMBER=1e4)

render_schedule = 1                                 # Render every # of epochs
mode = {                                            # Mode of the experiment
    'style': 'logger', 
    'task': 'transients + frequency content', 
    'format': 'image',
    'bounds': [100.0], 
    'bounds_freq': [[1.5, 1]], 
    't0': t0, 
    'scale': 'linear'
}

# %%
# Save the experiment discription in an Excel sheet
if save_sheet_flag:
    sheet_name = "Data"
    headers = ["Timestamp", "URL", 
               "Maximum Number of Added Reactions", 
               "Number of Species", 
               "Number of Inputs", 
               "Batch Size", 
               "Allow Input Influence", 
               "Learning Rate", "Number of Epochs", "Neural Network Depth", "Neural Network Width", "Deep Layer Size", "Number of CPUs",
               "Entropy Scheduler", 
               "Risk Scheduler",
               "Render Schedule", "Hall of Fame Size", 
               "Simulation Time", "Number of Time Steps", "Initial Condition Scenarios", "Input Scenarios",
               "Continuous Distribution"]
    data_row = [timestamp, logger.url, 
                max_added_reactions, 
                len(species_labels), 
                p, N,
                allow_input_influence, 
                learning_rate, epoch_num, depth, width, deep_layer_size, N_CPUs, 
                str(entropy_scheduler),
                str(risk_scheduler),
                render_schedule, hall_of_fame_size,
                t_f, N_t, len(ic.values), len(u_list),
                str(continuous_distribution)]

    if os.path.exists(file_name):
        wb = load_workbook(file_name)
        if sheet_name in wb.sheetnames:
            ws = wb[sheet_name]
        else:
            ws = wb.create_sheet(sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    if ws.max_column < 2:
        for i, header in enumerate(headers, start=1):
            ws.cell(row=i, column=1, value=header)
    next_col = ws.max_column + 1
    for i, value in enumerate(data_row, start=1):
        ws.cell(row=i, column=next_col, value=value)

    wb.save(file_name)
    print(f"New experiment data saved in column {next_col} of '{file_name}'.")

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)
# Out:
# Process ForkPoolWorker-69:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-90:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-75:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-86:
# Process ForkPoolWorker-99:
# Process ForkPoolWorker-73:
# Process ForkPoolWorker-120:
# Process ForkPoolWorker-78:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-116:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-97:
# Process ForkPoolWorker-123:
# Process ForkPoolWorker-112:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-72:
# Process ForkPoolWorker-79:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-74:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-96:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-126:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-128:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-108:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-85:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-101:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-121:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-125:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-122:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-94:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-119:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-92:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-17:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-16:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-82:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# ...
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-84:
# Process ForkPoolWorker-35:
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-95:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-111:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/local0/home/mfilo/git/CRN-GenerativeAI/.venv/lib/python3.10/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=False, masks=masks, device=device, continuous_distribution=continuous_distribution)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=False, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device)
if load_flag:
    agent.policy.load_state_dict(torch.load(load_filename+'.pth', map_location=device))

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Training Loop   
if train_flag:
    for i in tqdm(range(epoch_num)):
        mult_env.reset()
        for j in range(max_added_reactions):
            observations = mult_env.observe(observer, tensorizer)
            actions = agent.act(observations, actuator)
            out = mult_env.step(actions, stepper)
        rewards = mult_env.get_reward(compute_reward)
        agent.update(rewards, step_iteration=i)
        if i % render_schedule == 0:
            mult_env.render(rewards, n_best=5, disregarded_percentage=0.9, mode=mode)

# %%
# Test the model
mult_env.reset()
for j in range(max_added_reactions):
    observations = mult_env.observe(observer, tensorizer)
    actions = agent.act(observations, actuator)
    out = mult_env.step(actions, stepper)
rewards = mult_env.get_reward(compute_reward)

# Gather the CRNs from the environments
crns = mult_env.gather()

# Sort the CRNs by rewards
sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])

# %%
# Plot the results
n_plot = 100
ax = None
for i in range(n_plot):
    x0_list = ic.get_ic(sorted_crns_rewards[i][0])
    time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
    fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
    print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
    print(sorted_crns_rewards[i][0])
# Set y-axis limits
ax[0].set_ylim([0, 10])
# Out:
# IOCRN 0, Reward: 0.0213601161095599
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(14.538311958312988)]
# X_2 ----> X_2 + X_2;  [MAK(2.0556867122650146)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(6.423863410949707)]
# ∅ ----> X_1 + X_1;  [MAK(2.3137764930725098)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(9.027215003967285)]
# X_1 ----> X_2 + X_3;  [MAK(0.1869625449180603)]
# IOCRN 1, Reward: 0.025477564586348755
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.9117245674133301)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5528327822685242)]
# X_2 ----> X_2 + X_2;  [MAK(8.201395034790039)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.634516954421997)]
# ∅ ----> X_1 + X_3;  [MAK(6.102652549743652)]
# X_1 + X_3 ----> X_1;  [MAK(21.788604736328125)]
# IOCRN 2, Reward: 0.02743461591058416
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(2.482700824737549)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.21262702345848083)]
# X_1 ----> X_2 + X_3;  [MAK(0.800318717956543)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(5.150577068328857)]
# X_1 + X_3 ----> X_3;  [MAK(1.1165188550949097)]
# X_1 + X_3 ----> X_1;  [MAK(31.420900344848633)]
# IOCRN 3, Reward: 0.030844396005663022
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.1458414793014526)]
# X_2 ----> X_2 + X_2;  [MAK(16.190921783447266)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.3498232364654541)]
# X_1 ----> X_2 + X_3;  [MAK(1.5582730770111084)]
# X_1 + X_3 ----> X_1;  [MAK(27.784257888793945)]
# X_1 ----> X_1 + X_2;  [MAK(3.2031593322753906)]
# IOCRN 4, Reward: 0.03156120103507265
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(6.606992244720459)]
# X_1 + X_2 ----> X_1 + X_3;  [MAK(0.44070810079574585)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.29276975989341736)]
# X_1 + X_3 ----> X_1;  [MAK(6.427750110626221)]
# X_1 + X_2 ----> ∅;  [MAK(5.005043983459473)]
# X_1 ----> X_1 + X_2;  [MAK(1.2006891965866089)]
# IOCRN 5, Reward: 0.03256596483054908
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(7.262808799743652)]
# X_2 ----> X_2 + X_2;  [MAK(9.413331985473633)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.6602518558502197)]
# X_1 + X_1 ----> X_3;  [MAK(0.6154786944389343)]
# X_1 ----> X_2 + X_3;  [MAK(0.22074256837368011)]
# X_1 + X_3 ----> X_3;  [MAK(0.33642348647117615)]
# IOCRN 6, Reward: 0.034720433739116596
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.14097270369529724)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5938984751701355)]
# X_2 ----> X_2 + X_2;  [MAK(13.199705123901367)]
# X_1 ----> X_2 + X_3;  [MAK(1.4725439548492432)]
# X_1 + X_3 ----> X_1;  [MAK(10.004440307617188)]
# X_1 + X_1 ----> X_1 + X_3;  [MAK(0.5985257029533386)]
# IOCRN 7, Reward: 0.03518210017890244
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_2 ----> X_2 + X_3;  [MAK(7.036924362182617)]
# X_1 ----> X_2 + X_3;  [MAK(0.5151394009590149)]
# X_2 ----> X_2 + X_2;  [MAK(8.201407432556152)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.9487653970718384)]
# X_1 + X_3 ----> X_1;  [MAK(13.710967063903809)]
# X_1 + X_2 ----> ∅;  [MAK(1.0142059326171875)]
# IOCRN 8, Reward: 0.04014807618460525
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(10.090529441833496)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.2661774158477783)]
# X_1 + X_1 ----> X_3;  [MAK(0.9407622814178467)]
# X_1 ----> X_2 + X_3;  [MAK(0.3211628496646881)]
# X_1 + X_3 ----> X_1;  [MAK(17.724241256713867)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.9169217348098755)]
# IOCRN 9, Reward: 0.04088722403313516
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(1.134637475013733)]
# X_1 + X_3 ----> X_1;  [MAK(22.013736724853516)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.4121782779693604)]
# X_2 ----> X_2 + X_2;  [MAK(2.678133010864258)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.5638550519943237)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(5.924801349639893)]
# IOCRN 10, Reward: 0.04103070302229017
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(19.157501220703125)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(4.376860618591309)]
# X_2 ----> X_2 + X_2;  [MAK(10.384666442871094)]
# X_1 ----> X_2 + X_3;  [MAK(1.053758144378662)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.299911618232727)]
# X_1 ----> X_1 + X_1;  [MAK(0.0869324654340744)]
# IOCRN 11, Reward: 0.04195432111703268
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(3.0876541137695312)]
# X_1 + X_1 ----> X_1;  [MAK(7.233402252197266)]
# X_1 + X_3 ----> X_1;  [MAK(10.579167366027832)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.9946672916412354)]
# X_1 ----> X_2 + X_3;  [MAK(0.3909282982349396)]
# X_1 + X_3 ----> X_3;  [MAK(0.5950034260749817)]
# IOCRN 12, Reward: 0.043530254705679616
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(68.01884460449219)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(17.168968200683594)]
# X_1 ----> X_2 + X_3;  [MAK(0.4668668806552887)]
# ∅ ----> X_1 + X_1;  [MAK(13.29098892211914)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.7237956523895264)]
# X_1 + X_3 ----> X_1;  [MAK(15.089545249938965)]
# IOCRN 13, Reward: 0.04438011501106642
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_1 ----> X_1 + X_3;  [MAK(0.6953623294830322)]
# X_1 ----> X_2 + X_3;  [MAK(0.6833610534667969)]
# X_2 ----> X_2 + X_2;  [MAK(1.6903802156448364)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(4.4617767333984375)]
# X_1 + X_3 ----> X_1;  [MAK(26.673431396484375)]
# X_1 + X_3 ----> X_3;  [MAK(3.200974702835083)]
# IOCRN 14, Reward: 0.04520744064799975
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5982020497322083)]
# X_2 ----> X_2 + X_2;  [MAK(15.293166160583496)]
# X_1 ----> X_3;  [MAK(0.6556451320648193)]
# X_1 ----> X_2 + X_3;  [MAK(2.3620243072509766)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(7.037144184112549)]
# X_1 + X_3 ----> X_1;  [MAK(49.16697692871094)]
# IOCRN 15, Reward: 0.049515945632329306
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(16.329608917236328)]
# X_2 ----> X_2 + X_2;  [MAK(1.7425100803375244)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.4739716053009033)]
# X_1 ----> X_1 + X_2;  [MAK(0.3463858664035797)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.4656861126422882)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(2.244621753692627)]
# IOCRN 16, Reward: 0.04982901115867033
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.842604398727417)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.023315906524658)]
# X_2 ----> X_2 + X_2;  [MAK(1.5711677074432373)]
# X_1 + X_3 ----> ∅;  [MAK(0.7917687892913818)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.781811535358429)]
# X_1 + X_3 ----> X_1;  [MAK(26.315711975097656)]
# IOCRN 17, Reward: 0.0499812960427769
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.2953317165374756)]
# X_2 ----> X_2 + X_2;  [MAK(76.42831420898438)]
# X_2 + X_3 ----> ∅;  [MAK(1.6687220335006714)]
# X_1 + X_3 ----> X_3;  [MAK(4.257840156555176)]
# X_1 ----> X_2 + X_3;  [MAK(4.244991302490234)]
# X_1 + X_1 ----> ∅;  [MAK(6.722378253936768)]
# IOCRN 18, Reward: 0.05354132167255321
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(26.809284210205078)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.3117547035217285)]
# X_1 ----> X_2 + X_3;  [MAK(0.47622784972190857)]
# X_1 + X_3 ----> X_1;  [MAK(22.108264923095703)]
# X_1 ----> X_1 + X_2;  [MAK(5.732713222503662)]
# X_1 ----> X_3;  [MAK(2.426980972290039)]
# IOCRN 19, Reward: 0.05386334705424467
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(3.223919630050659)]
# X_2 ----> X_2 + X_2;  [MAK(1.8889646530151367)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.9041597247123718)]
# X_1 ----> X_2 + X_3;  [MAK(0.9791645407676697)]
# X_1 + X_3 ----> X_1;  [MAK(40.35953140258789)]
# X_1 + X_3 ----> X_3;  [MAK(4.798335075378418)]
# IOCRN 20, Reward: 0.05616308213065435
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(19.95309066772461)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.439089775085449)]
# X_1 + X_3 ----> X_1;  [MAK(4.760860919952393)]
# X_1 + X_3 ----> ∅;  [MAK(29.72890853881836)]
# X_1 + X_3 ----> X_3;  [MAK(15.161604881286621)]
# X_1 ----> X_2 + X_3;  [MAK(2.2483208179473877)]
# IOCRN 21, Reward: 0.056186626132449846
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.061039686203003)]
# X_1 + X_3 ----> X_1;  [MAK(5.325759410858154)]
# X_2 ----> X_2 + X_2;  [MAK(29.520383834838867)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.6927376389503479)]
# X_1 + X_3 ----> ∅;  [MAK(11.162388801574707)]
# X_1 ----> X_2 + X_3;  [MAK(3.1440536975860596)]
# IOCRN 22, Reward: 0.05807230156422161
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(4.651378631591797)]
# X_2 ----> X_2 + X_2;  [MAK(24.83020782470703)]
# X_1 + X_3 ----> ∅;  [MAK(4.847524166107178)]
# X_1 ----> X_2 + X_3;  [MAK(0.26449862122535706)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.7191562056541443)]
# X_1 + X_3 ----> X_3;  [MAK(2.073460340499878)]
# IOCRN 23, Reward: 0.05855004498753591
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(53.531734466552734)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.7832176685333252)]
# X_1 + X_3 ----> X_1;  [MAK(1.258963942527771)]
# X_1 ----> X_2 + X_3;  [MAK(0.5574925541877747)]
# X_1 ----> X_3;  [MAK(10.476887702941895)]
# X_1 + X_3 ----> X_3;  [MAK(4.145934581756592)]
# IOCRN 24, Reward: 0.058775007135328905
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.586745023727417)]
# X_2 ----> X_2 + X_2;  [MAK(48.847633361816406)]
# X_1 + X_3 ----> X_3;  [MAK(3.1547980308532715)]
# X_1 ----> X_2 + X_3;  [MAK(22.41161346435547)]
# X_1 + X_3 ----> X_1;  [MAK(1.8598244190216064)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(11.383562088012695)]
# IOCRN 25, Reward: 0.06006073088230901
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.0550856590270996)]
# X_2 ----> X_2 + X_2;  [MAK(6.588113307952881)]
# X_1 ----> X_2 + X_3;  [MAK(0.3992612063884735)]
# X_1 + X_3 ----> X_1;  [MAK(11.013663291931152)]
# X_1 + X_3 ----> X_3;  [MAK(9.921333312988281)]
# X_1 + X_2 ----> X_3;  [MAK(3.374154806137085)]
# IOCRN 26, Reward: 0.06049735108802157
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(9.914667129516602)]
# X_2 ----> X_2 + X_2;  [MAK(139.7239532470703)]
# X_1 ----> X_3 + X_3;  [MAK(17.4283390045166)]
# X_1 + X_3 ----> X_3;  [MAK(1.1038204431533813)]
# X_1 + X_2 ----> X_1;  [MAK(1.0460258722305298)]
# X_1 ----> X_2 + X_3;  [MAK(0.2171170562505722)]
# IOCRN 27, Reward: 0.06089319652957581
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3;  [MAK(4.4873504638671875)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.4107911288738251)]
# X_2 ----> X_2 + X_2;  [MAK(5.000520706176758)]
# X_1 ----> X_2 + X_3;  [MAK(3.7114923000335693)]
# X_1 ----> X_3 + X_3;  [MAK(1.7137349843978882)]
# X_1 + X_3 ----> X_1;  [MAK(42.171817779541016)]
# IOCRN 28, Reward: 0.061355424734166
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(2.8714168071746826)]
# X_1 ----> X_2 + X_3;  [MAK(1.4760425090789795)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.9089865684509277)]
# X_1 + X_3 ----> X_1;  [MAK(66.70143127441406)]
# X_1 + X_3 ----> X_3;  [MAK(1.4021875858306885)]
# X_1 + X_2 ----> X_2 + X_2;  [MAK(0.43606629967689514)]
# IOCRN 29, Reward: 0.06202769583525336
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.4297175705432892)]
# X_1 + X_3 ----> X_3;  [MAK(2.0427346229553223)]
# X_1 ----> X_2 + X_3;  [MAK(2.875979423522949)]
# X_1 + X_3 ----> X_1;  [MAK(5.242255210876465)]
# X_2 ----> X_2 + X_2;  [MAK(18.98448944091797)]
# X_1 + X_2 ----> X_3;  [MAK(2.1981189250946045)]
# IOCRN 30, Reward: 0.06256636239854185
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> ∅;  [MAK(4.223484516143799)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.6935189366340637)]
# X_2 ----> X_2 + X_2;  [MAK(20.31787872314453)]
# X_1 ----> X_3;  [MAK(1.652733564376831)]
# X_1 ----> X_3 + X_3;  [MAK(2.2829554080963135)]
# X_1 ----> X_2 + X_3;  [MAK(1.2396650314331055)]
# IOCRN 31, Reward: 0.06257779305687272
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(29.393346786499023)]
# X_1 + X_2 ----> X_3 + X_3;  [MAK(1.480887532234192)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.65277099609375)]
# X_1 + X_3 ----> X_1;  [MAK(0.5921916365623474)]
# X_1 ----> X_2 + X_3;  [MAK(0.887017011642456)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(6.196936130523682)]
# IOCRN 32, Reward: 0.0631747983689902
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(32.80204772949219)]
# X_1 ----> X_3;  [MAK(0.8213021755218506)]
# X_1 + X_2 ----> X_2;  [MAK(0.5105986595153809)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.8753679394721985)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(4.886375427246094)]
# X_1 ----> X_2 + X_3;  [MAK(8.371450424194336)]
# IOCRN 33, Reward: 0.06528811419326175
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(31.20525550842285)]
# X_1 ----> X_2 + X_3;  [MAK(5.195048809051514)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.5208191871643066)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(37.065467834472656)]
# X_1 + X_1 ----> X_1 + X_3;  [MAK(0.3272140622138977)]
# X_1 + X_3 ----> X_1;  [MAK(5.494478702545166)]
# IOCRN 34, Reward: 0.06665038416772706
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.6737397909164429)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.016705870628357)]
# X_2 ----> X_2 + X_2;  [MAK(9.058595657348633)]
# X_1 + X_3 ----> X_1;  [MAK(6.12156867980957)]
# X_1 + X_3 ----> X_3;  [MAK(0.18799537420272827)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.0141866207122803)]
# IOCRN 35, Reward: 0.06699108024882283
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.1968604326248169)]
# X_2 ----> X_2 + X_2;  [MAK(14.740934371948242)]
# X_1 ----> X_2 + X_3;  [MAK(8.72618293762207)]
# X_1 + X_3 ----> X_1;  [MAK(4.571840286254883)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.1668775081634521)]
# X_1 + X_3 ----> X_3;  [MAK(0.7132022976875305)]
# IOCRN 36, Reward: 0.06720746677370704
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(19.7684268951416)]
# X_1 + X_3 ----> X_3;  [MAK(22.9394474029541)]
# X_1 ----> X_2 + X_3;  [MAK(2.508697271347046)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.650931715965271)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(5.364006519317627)]
# X_1 ----> X_3 + X_3;  [MAK(2.980955123901367)]
# IOCRN 37, Reward: 0.06721902674238667
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(24.16749382019043)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.26262423396110535)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(4.0499653816223145)]
# X_1 + X_3 ----> X_1;  [MAK(6.720550537109375)]
# X_1 + X_3 ----> X_3;  [MAK(16.81977081298828)]
# X_1 ----> X_2 + X_3;  [MAK(22.220888137817383)]
# IOCRN 38, Reward: 0.0673281251870933
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(42.221778869628906)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(3.976346731185913)]
# X_1 + X_3 ----> X_3;  [MAK(3.6124656200408936)]
# X_1 ----> X_2 + X_3;  [MAK(3.0719759464263916)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(36.788604736328125)]
# X_1 ----> X_3;  [MAK(1.306717038154602)]
# IOCRN 39, Reward: 0.06758907493326927
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_3;  [MAK(12.106431007385254)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.3169965744018555)]
# X_2 ----> X_2 + X_2;  [MAK(29.545873641967773)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(7.3467020988464355)]
# X_1 + X_3 ----> X_3;  [MAK(0.8555126786231995)]
# X_1 ----> X_2 + X_3;  [MAK(1.2464051246643066)]
# IOCRN 40, Reward: 0.06858802321812718
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(5.560197353363037)]
# X_1 + X_3 ----> X_3;  [MAK(2.789140462875366)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.2787938416004181)]
# X_2 ----> X_2 + X_2;  [MAK(22.730228424072266)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.8413405418395996)]
# X_1 + X_2 ----> X_2 + X_2;  [MAK(0.7410539984703064)]
# IOCRN 41, Reward: 0.06872760787452747
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(83.41157531738281)]
# X_1 + X_3 ----> X_1;  [MAK(1.4738785028457642)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.752408742904663)]
# X_1 + X_3 ----> X_3;  [MAK(13.125730514526367)]
# X_1 ----> X_2 + X_3;  [MAK(5.929455280303955)]
# X_1 + X_2 ----> X_2;  [MAK(3.6758155822753906)]
# IOCRN 42, Reward: 0.06884689380087217
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(17.237239837646484)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(16.11557388305664)]
# X_1 + X_3 ----> X_1;  [MAK(1.33896803855896)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5938055515289307)]
# X_1 ----> X_3;  [MAK(8.950996398925781)]
# X_1 ----> X_2 + X_3;  [MAK(9.78498649597168)]
# IOCRN 43, Reward: 0.06904910629999694
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(18.979183197021484)]
# X_2 ----> X_2 + X_2;  [MAK(20.89039421081543)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.2071120738983154)]
# X_1 ----> X_2 + X_3;  [MAK(3.589592933654785)]
# X_1 ----> X_3 + X_3;  [MAK(1.1482123136520386)]
# X_1 ----> X_3;  [MAK(3.8464784622192383)]
# IOCRN 44, Reward: 0.06968060079114702
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(14.655265808105469)]
# X_1 + X_3 ----> X_1;  [MAK(1.804835319519043)]
# X_1 + X_3 ----> X_3;  [MAK(5.9540486335754395)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.1037802696228027)]
# X_1 ----> X_2 + X_3;  [MAK(1.5390304327011108)]
# X_1 ----> X_1 + X_1;  [MAK(1.1740350723266602)]
# IOCRN 45, Reward: 0.07011961354091245
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.3042380213737488)]
# X_2 ----> X_2 + X_2;  [MAK(10.437042236328125)]
# X_1 + X_3 ----> X_1;  [MAK(2.9495997428894043)]
# X_1 ----> X_2 + X_3;  [MAK(1.8610303401947021)]
# X_1 + X_3 ----> X_3;  [MAK(1.3044801950454712)]
# X_1 ----> X_3 + X_3;  [MAK(5.102826118469238)]
# IOCRN 46, Reward: 0.07045477238328957
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5510298609733582)]
# X_2 ----> X_2 + X_2;  [MAK(9.799220085144043)]
# X_1 ----> X_2 + X_3;  [MAK(6.2790398597717285)]
# X_1 + X_1 ----> X_2;  [MAK(0.7442575097084045)]
# X_1 + X_3 ----> ∅;  [MAK(34.2786750793457)]
# X_1 ----> X_1 + X_2;  [MAK(1.111878514289856)]
# IOCRN 47, Reward: 0.07052602041481315
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(8.545746803283691)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(26.695884704589844)]
# X_1 ----> X_2 + X_3;  [MAK(0.26073241233825684)]
# X_1 + X_3 ----> X_3;  [MAK(13.764941215515137)]
# X_2 ----> X_3 + X_3;  [MAK(0.28156763315200806)]
# X_1 + X_3 ----> ∅;  [MAK(28.312074661254883)]
# IOCRN 48, Reward: 0.070687525294725
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.36698561906814575)]
# X_1 ----> X_2 + X_3;  [MAK(9.35123062133789)]
# X_2 ----> X_2 + X_2;  [MAK(26.72137451171875)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(12.661091804504395)]
# X_1 + X_3 ----> X_1;  [MAK(1.4916377067565918)]
# X_1 + X_3 ----> X_3;  [MAK(4.8664021492004395)]
# IOCRN 49, Reward: 0.0708132728700005
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(18.6882381439209)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5330229997634888)]
# X_1 ----> X_2 + X_3;  [MAK(1.2173994779586792)]
# X_1 + X_3 ----> X_3;  [MAK(2.279176712036133)]
# X_2 ----> X_1;  [MAK(6.195901870727539)]
# X_1 ----> X_3;  [MAK(1.365188479423523)]
# IOCRN 50, Reward: 0.07084800258961044
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.3508794605731964)]
# X_2 ----> X_2 + X_2;  [MAK(8.205124855041504)]
# X_1 + X_2 ----> X_2 + X_2;  [MAK(10.057003021240234)]
# X_1 + X_3 ----> X_1;  [MAK(23.514692306518555)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5511716604232788)]
# X_1 + X_3 ----> X_3;  [MAK(16.720043182373047)]
# IOCRN 51, Reward: 0.07089909063459221
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(10.736018180847168)]
# X_1 + X_3 ----> X_3;  [MAK(22.75490379333496)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.8899999856948853)]
# X_1 + X_3 ----> X_1;  [MAK(13.00284194946289)]
# X_1 ----> X_2 + X_3;  [MAK(0.2917293906211853)]
# X_1 ----> X_3;  [MAK(0.19440968334674835)]
# IOCRN 52, Reward: 0.07235925195116788
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(1.8930939435958862)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.7070657014846802)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(3.2000553607940674)]
# X_1 ----> X_2 + X_3;  [MAK(0.8479769229888916)]
# X_2 ----> X_2 + X_2;  [MAK(17.327674865722656)]
# X_1 + X_3 ----> X_3;  [MAK(0.7021961808204651)]
# IOCRN 53, Reward: 0.07263448951815776
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.6668317914009094)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.3265092372894287)]
# X_2 ----> X_2 + X_2;  [MAK(14.692012786865234)]
# X_1 ----> X_2 + X_3;  [MAK(2.1432619094848633)]
# X_1 + X_3 ----> X_3;  [MAK(9.06567096710205)]
# X_1 + X_3 ----> X_1;  [MAK(1.1305922269821167)]
# IOCRN 54, Reward: 0.07318923151537737
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(7.247612476348877)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(3.086435317993164)]
# X_1 + X_3 ----> X_1;  [MAK(15.691129684448242)]
# X_1 + X_3 ----> X_3;  [MAK(64.04280090332031)]
# X_1 ----> X_2 + X_3;  [MAK(1.346994161605835)]
# X_1 + X_3 ----> ∅;  [MAK(5.403033256530762)]
# IOCRN 55, Reward: 0.07349365823592413
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(7.476526737213135)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.9259230494499207)]
# X_1 ----> X_2 + X_3;  [MAK(2.541443109512329)]
# X_1 + X_3 ----> X_1;  [MAK(0.5457366108894348)]
# X_1 + X_3 ----> ∅;  [MAK(31.986270904541016)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.757556915283203)]
# IOCRN 56, Reward: 0.07350318742715645
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(3.568450450897217)]
# X_1 ----> X_2 + X_3;  [MAK(0.6348156929016113)]
# X_1 + X_3 ----> X_1;  [MAK(3.7389791011810303)]
# X_2 ----> X_2 + X_2;  [MAK(10.567314147949219)]
# X_1 + X_3 ----> X_3;  [MAK(2.2089715003967285)]
# X_1 + X_3 ----> ∅;  [MAK(6.733608722686768)]
# IOCRN 57, Reward: 0.07378362445645703
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(11.656038284301758)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.22968335449695587)]
# X_1 ----> X_2 + X_3;  [MAK(2.462432384490967)]
# X_1 + X_1 ----> X_3;  [MAK(2.7405717372894287)]
# X_1 + X_3 ----> X_1;  [MAK(5.233731269836426)]
# X_1 + X_3 ----> X_3;  [MAK(3.8708674907684326)]
# IOCRN 58, Reward: 0.07403488427286076
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(15.675366401672363)]
# X_1 + X_3 ----> X_3;  [MAK(5.790840148925781)]
# X_1 + X_3 ----> X_1;  [MAK(0.5596516728401184)]
# X_1 + X_3 ----> ∅;  [MAK(17.801681518554688)]
# X_1 ----> X_2 + X_3;  [MAK(1.6726365089416504)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(3.559314250946045)]
# IOCRN 59, Reward: 0.07409420998074756
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(18.165863037109375)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5060734748840332)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(10.305784225463867)]
# X_1 ----> X_3 + X_3;  [MAK(13.104618072509766)]
# X_1 ----> X_2 + X_3;  [MAK(1.809181571006775)]
# X_2 ----> X_2 + X_2;  [MAK(9.812548637390137)]
# IOCRN 60, Reward: 0.07423653403456287
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(13.509592056274414)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5907673835754395)]
# X_1 + X_3 ----> X_3;  [MAK(6.305936813354492)]
# X_1 ----> X_2 + X_3;  [MAK(8.981039047241211)]
# X_1 ----> X_3;  [MAK(0.29506000876426697)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(8.108779907226562)]
# IOCRN 61, Reward: 0.07426968483597918
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.4555208683013916)]
# X_1 + X_3 ----> X_3;  [MAK(14.375672340393066)]
# X_1 ----> X_2 + X_3;  [MAK(0.6438729763031006)]
# X_2 ----> X_2 + X_2;  [MAK(10.786892890930176)]
# X_1 + X_3 ----> X_1;  [MAK(3.632582902908325)]
# X_1 ----> X_3 + X_3;  [MAK(0.6039074063301086)]
# IOCRN 62, Reward: 0.07432959349106938
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_3 + X_3;  [MAK(2.96890926361084)]
# X_2 ----> X_2 + X_2;  [MAK(9.792370796203613)]
# X_1 ----> X_2 + X_3;  [MAK(0.6753186583518982)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.30439305305480957)]
# X_1 + X_3 ----> X_3;  [MAK(0.5971133708953857)]
# X_1 + X_3 ----> X_1;  [MAK(1.0786057710647583)]
# IOCRN 63, Reward: 0.07460297636522151
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(1.2043007612228394)]
# X_1 + X_3 ----> X_3;  [MAK(4.423009872436523)]
# X_1 ----> X_2 + X_3;  [MAK(0.8313174843788147)]
# X_1 ----> X_1 + X_1;  [MAK(34.424049377441406)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.931470274925232)]
# X_2 + X_2 ----> X_3;  [MAK(9.682821273803711)]
# IOCRN 64, Reward: 0.07466917867025025
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(9.243467330932617)]
# X_1 ----> X_2 + X_3;  [MAK(3.652763843536377)]
# X_1 ----> X_2 + X_2;  [MAK(1.9800341129302979)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.5899549722671509)]
# X_1 ----> X_1 + X_1;  [MAK(118.02347564697266)]
# X_1 + X_3 ----> X_3;  [MAK(0.5005223751068115)]
# IOCRN 65, Reward: 0.07496627990041338
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(8.243767738342285)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.6713070273399353)]
# X_1 ----> X_2 + X_3;  [MAK(1.86620032787323)]
# X_1 + X_3 ----> X_1;  [MAK(1.108328104019165)]
# X_1 + X_3 ----> ∅;  [MAK(14.490564346313477)]
# X_1 ----> X_1 + X_2;  [MAK(3.150437116622925)]
# IOCRN 66, Reward: 0.07498015754325493
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.6024592518806458)]
# X_2 ----> X_2 + X_2;  [MAK(16.617116928100586)]
# X_1 ----> X_2 + X_3;  [MAK(0.7198665142059326)]
# X_1 + X_3 ----> X_3;  [MAK(0.33840954303741455)]
# X_1 + X_2 ----> X_3;  [MAK(13.117840766906738)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.4600608348846436)]
# IOCRN 67, Reward: 0.07513403949234243
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.5885206460952759)]
# X_2 ----> X_2 + X_2;  [MAK(5.835116863250732)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.7127066850662231)]
# X_1 + X_3 ----> X_1;  [MAK(9.128809928894043)]
# X_1 ----> X_1 + X_2;  [MAK(2.5112175941467285)]
# X_1 + X_2 ----> X_3;  [MAK(6.567228317260742)]
# IOCRN 68, Reward: 0.07601796448701714
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(15.595985412597656)]
# X_1 ----> X_2 + X_3;  [MAK(0.5972831845283508)]
# X_1 + X_3 ----> X_1;  [MAK(1.8949285745620728)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(3.4411697387695312)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.4156213998794556)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(2.844890594482422)]
# IOCRN 69, Reward: 0.07660664262886907
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(4.673004150390625)]
# X_2 ----> X_2 + X_2;  [MAK(10.652759552001953)]
# X_1 ----> X_2 + X_3;  [MAK(1.5451879501342773)]
# X_1 + X_3 ----> X_3;  [MAK(2.256784677505493)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5990697145462036)]
# X_1 ----> X_3 + X_3;  [MAK(24.814836502075195)]
# IOCRN 70, Reward: 0.07663391479512749
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(16.516611099243164)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(3.7480859756469727)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.2770000696182251)]
# X_1 ----> X_2 + X_3;  [MAK(2.485492467880249)]
# X_1 + X_3 ----> X_1;  [MAK(2.66752552986145)]
# X_1 ----> X_1 + X_1;  [MAK(4.352540969848633)]
# IOCRN 71, Reward: 0.07666066492474377
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.7673979997634888)]
# X_1 + X_3 ----> X_3;  [MAK(3.3139753341674805)]
# X_1 + X_3 ----> X_1;  [MAK(3.493736982345581)]
# X_2 ----> X_2 + X_2;  [MAK(15.175378799438477)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.3898208141326904)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(8.759641647338867)]
# IOCRN 72, Reward: 0.07701044953556335
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_2 ----> X_2;  [MAK(1.4719440937042236)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.528834879398346)]
# X_1 + X_3 ----> X_3;  [MAK(8.83729076385498)]
# X_2 ----> X_2 + X_2;  [MAK(9.550237655639648)]
# X_1 ----> X_2 + X_3;  [MAK(3.5291152000427246)]
# X_1 + X_3 ----> X_1;  [MAK(0.3404560685157776)]
# IOCRN 73, Reward: 0.07713332800476735
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(1.4869656562805176)]
# X_1 + X_3 ----> X_1;  [MAK(0.8248479962348938)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(4.352600574493408)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5344805121421814)]
# X_2 ----> X_2 + X_2;  [MAK(12.940366744995117)]
# X_1 + X_3 ----> X_3;  [MAK(1.6462101936340332)]
# IOCRN 74, Reward: 0.07832128133231286
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.017322063446045)]
# X_1 + X_3 ----> ∅;  [MAK(0.36797016859054565)]
# X_2 ----> X_2 + X_2;  [MAK(17.9239444732666)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.7421703338623047)]
# X_1 ----> X_3 + X_3;  [MAK(1.8709787130355835)]
# X_1 ----> X_2 + X_3;  [MAK(1.587380051612854)]
# IOCRN 75, Reward: 0.07839223149159535
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5182346701622009)]
# X_2 ----> X_2 + X_2;  [MAK(13.232096672058105)]
# X_1 + X_3 ----> X_1;  [MAK(1.6425808668136597)]
# X_1 + X_3 ----> X_3;  [MAK(6.129359245300293)]
# X_1 ----> X_2 + X_3;  [MAK(0.9763931632041931)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.7252135276794434)]
# IOCRN 76, Reward: 0.07884216217310558
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(3.5223798751831055)]
# X_1 + X_1 ----> X_1 + X_3;  [MAK(1.0975288152694702)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.4820517301559448)]
# X_1 ----> X_2 + X_3;  [MAK(0.6444730162620544)]
# X_1 + X_3 ----> X_1;  [MAK(6.63355016708374)]
# X_1 + X_3 ----> ∅;  [MAK(3.1706199645996094)]
# IOCRN 77, Reward: 0.07926675919341097
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.153416395187378)]
# X_1 ----> X_2 + X_3;  [MAK(1.9571263790130615)]
# X_2 ----> X_2 + X_2;  [MAK(13.220637321472168)]
# X_1 ----> X_3;  [MAK(2.5017528533935547)]
# X_1 ----> X_1 + X_2;  [MAK(2.792675733566284)]
# X_1 + X_3 ----> ∅;  [MAK(29.988224029541016)]
# IOCRN 78, Reward: 0.07960958823862152
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(21.73280906677246)]
# X_1 ----> X_2 + X_3;  [MAK(0.7517493367195129)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.10294844955205917)]
# X_1 + X_3 ----> ∅;  [MAK(1.3205879926681519)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.6512930393218994)]
# X_1 + X_3 ----> X_3;  [MAK(0.6301298141479492)]
# IOCRN 79, Reward: 0.07962838157569863
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(11.316131591796875)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.6376360654830933)]
# X_1 ----> X_2 + X_3;  [MAK(0.22949904203414917)]
# X_1 + X_3 ----> ∅;  [MAK(0.8332666754722595)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.1774404048919678)]
# X_1 + X_3 ----> X_3;  [MAK(4.688572406768799)]
# IOCRN 80, Reward: 0.0800813787843665
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(1.4722872972488403)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(4.750421047210693)]
# X_1 ----> X_2 + X_3;  [MAK(0.7240452766418457)]
# X_1 + X_3 ----> X_3;  [MAK(8.563081741333008)]
# X_1 + X_3 ----> ∅;  [MAK(41.32748794555664)]
# X_1 + X_3 ----> X_1;  [MAK(0.48538726568222046)]
# IOCRN 81, Reward: 0.08048616298700717
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.6606685519218445)]
# X_2 ----> X_2 + X_2;  [MAK(6.679810523986816)]
# X_1 + X_3 ----> X_3;  [MAK(14.991705894470215)]
# X_1 ----> X_3 + X_3;  [MAK(1.6416597366333008)]
# X_1 + X_3 ----> X_1;  [MAK(13.249983787536621)]
# X_1 ----> X_2 + X_3;  [MAK(4.24375057220459)]
# IOCRN 82, Reward: 0.08081969906574582
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_3;  [MAK(6.699763298034668)]
# X_2 ----> X_2 + X_2;  [MAK(32.02805709838867)]
# X_1 ----> X_2 + X_3;  [MAK(0.744554877281189)]
# X_1 + X_3 ----> X_1;  [MAK(15.310962677001953)]
# X_1 + X_3 ----> X_3;  [MAK(9.614792823791504)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(7.1993513107299805)]
# IOCRN 83, Reward: 0.0808877654518293
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(13.56616497039795)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.21445833146572113)]
# X_1 ----> X_2 + X_3;  [MAK(1.7062946557998657)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(2.446195363998413)]
# X_1 + X_3 ----> ∅;  [MAK(27.51058578491211)]
# X_1 + X_3 ----> X_3;  [MAK(1.9492039680480957)]
# IOCRN 84, Reward: 0.08139767483609761
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(14.639551162719727)]
# X_1 ----> X_2 + X_3;  [MAK(0.12086190283298492)]
# X_1 + X_3 ----> X_1;  [MAK(0.6306191086769104)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.2553664445877075)]
# X_1 ----> X_3;  [MAK(14.177101135253906)]
# X_1 + X_3 ----> X_3;  [MAK(2.621807813644409)]
# IOCRN 85, Reward: 0.0814300177992987
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.23812711238861084)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.711612582206726)]
# X_1 ----> X_2 + X_3;  [MAK(2.0586507320404053)]
# X_2 ----> X_2 + X_2;  [MAK(3.4084432125091553)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(3.0152409076690674)]
# X_1 + X_3 ----> X_1;  [MAK(9.7841796875)]
# IOCRN 86, Reward: 0.08147285986899833
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.26997900009155273)]
# X_1 + X_3 ----> X_1;  [MAK(7.178158283233643)]
# X_2 ----> X_2 + X_2;  [MAK(4.763577461242676)]
# X_1 ----> X_2 + X_3;  [MAK(0.5014333724975586)]
# X_1 + X_1 ----> X_3;  [MAK(1.1830291748046875)]
# X_1 + X_3 ----> ∅;  [MAK(4.743152141571045)]
# IOCRN 87, Reward: 0.08204893887144304
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3;  [MAK(2.5564494132995605)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.6345107555389404)]
# X_2 ----> X_2 + X_2;  [MAK(3.9516427516937256)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.877801775932312)]
# X_1 + X_3 ----> X_1;  [MAK(3.77780818939209)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(6.984528541564941)]
# IOCRN 88, Reward: 0.08233359640623539
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.2675580084323883)]
# X_1 + X_3 ----> ∅;  [MAK(0.4389069974422455)]
# X_1 ----> X_2 + X_3;  [MAK(4.005504608154297)]
# X_2 ----> X_2 + X_2;  [MAK(8.54204273223877)]
# X_1 + X_2 ----> X_2 + X_3;  [MAK(1.4241971969604492)]
# X_1 + X_3 ----> X_3;  [MAK(5.435658931732178)]
# IOCRN 89, Reward: 0.0824295677694935
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.0528179295361042)]
# X_2 ----> X_2 + X_2;  [MAK(13.220013618469238)]
# X_1 ----> X_2 + X_3;  [MAK(35.66624450683594)]
# X_1 + X_3 ----> X_3;  [MAK(61.229393005371094)]
# X_1 ----> X_3 + X_3;  [MAK(0.40495437383651733)]
# X_1 ----> X_1 + X_2;  [MAK(0.7224534153938293)]
# IOCRN 90, Reward: 0.08320761756633799
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.8814589977264404)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5023490190505981)]
# X_1 ----> X_2 + X_3;  [MAK(1.489833950996399)]
# X_2 ----> X_2 + X_2;  [MAK(6.8953375816345215)]
# X_1 + X_3 ----> X_3;  [MAK(3.591277837753296)]
# X_1 + X_3 ----> ∅;  [MAK(5.954953193664551)]
# IOCRN 91, Reward: 0.0833100854140546
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(9.430399894714355)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.3429597020149231)]
# X_1 ----> X_2 + X_3;  [MAK(1.7894681692123413)]
# X_1 + X_1 ----> X_3;  [MAK(17.519180297851562)]
# X_1 + X_3 ----> X_3;  [MAK(0.7905091047286987)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.9101029634475708)]
# IOCRN 92, Reward: 0.08350558843332523
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(26.901613235473633)]
# X_1 + X_1 ----> X_2 + X_3;  [MAK(0.4414209723472595)]
# X_1 + X_1 ----> X_3 + X_3;  [MAK(7.655948162078857)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.8637871146202087)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(10.86037540435791)]
# X_1 + X_3 ----> X_3;  [MAK(2.146556854248047)]
# IOCRN 93, Reward: 0.08376353419876725
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.0016884803771973)]
# X_2 ----> X_2 + X_2;  [MAK(16.807096481323242)]
# X_1 ----> X_2 + X_3;  [MAK(0.35656100511550903)]
# X_1 ----> X_3;  [MAK(4.192446708679199)]
# X_1 ----> X_3 + X_3;  [MAK(0.23329605162143707)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(5.268303394317627)]
# IOCRN 94, Reward: 0.08439121212676381
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(7.446572780609131)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.26565444469451904)]
# X_1 + X_3 ----> X_3;  [MAK(1.0228244066238403)]
# X_1 ----> X_2 + X_3;  [MAK(1.1769956350326538)]
# X_1 + X_2 ----> X_1 + X_1;  [MAK(15.410244941711426)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.282639741897583)]
# IOCRN 95, Reward: 0.08458595938049607
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.023353934288025)]
# X_1 ----> X_2 + X_3;  [MAK(0.1469188779592514)]
# X_2 ----> X_2 + X_2;  [MAK(3.4981987476348877)]
# X_1 + X_3 ----> X_3;  [MAK(0.32893916964530945)]
# X_1 + X_3 ----> X_1;  [MAK(4.578757286071777)]
# ∅ ----> X_3;  [MAK(0.35143202543258667)]
# IOCRN 96, Reward: 0.08517837485414803
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(12.221575736999512)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.1364426612854004)]
# X_2 ----> X_2 + X_2;  [MAK(14.056246757507324)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(20.332534790039062)]
# X_1 + X_3 ----> X_1;  [MAK(1.0485060214996338)]
# X_1 ----> X_3 + X_3;  [MAK(7.699771881103516)]
# IOCRN 97, Reward: 0.08518491625590485
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(3.4857022762298584)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(3.1028974056243896)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(2.0393714904785156)]
# X_1 + X_3 ----> X_1;  [MAK(8.193116188049316)]
# X_2 ----> X_2 + X_2;  [MAK(45.237876892089844)]
# X_1 + X_3 ----> X_3;  [MAK(0.31637042760849)]
# IOCRN 98, Reward: 0.08525706392026267
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.294314444065094)]
# X_1 ----> X_2 + X_3;  [MAK(3.723647356033325)]
# X_2 ----> X_2 + X_2;  [MAK(10.580567359924316)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.211449146270752)]
# X_1 + X_3 ----> X_1;  [MAK(1.4858262538909912)]
# X_1 + X_3 ----> X_3;  [MAK(21.696176528930664)]
# IOCRN 99, Reward: 0.0855317875722359
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(3.5302062034606934)]
# X_1 ----> X_2 + X_3;  [MAK(0.718948483467102)]
# X_1 + X_3 ----> ∅;  [MAK(34.749114990234375)]
# X_1 + X_1 ----> X_3;  [MAK(0.7048642635345459)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.8841463327407837)]
# X_1 ----> X_3 + X_3;  [MAK(4.520818710327148)]
# (0.0, 10.0)

# %%
if save_flag:
    torch.save(agent.policy.state_dict(), save_filename)

# %%
# Plot the results
n_plot = 5
for i in range(n_plot):
    x0_list = ic.get_ic(sorted_crns_rewards[i][0])
    time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
    fig, ax = sorted_crns_rewards[i][0].plot_transient_response(alpha=1)
    fig, ax = sorted_crns_rewards[i][0].plot_frequency_content(alpha=1)
    print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
    print(sorted_crns_rewards[i][0])
# Out:
# IOCRN 0, Reward: 0.0213601161095599
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 + X_3 ----> X_1;  [MAK(14.538311958312988)]
# X_2 ----> X_2 + X_2;  [MAK(2.0556867122650146)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(6.423863410949707)]
# ∅ ----> X_1 + X_1;  [MAK(2.3137764930725098)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(9.027215003967285)]
# X_1 ----> X_2 + X_3;  [MAK(0.1869625449180603)]
# IOCRN 1, Reward: 0.025477564586348755
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_1 ----> X_2 + X_3;  [MAK(0.9117245674133301)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.5528327822685242)]
# X_2 ----> X_2 + X_2;  [MAK(8.201395034790039)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(1.634516954421997)]
# ∅ ----> X_1 + X_3;  [MAK(6.102652549743652)]
# X_1 + X_3 ----> X_1;  [MAK(21.788604736328125)]
# IOCRN 2, Reward: 0.02743461591058416
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(2.482700824737549)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.21262702345848083)]
# X_1 ----> X_2 + X_3;  [MAK(0.800318717956543)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(5.150577068328857)]
# X_1 + X_3 ----> X_3;  [MAK(1.1165188550949097)]
# X_1 + X_3 ----> X_1;  [MAK(31.420900344848633)]
# IOCRN 3, Reward: 0.030844396005663022
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(1.1458414793014526)]
# X_2 ----> X_2 + X_2;  [MAK(16.190921783447266)]
# X_1 + X_3 ----> X_3 + X_3;  [MAK(0.3498232364654541)]
# X_1 ----> X_2 + X_3;  [MAK(1.5582730770111084)]
# X_1 + X_3 ----> X_1;  [MAK(27.784257888793945)]
# X_1 ----> X_1 + X_2;  [MAK(3.2031593322753906)]
# IOCRN 4, Reward: 0.03156120103507265
# Inputs: ['u_1']
# Species: ['X_1', 'X_2', 'X_3']
# Output Species: ['X_3']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# X_1 ----> ∅;  [MAK(0.1)]
# X_2 ----> ∅;  [MAK(0.1)]
# X_3 ----> ∅;  [MAK(0.1)]
# X_2 ----> X_2 + X_2;  [MAK(6.606992244720459)]
# X_1 + X_2 ----> X_1 + X_3;  [MAK(0.44070810079574585)]
# X_2 + X_3 ----> X_3 + X_3;  [MAK(0.29276975989341736)]
# X_1 + X_3 ----> X_1;  [MAK(6.427750110626221)]
# X_1 + X_2 ----> ∅;  [MAK(5.005043983459473)]
# X_1 ----> X_1 + X_2;  [MAK(1.2006891965866089)]
