# %%
# Set up the file path
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
sys.path.append(parent_dir)
print('Parent directory set to:', parent_dir)
target_directory = '/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_HF_REINFORCE/logic_4inputs_1output_6species_8rxns/'
sys.path.append(parent_dir)
print('Working directory set to:', parent_dir)
print('Target directory set to:', target_directory)
# Out:
# Parent directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Working directory set to: /local0/home/mfilo/git/CRN-GenerativeAI
# Target directory set to: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_HF_REINFORCE/logic_4inputs_1output_6species_8rxns/

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_ordered_index import AddReactionByOrderedIndex
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_hill_production_library
from RL4CRN.iocrns.reaction_library import construct_active_degradation_library

# Import Reward packages
from RL4CRN.rewards.deterministic import dynamic_tracking_error

# Import visualization packages
from RL4CRN.utils.visualizations import plot_truth_table

# %%
# Filename for loading the agent checkpoint
load_path = os.path.join(target_directory, 'models')
print('Loading models from:', load_path)

# locate all files corresponding to *.pth in the subdirectory of load path
input_paths = []
for file in os.listdir(load_path):
    if file.endswith('.pth') and not file.startswith('generated_'):
        input_paths.append(os.path.join(load_path, file))

save_flag = True                # Save the results of the obtained IOCRNs

# No logger needed
logger = None
# Out:
# Loading models from: /local0/home/mfilo/git/CRN-GenerativeAI/apps_results_HF_REINFORCE/logic_4inputs_1output_6species_8rxns/models

# %%
# Construct the template CRN
productions = []
dilutions = []
n_inputs = 4
species_labels = [f'X_{i+1}' for i in range(n_inputs)] 
for i,s in enumerate(species_labels):
    productions.append(MassAction(reactant_labels=[], product_labels=[s], input_channels=[f'u_{i+1}'], params=[1.], params_controllability=[True]))
    dilutions.append(MassAction(reactant_labels=[s], product_labels=[], input_channels=[None], params=[1.], params_controllability=[False]))
species_labels.append('X_5')
species_labels.append('OUT') # add output species label
dilutions.append(MassAction(reactant_labels=['X_5'], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True]))
dilutions.append(MassAction(reactant_labels=['OUT'], product_labels=[], input_channels=[None], params=[1.], params_controllability=[True]))
crn_template = IOCRN(productions + dilutions, output_labels=['OUT'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
crn_template.atol = 1e-6
crn_template.rtol = 1e-6
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
library = construct_hill_production_library(species_labels=species_labels, max_product_order=1, max_num_regulators=2)
library_active_degradation = construct_active_degradation_library(species_labels)
library.merge(library_active_degradation)
library.add_reactions(productions+dilutions) # add the production reactions to the library
zero_reaction = MassAction(reactant_labels=[], product_labels=[], input_channels=[None], params=[1.], params_controllability=[False]) # define the zero reaction (∅ → ∅)
library.add_reactions(zero_reaction) # add the zero reaction to the library
library.prepare_lookup_tables()
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Warning: no reaction IDs found, printing reactions in original order.
# Inputs: ['u_1', 'u_2', 'u_3', 'u_4']
# Species: ['OUT', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5']
# Output Species: ['OUT']
# ∅ ----> X_1;  [MAK(1.0, u_1)]
# ∅ ----> X_2;  [MAK(1.0, u_2)]
# ∅ ----> X_3;  [MAK(1.0, u_3)]
# ∅ ----> X_4;  [MAK(1.0, u_4)]
# X_1 ----> ∅;  [MAK(1.0)]
# X_2 ----> ∅;  [MAK(1.0)]
# X_3 ----> ∅;  [MAK(1.0)]
# X_4 ----> ∅;  [MAK(1.0)]
# X_5 ----> ∅;  [MAK(1.0)]
# OUT ----> ∅;  [MAK(1.0)]
# Library of possible reactions:
# Number of reactions: 473
# R0: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R1: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R2: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R3: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_4(None, 1))]
# R4: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_5(None, 1))]
# R5: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R6: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R7: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R8: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R9: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = )]
# R10: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = )]
# R11: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R12: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R13: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R14: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_4(None, 1))]
# R15: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_5(None, 1))]
# R16: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R17: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R18: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_4(None, 1))]
# R19: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_5(None, 1))]
# R20: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R21: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1), X_4(None, 1))]
# R22: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1), X_5(None, 1))]
# R23: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R24: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_4(None, 1), X_5(None, 1))]
# R25: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_4(None, 1))]
# R26: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_5(None, 1))]
# R27: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R28: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R29: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_4(None, 1))]
# R30: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_5(None, 1))]
# R31: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R32: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R33: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R34: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_4(None, 1))]
# R35: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_5(None, 1))]
# R36: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R37: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R38: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R39: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_4(None, 1))]
# R40: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_5(None, 1))]
# R41: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R42: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_1(None, 1))]
# R43: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_2(None, 1))]
# R44: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_3(None, 1))]
# R45: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_5(None, 1))]
# R46: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = OUT(None, 1))]
# R47: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_1(None, 1))]
# R48: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_2(None, 1))]
# R49: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_3(None, 1))]
# R50: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_4(None, 1))]
# R51: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = OUT(None, 1))]
# R52: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R53: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R54: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R55: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_4(None, 1))]
# R56: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_5(None, 1))]
# R57: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R58: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R59: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R60: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R61: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R62: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R63: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R64: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R65: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R66: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R67: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R68: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R69: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R70: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R71: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R72: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1))]
# R73: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1))]
# R74: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1))]
# R75: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_4(None, 1))]
# R76: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_5(None, 1))]
# R77: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1))]
# R78: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = )]
# R79: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = )]
# R80: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = )]
# R81: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = )]
# R82: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = )]
# R83: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = )]
# R84: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_2(None, 1))]
# R85: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_3(None, 1))]
# R86: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_4(None, 1))]
# R87: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1), X_5(None, 1))]
# R88: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_1(None, 1))]
# R89: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_3(None, 1))]
# R90: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_4(None, 1))]
# R91: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1), X_5(None, 1))]
# R92: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_2(None, 1))]
# R93: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1), X_4(None, 1))]
# R94: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1), X_5(None, 1))]
# R95: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_3(None, 1))]
# R96: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_4(None, 1), X_5(None, 1))]
# R97: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_4(None, 1))]
# R98: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = OUT(None, 1), X_5(None, 1))]
# R99: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_2(None, 1))]
# R100: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_3(None, 1))]
# R101: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_4(None, 1))]
# R102: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = X_5(None, 1))]
# R103: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1);    (Kr, nr) = OUT(None, 1))]
# R104: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_1(None, 1))]
# R105: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_3(None, 1))]
# R106: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_4(None, 1))]
# R107: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = X_5(None, 1))]
# R108: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1);    (Kr, nr) = OUT(None, 1))]
# R109: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_1(None, 1))]
# R110: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_2(None, 1))]
# R111: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_4(None, 1))]
#
∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = X_5(None, 1))]
# R401: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1);    (Kr, nr) = OUT(None, 1))]
# R402: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_1(None, 1))]
# R403: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_2(None, 1))]
# R404: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_3(None, 1))]
# R405: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = X_5(None, 1))]
# R406: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1);    (Kr, nr) = OUT(None, 1))]
# R407: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_1(None, 1))]
# R408: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_2(None, 1))]
# R409: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_3(None, 1))]
# R410: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = X_4(None, 1))]
# R411: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_5(None, 1);    (Kr, nr) = OUT(None, 1))]
# R412: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_1(None, 1))]
# R413: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_2(None, 1))]
# R414: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_3(None, 1))]
# R415: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_4(None, 1))]
# R416: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1);    (Kr, nr) = X_5(None, 1))]
# R417: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R418: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R419: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R420: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R421: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_1(None, 1);    (Kr, nr) = )]
# R422: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R423: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R424: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R425: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_2(None, 1);    (Kr, nr) = )]
# R426: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R427: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R428: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_3(None, 1);    (Kr, nr) = )]
# R429: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_4(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R430: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_4(None, 1);    (Kr, nr) = )]
# R431: ∅ ----> OUT;  [HILLProd(b = None, Vm = None,    (Ka, na) = OUT(None, 1), X_5(None, 1);    (Kr, nr) = )]
# R432: X_1 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R433: X_1 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R434: X_1 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R435: X_1 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R436: X_1 ----> ∅;  [ActiveDeg(E = ['OUT'],    a = None,    K = None)]
# R437: X_2 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R438: X_2 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R439: X_2 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R440: X_2 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R441: X_2 ----> ∅;  [ActiveDeg(E = ['OUT'],    a = None,    K = None)]
# R442: X_3 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R443: X_3 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R444: X_3 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R445: X_3 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R446: X_3 ----> ∅;  [ActiveDeg(E = ['OUT'],    a = None,    K = None)]
# R447: X_4 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R448: X_4 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R449: X_4 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R450: X_4 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R451: X_4 ----> ∅;  [ActiveDeg(E = ['OUT'],    a = None,    K = None)]
# R452: X_5 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R453: X_5 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R454: X_5 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R455: X_5 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R456: X_5 ----> ∅;  [ActiveDeg(E = ['OUT'],    a = None,    K = None)]
# R457: OUT ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R458: OUT ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R459: OUT ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R460: OUT ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R461: OUT ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R462: ∅ ----> X_1;  [MAK(1.0, u_1)]
# R463: ∅ ----> X_2;  [MAK(1.0, u_2)]
# R464: ∅ ----> X_3;  [MAK(1.0, u_3)]
# R465: ∅ ----> X_4;  [MAK(1.0, u_4)]
# R466: X_1 ----> ∅;  [MAK(1.0)]
# R467: X_2 ----> ∅;  [MAK(1.0)]
# R468: X_3 ----> ∅;  [MAK(1.0)]
# R469: X_4 ----> ∅;  [MAK(1.0)]
# R470: X_5 ----> ∅;  [MAK(1.0)]
# R471: OUT ----> ∅;  [MAK(1.0)]
# R472: ∅ ----> ∅;  [MAK(1.0)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
print(f'Number of CPUs available: {os.cpu_count()}')
# Out:
# Using device: cuda
# Number of CPUs available: 128

# %%
# Hyperparameters
max_added_reactions = 8                             # Maximum number of reactions
N_CPUs = os.cpu_count()                             # Number of CPUs          
N = 10*N_CPUs                                       # Number of samples (batch size)    
width = 1024                                        # Width of the neural networks  
depth = 5                                           # Depth of the neural networks 
deep_layer_size = 1024*10                           # Size of the deep layer encoding the CRNs
allow_input_influence = False                       # Allow input influence in the policy
learning_rate = 1e-3                                # Learning rate for the optimizer 
hall_of_fame_size = 30                              # Size of the hall of fame  
entropy_scheduler = {                                   # Entropy scheduler parameters 
    'entropy_weight': 1e-3 ,                            # Global entropy weight
    'entropy_weight_structure_head': 5.0,               # Entropy weight for the structure head
    'entropy_weight_continuous_head': 0.5,              # Entropy weight for the continuous parameters head
    'topk_entropy_weight': 1.0,                         # Entropy weight for the top-k actions
    'remainder_entropy_weight': 1.0,                    # Entropy weight for the remainder actions
    'entropy_update_coefficient': 1,                    # Entropy update coefficient (multiplicative)
    'entropy_schedule': 1000,                           # Entropy schedule (in epochs) 
    'minimum_entropy_weight': 0.0                       # Minimum entropy weight
}
structure_head_temperature = {
    'target_entropy_ratio_to_max': np.log(5)/np.log(M), 
    'initial_temperature': 1.0, 
    'rate': 0.0, 
    'current_temperature': 1.0}
risk_scheduler = {                                      # Risk scheduler parameters
    'risk': 0.9,                                        # Percentage of worst samples to disregard when computing the reward
    'risk_update': 0.0,                                 # Risk update coefficient (additive)
    'max_risk': 1.0,                                    # Maximum risk
    'risk_schedule': 1000                               # Risk schedule (in epochs)
}
epoch_num = 500                                         # Number of epochs for training
render_schedule = 10                                    # Render every # of epochs
render_mode = {                                         # Mode of the experiment
    'style': 'logger', 
    'task': 'transients + logic', 
    'format': 'image',
    'topology': True,
    'bounds': [2.5]
}
render_n_best = 10                                      # Number of best CRNs to plot responses for
render_disregard_percentage = 0.99                      # Percentage of worst CRNs to disregard in the responses plotting
sil_settings = {
    'sil_loss_weight': 1.0,
}

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_independent'}

# Stopping and zero reaction flags
stop_flag = False                                       # Whether to stop adding reactions when the “zero reaction” is selected (only relevant if zero_reaction_idx is provided)
allow_repeated_zero_reactions = True                    # Whether to allow repeated selection of the “zero reaction”

# Time horizon for the simulation
t_f = 100                                               # Final time for the simulation
N_t = 1000                                              # Number of time steps
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs: all combination of inputs between 0 and 1 
nums = [0., 1.]
u_list = [np.array(u) for u in product(*[nums for _ in range(n_inputs)])] # list of input combinations, each input is a numpy array of shape (p,)

# Define the logic function
logic_target = lambda u : (u[0] and u[1]) or (u[1] and u[2]) or (u[2] and u[3])  # target logic function

# Construct the reference setpoints
r_list = [np.array([float(logic_target(u))]) for u in u_list]  # list of reference outputs, each output is a numpy array of shape (q,)

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01 for _ in species_labels]])

# Construct the weights for the performance metric
# w = np.ones(N_t)
# w[(len(w)//5)*4:] = w[(len(w)//5)*4:]*2
# w[:(len(w)//5)] = w[:(len(w)//5)]*0.25
# w = w[np.newaxis, :]
w = np.zeros((1, N_t))
w[:, -1] = 1.0 * N_t

# Construct the compute reward routine
def compute_reward(state):
    x0_list = ic.get_ic(state)
    return dynamic_tracking_error(state, u_list, x0_list, time_horizon, r_list, w, norm=1, LARGE_NUMBER=1e4)

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
entropy_weights_per_head = {'structure': entropy_scheduler['entropy_weight_structure_head'], 'continuous': entropy_scheduler['entropy_weight_continuous_head'], 'discrete': 0.0, 'input_influence': 0.0} 
zero_reaction_idx = library.find_zero_reaction() if allow_repeated_zero_reactions else None 
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=allow_input_influence, masks=masks, zero_reaction_idx=zero_reaction_idx, stop_flag=stop_flag, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=allow_input_influence, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, sil_settings=sil_settings, device=device)

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library, allow_input_observation=allow_input_influence)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Test the model
from tqdm import tqdm
sorted_crns_rewards_list = []
for p in tqdm(input_paths):
    agent.policy.load_state_dict(torch.load(p, map_location=device))

    agent.policy.eval()
    mult_env.reset()
    for j in range(max_added_reactions):
        observations = mult_env.observe(observer, tensorizer)
        actions, raw_actions = agent.act(observations, actuator)
        out = mult_env.step(actions, stepper, raw_actions=raw_actions)
    rewards = mult_env.get_reward(compute_reward)

    # Gather the CRNs from the environments
    crns = mult_env.gather()

    # Sort the CRNs by rewards
    sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])
    sorted_crns_rewards_list.append(sorted_crns_rewards)
# Out:
# 100%|██████████| 1/1 [01:34<00:00, 94.05s/it]

# %%
# Plot the results
for  j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
    n_plot = 100
    ax = None
    for i in range(n_plot):
        x0_list = ic.get_ic(sorted_crns_rewards[i][0])
        time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
        fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
        model_name = os.path.basename(input_paths[j]).replace('.pth','')
        ax[0].set_title(f'Top IOCRNs from model {model_name} - Setpoint tracking responses')
        # print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
        # print(sorted_crns_rewards[i][0])

# %%
if save_flag:
    for j, sorted_crns_rewards in enumerate(sorted_crns_rewards_list):
        load_filename = os.path.basename(input_paths[j]).replace('.pth','')
        output_path = os.path.join(target_directory, 'models', 'generated_' + load_filename + '.pth')
        print('Saving generated CRNs to file:','generated_' + output_path + '.pth')
        sorted_crns = [crn for crn, _ in sorted_crns_rewards]
        torch.save(sorted_crns, output_path)
# Out:
# Saving generated CRNs to file: generated_/local0/home/mfilo/git/CRN-GenerativeAI/apps_results_HF_REINFORCE/logic_4inputs_1output_6species_8rxns/models/generated_2026-02-16 12:47:28.pth.pth
