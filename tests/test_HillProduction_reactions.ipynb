# %%
# Set up the file path
import os
os.chdir('..')

# %%
# Import packages
from RL4CRN.iocrns.reactions import HillProduction

# %%
# Construct library from a list of reactions
rxn_0 = HillProduction(product_labels=['X_1'], activator_labels=['X_4', 'X_3'], repressor_labels=['X_2', 'X_1'], 
                       input_channels=[None, None, 'u_3', None, 'u_4', None, 'u_2', None, 'u_1', None], 
                       params=[0.1, 1.0, 10.0, 2, 5.0, 2, 3.0, 1, 7.0, 1], 
                       params_controllability=[False, True, True, False, True, False, True, False, True, False])
rxn_1 = HillProduction(product_labels=['X_2'], activator_labels=[], repressor_labels=['X_1'], 
                       input_channels=[None, None, None, None], 
                       params=[0.2, 2.0, 20.0, 3], 
                       params_controllability=[False, True, True, False])
rxn_2 = HillProduction(product_labels=['X_3'], activator_labels=['X_5'], repressor_labels=[], 
                       input_channels=[None, 'u_3', 'u_5', None], 
                       params=[0.25, 2.5, 30.0, 4], 
                       params_controllability=[False, True, True, False])

# %%
print(rxn_0.signature)
print(rxn_1.signature)
print(rxn_2.signature)
# Out:
# ('HILLProd', ['X_1'], ['X_3', 'X_4'], ['X_1', 'X_2'])
# ('HILLProd', ['X_2'], [], ['X_1'])
# ('HILLProd', ['X_3'], ['X_5'], [])

# %%
print('Reaction 0 parameters:', rxn_0.params)
print('Basal rate:', rxn_0.basal_rate)
print('Maximal rate:', rxn_0.maximal_rate)
print('Activator dissociation constants:', rxn_0.activator_dissociation_constants)
print('Activator Hill coefficients:', rxn_0.activator_hill_coefficients)
print('Repressor dissociation constants:', rxn_0.repressor_dissociation_constants)
print('Repressor Hill coefficients:', rxn_0.repressor_hill_coefficients)
print('----------------------------------')
print('Reaction 1 parameters:', rxn_1.params)
print('Basal rate:', rxn_1.basal_rate)
print('Maximal rate:', rxn_1.maximal_rate)
print('Activator dissociation constants:', rxn_1.activator_dissociation_constants)
print('Activator Hill coefficients:', rxn_1.activator_hill_coefficients)
print('Repressor dissociation constants:', rxn_1.repressor_dissociation_constants)
print('Repressor Hill coefficients:', rxn_1.repressor_hill_coefficients)
print('----------------------------------')
print('Reaction 2 parameters:', rxn_2.params)
print('Basal rate:', rxn_2.basal_rate)
print('Maximal rate:', rxn_2.maximal_rate)
print('Activator dissociation constants:', rxn_2.activator_dissociation_constants)
print('Activator Hill coefficients:', rxn_2.activator_hill_coefficients)
print('Repressor dissociation constants:', rxn_2.repressor_dissociation_constants)
print('Repressor Hill coefficients:', rxn_2.repressor_hill_coefficients)
# Out:
# Reaction 0 parameters: [0.1, 1.0, 5.0, 2, 10.0, 2, 7.0, 1, 3.0, 1]
# Basal rate: 0.1
# Maximal rate: 1.0
# Activator dissociation constants: [5.0, 2]
# Activator Hill coefficients: [10.0, 2]
# Repressor dissociation constants: [7.0, 1]
# Repressor Hill coefficients: [3.0, 1]
# ----------------------------------
# Reaction 1 parameters: [0.2, 2.0, 20.0, 3]
# Basal rate: 0.2
# Maximal rate: 2.0
# Activator dissociation constants: []
# Activator Hill coefficients: []
# Repressor dissociation constants: [20.0]
# Repressor Hill coefficients: [3]
# ----------------------------------
# Reaction 2 parameters: [0.25, 2.5, 30.0, 4]
# Basal rate: 0.25
# Maximal rate: 2.5
# Activator dissociation constants: [30.0]
# Activator Hill coefficients: [4]
# Repressor dissociation constants: []
# Repressor Hill coefficients: []
