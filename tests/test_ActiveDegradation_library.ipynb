# %%
# Set up the file path
import os
os.chdir('..')

# %%
# Import packages
from RL4CRN.iocrns.reaction_library import construct_active_degradation_library

# %%
species_labels = ['X_1', 'X_2', 'X_3', 'X_4', 'X_5']
library = construct_active_degradation_library(species_labels)
print(library)
# Out:
# Number of reactions: 20
# R0: X_1 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R1: X_1 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R2: X_1 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R3: X_1 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R4: X_2 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R5: X_2 ----> ∅;  [ActiveDeg(E = ['X_3'],    a = None,    K = None)]
# R6: X_2 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R7: X_2 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R8: X_3 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# R9: X_3 ----> ∅;  [ActiveDeg(E = ['X_2'],    a = None,    K = None)]
# R10: X_3 ----> ∅;  [ActiveDeg(E = ['X_4'],    a = None,    K = None)]
# R11: X_3 ----> ∅;  [ActiveDeg(E = ['X_5'],    a = None,    K = None)]
# R12: X_4 ----> ∅;  [ActiveDeg(E = ['X_1'],    a = None,    K = None)]
# ...
