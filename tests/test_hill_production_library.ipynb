# %%
# Set up the file path
import os
os.chdir('..')

# %%
# Import packages
from RL4CRN.iocrns.reaction_library import construct_hill_production_library

# %%
species_labels = ['X_1', 'X_2', 'X_3']
n = len(species_labels)
P = 1
R = 2
library = construct_hill_production_library(species_labels, max_product_order=P, max_num_regulators=R)
print(library)
# Out:
# Number of reactions: 54
# R0: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0))]
# R1: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0))]
# R2: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1.0))]
# R3: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = )]
# R4: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = )]
# R5: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = )]
# R6: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_2(None, 1.0))]
# R7: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_3(None, 1.0))]
# R8: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0), X_3(None, 1.0))]
# R9: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R10: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R11: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R12: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R13: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R14: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R15: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_2(None, 1.0);    (Kr, nr) = )]
# R16: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
# R17: ∅ ----> X_1;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
# R18: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0))]
# R19: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0))]
# R20: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1.0))]
# R21: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = )]
# R22: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = )]
# R23: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = )]
# R24: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_2(None, 1.0))]
# R25: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_3(None, 1.0))]
# R26: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0), X_3(None, 1.0))]
# R27: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R28: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R29: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R30: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R31: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R32: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R33: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_2(None, 1.0);    (Kr, nr) = )]
# R34: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
# R35: ∅ ----> X_2;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
# R36: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0))]
# R37: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0))]
# R38: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_3(None, 1.0))]
# R39: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = )]
# R40: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = )]
# R41: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = )]
# R42: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_2(None, 1.0))]
# R43: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_1(None, 1.0), X_3(None, 1.0))]
# R44: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = ;    (Kr, nr) = X_2(None, 1.0), X_3(None, 1.0))]
# R45: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R46: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R47: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R48: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0);    (Kr, nr) = X_3(None, 1.0))]
# R49: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_1(None, 1.0))]
# R50: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_3(None, 1.0);    (Kr, nr) = X_2(None, 1.0))]
# R51: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_2(None, 1.0);    (Kr, nr) = )]
# R52: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_1(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
# R53: ∅ ----> X_3;  [HILLProd(b = None, Vm = None,    (Ka, na) = X_2(None, 1.0), X_3(None, 1.0);    (Kr, nr) = )]
