# %%
# Set up the file path
import os
os.chdir('..')

# %%
# Import packages
from RL4CRN.utils.utils import cartesian_prod

# %%
v1 = [1, 2, 3, 4, 5]
v2 = [10, 20]
v3 = [100, 200, 300]
grid = cartesian_prod([v1, v2, v3])
print(grid.shape)
print(grid)
# Out:
# (30, 3)
# [[  1  10 100]
#  [  1  10 200]
#  [  1  10 300]
#  [  1  20 100]
#  [  1  20 200]
#  [  1  20 300]
#  [  2  10 100]
#  [  2  10 200]
#  [  2  10 300]
#  [  2  20 100]
#  [  2  20 200]
#  [  2  20 300]
#  [  3  10 100]
#  [  3  10 200]
#  [  3  10 300]
#  [  3  20 100]
#  [  3  20 200]
#  [  3  20 300]
#  [  4  10 100]
#  [  4  10 200]
#  [  4  10 300]
#  [  4  20 100]
#  [  4  20 200]
#  [  4  20 300]
#  [  5  10 100]
#  [  5  10 200]
#  [  5  10 300]
#  [  5  20 100]
#  [  5  20 200]
#  [  5  20 300]]
