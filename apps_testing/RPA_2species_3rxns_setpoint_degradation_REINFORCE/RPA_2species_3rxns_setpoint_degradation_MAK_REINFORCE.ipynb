# %%
# Set up the file path
import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(parent_dir)

# %%
# Import general packages
from openpyxl import Workbook, load_workbook
from datetime import datetime
import torch
from matplotlib import pyplot as plt
from pytorch_lightning.loggers import CometLogger
import numpy as np
from itertools import product
from tqdm import tqdm

# Import Agent-Environment packages
from RL4CRN.environments.environment import Environment
from RL4CRN.environments.parallel_environments import ParallelEnvironments
from RL4CRN.environments.serial_environments import SerialEnvironments
from RL4CRN.agents.reinforce_agent import REINFORCEAgent
from RL4CRN.policies.add_reaction_by_index import AddReactionByIndex

# Import Interface packages
from RL4CRN.env2agent_interface.explicit_observer import ExplicitObserver
from RL4CRN.env2agent_interface.explicit_tensorizer import ExplicitTensorizer
from RL4CRN.agent2env_interface.library_actuator import LibraryActuator
from RL4CRN.agent2env_interface.iocrn_stepper import IOCRNStepper

# Import CRN packages
from RL4CRN.iocrns.iocrn import IOCRN
from RL4CRN.iocrns.reactions import MassAction
from RL4CRN.utils.ic import IC
from RL4CRN.iocrns.reaction_library import construct_mass_action_library

# Import Reward packages
from RL4CRN.rewards.deterministic import dynamic_tracking_error

# %%
# Set the logger to use Comet
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
api_key = "o77J6VCMDamustkfJuMXZ2jdV"
logger = CometLogger(
    api_key=api_key,
    project="RPA_2species_3rxns_setpoint_degradation_MAK_REINFORCE",        
    workspace="maurice-filo", 
    name=f'RPA_2species_3rxns_setpoint_degradation_MAK_REINFORCE_{timestamp}',
)
logger = logger.experiment
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: sklearn, torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/maurice-filo/rpa-2species-3rxns-setpoint-degradation-mak-reinforce/a3c24eb6c7e44b9eb1c83a2b4e089287

# %%
# Construct the template CRN
r1 = MassAction(reactant_labels=['Z'], product_labels=[], input_channels=['u_1'], params=[1.], params_controllability=[True])
r2 = MassAction(reactant_labels=['X'], product_labels=[], input_channels=['u_2'], params=[1.], params_controllability=[True])
crn_template = IOCRN([r1, r2], output_labels=['X'])
crn_template.compile()
p = crn_template.num_inputs # Number of inputs of the IOCRNs
print("Template CRN:")
print(crn_template)

# Construct the library of possible reactions
species_labels = ['X', 'Z']
library = construct_mass_action_library(species_labels=species_labels, order=2)
crn_template.set_library_context(library)
M = len(library.reactions) # Number of possible reactions
K = library.get_num_parameters() # Total number of parameters in all the reactions of the library
print("Library of possible reactions:")
print(library)
print("------------------------------------------------")
# Out:
# Template CRN:
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# Library of possible reactions:
# Number of reactions: 31
# R0: ∅ ----> ∅;  [MAK(None)]
# R1: ∅ ----> X;  [MAK(None)]
# R2: ∅ ----> Z;  [MAK(None)]
# R3: ∅ ----> X + X;  [MAK(None)]
# R4: ∅ ----> X + Z;  [MAK(None)]
# R5: ∅ ----> Z + Z;  [MAK(None)]
# R6: X ----> ∅;  [MAK(None)]
# R7: X ----> Z;  [MAK(None)]
# R8: X ----> X + X;  [MAK(None)]
# R9: X ----> X + Z;  [MAK(None)]
# R10: X ----> Z + Z;  [MAK(None)]
# R11: Z ----> ∅;  [MAK(None)]
# R12: Z ----> X;  [MAK(None)]
# R13: Z ----> X + X;  [MAK(None)]
# R14: Z ----> X + Z;  [MAK(None)]
# R15: Z ----> Z + Z;  [MAK(None)]
# R16: X + X ----> ∅;  [MAK(None)]
# R17: X + X ----> X;  [MAK(None)]
# R18: X + X ----> Z;  [MAK(None)]
# R19: X + X ----> X + Z;  [MAK(None)]
# R20: X + X ----> Z + Z;  [MAK(None)]
# R21: X + Z ----> ∅;  [MAK(None)]
# R22: X + Z ----> X;  [MAK(None)]
# R23: X + Z ----> Z;  [MAK(None)]
# R24: X + Z ----> X + X;  [MAK(None)]
# R25: X + Z ----> Z + Z;  [MAK(None)]
# R26: Z + Z ----> ∅;  [MAK(None)]
# R27: Z + Z ----> X;  [MAK(None)]
# R28: Z + Z ----> Z;  [MAK(None)]
# R29: Z + Z ----> X + X;  [MAK(None)]
# R30: Z + Z ----> X + Z;  [MAK(None)]
# ------------------------------------------------

# %%
# Device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Flags and filenames
save_flag = True                                                # Save the agent checkpoint
load_flag = False                                               # Load the agent checkpoint 
train_flag = True                                               # Train the agent
save_sheet_flag = True                                          # Save the configuration to an Excel sheet

save_filename = timestamp + '.pth'                              # Filename for saving the agent checkpoint
load_filename = ''                                              # Filename for loading the agent checkpoint
file_name = "RPA_2species_3rxns_setpoint_degradation_MAK_REINFORCE.xlsx"             # Filename for saving the Excel sheet

# %%
# Hyperparameters
max_added_reactions = 3                             # Maximum number of reactions
N_CPUs = os.cpu_count()                             # Number of CPUs          
N = 10*N_CPUs                                       # Number of samples (batch size)    
width = 1024                                        # Width of the neural networks  
depth = 5                                           # Depth of the neural networks 
deep_layer_size = 1024*10                           # Size of the deep layer encoding the CRNs
allow_input_influence = False                       # Allow input influence in the policy
learning_rate = 1e-4                                # Learning rate for the optimizer 
hall_of_fame_size = 1                               # Size of the hall of fame  
entropy_scheduler = {                               # Entropy scheduler parameters 
    'entropy_weight': 0.005, 
    'entropy_update_coefficient': 1, 
    'entropy_schedule': 1000, 
    'minimum_entropy_weight': 0.005
}
entropy_weights_per_head = {'structure': 1., 'continuous': 1., 'discrete': 0.0, 'input_influence': 0.0} 
risk_scheduler = {                                  # Risk scheduler parameters
    'risk': 0.9, 
    'risk_update': 0.0, 
    'max_risk': 1.0, 
    'risk_schedule': 1000
}
epoch_num = 200                                     # Number of epochs for training
render_schedule = 1                                 # Render every # of epochs
mode = {                                            # Mode of the experiment
    'style': 'logger', 
    'task': 'transients', 
    'format': 'image',
    'topology': True,
    'bounds': [2.5]
}

# Parameter distribution for the reactions added by the agent
continuous_distribution = {"type": 'lognormal_1D'}

# Time horizon for the simulation
t_f = 200                                           # Final time for the simulation
N_t = 1000                                          # Number of time steps
time_horizon = np.linspace(0, t_f, N_t, dtype=np.float32)

# Construct the IOCRN inputs
nums = [0.5, 1.0, 1.5]
u_list = [np.array(u) for u in product(nums, repeat=p)] # list of input combinations, each input is a numpy array of shape (p,)

# Construct the IOCRN initial conditions
ic = IC(names=species_labels, values=[[0.01, 0.01, 0.01]])

# Construct the weights for the performance metric
w = np.ones(N_t)
w[(len(w)//5)*4:] = w[(len(w)//5)*4:]*2
w[:(len(w)//5)] = w[:(len(w)//5)]*0.25
w = w[np.newaxis, :]

# Construct the compute reward routine
def compute_reward(state):
    r_list = [np.array([u[0]]) for u in u_list]
    x0_list = ic.get_ic(state)
    return dynamic_tracking_error(state, u_list, x0_list, time_horizon, r_list, w, norm=1, LARGE_NUMBER=1e4)

# %%
# Save the experiment discription in an Excel sheet
if save_sheet_flag:
    sheet_name = "Data"
    headers = ["Timestamp", "URL", 
               "Maximum Number of Added Reactions", 
               "Number of Species", 
               "Number of Inputs", 
               "Batch Size", 
               "Allow Input Influence", 
               "Learning Rate", "Number of Epochs", "Neural Network Depth", "Neural Network Width", "Deep Layer Size", "Number of CPUs",
               "Entropy Scheduler", 
               "Risk Scheduler",
               "Render Schedule", "Hall of Fame Size", 
               "Simulation Time", "Number of Time Steps", "Initial Condition Scenarios", "Input Scenarios",
               "Continuous Distribution"]
    data_row = [timestamp, logger.url, 
                max_added_reactions, 
                len(species_labels), 
                p, N,
                allow_input_influence, 
                learning_rate, epoch_num, depth, width, deep_layer_size, N_CPUs, 
                str(entropy_scheduler),
                str(risk_scheduler),
                render_schedule, hall_of_fame_size,
                t_f, N_t, len(ic.values), len(u_list),
                str(continuous_distribution)]

    if os.path.exists(file_name):
        wb = load_workbook(file_name)
        if sheet_name in wb.sheetnames:
            ws = wb[sheet_name]
        else:
            ws = wb.create_sheet(sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    if ws.max_column < 2:
        for i, header in enumerate(headers, start=1):
            ws.cell(row=i, column=1, value=header)
    next_col = ws.max_column + 1
    for i, value in enumerate(data_row, start=1):
        ws.cell(row=i, column=next_col, value=value)

    wb.save(file_name)
    print(f"New experiment data saved in column {next_col} of '{file_name}'.")
# Out:
# New experiment data saved in column 2 of 'RPA_2species_3rxns_setpoint_degradation_MAK_REINFORCE.xlsx'.

# %%
# Construct parallel environments
crn_0 = crn_template.clone()
mult_env = ParallelEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, N_CPUs=N_CPUs, logger=logger)
# mult_env = SerialEnvironments([Environment(crn_0, max_added_reactions, logger=logger, logger_schedule=1) for _ in range(N)], hall_of_fame_size=hall_of_fame_size, logger=logger)

# %%
# Construct the policy
encoder_attributes = {"hidden_size": width, "num_layers": depth}
structure_head_attributes = {"hidden_size": width, "num_layers": depth}
rate_head_attributes = {"hidden_size": width, "num_layers": depth}
input_influence_head_attributes = {"hidden_size": width, "num_layers": depth}
masks = {"continuous": library.get_parameter_mask(mode="continuous"), "discrete": library.get_parameter_mask(mode="discrete"), "logit": library.get_logit_mask()}
policy = AddReactionByIndex(M, K, p, encoder_attributes, deep_layer_size, structure_head_attributes, rate_head_attributes, input_influence_head_attributes, allow_input_influence=False, masks=masks, device=device, continuous_distribution=continuous_distribution, entropy_weights_per_head=entropy_weights_per_head)

# Construct the agent
agent = REINFORCEAgent(policy, allow_input_influence=False, logger=logger, learning_rate=learning_rate, entropy_scheduler=entropy_scheduler, risk_scheduler=risk_scheduler, device=device)
if load_flag:
    agent.policy.load_state_dict(torch.load(load_filename+'.pth', map_location=device))

# %%
# Construct the interfaces
observer = ExplicitObserver(reaction_library=library)
tensorizer = ExplicitTensorizer(device=device)
actuator = LibraryActuator(reaction_library=library)
stepper = IOCRNStepper()

# %%
# Training Loop   
if train_flag:
    for i in tqdm(range(epoch_num)):
        mult_env.reset()
        for j in range(max_added_reactions):
            observations = mult_env.observe(observer, tensorizer)
            actions = agent.act(observations, actuator)
            out = mult_env.step(actions, stepper)
        rewards = mult_env.get_reward(compute_reward)
        agent.update(rewards, step_iteration=i)
        if i % render_schedule == 0:
            mult_env.render(rewards, n_best=10, disregarded_percentage=0.9, mode=mode)
# Out:
# 100%|██████████| 200/200 [25:32<00:00,  7.66s/it]

# %%
# Test the model
mult_env.reset()
for j in range(max_added_reactions):
    observations = mult_env.observe(observer, tensorizer)
    actions = agent.act(observations, actuator)
    out = mult_env.step(actions, stepper)
rewards = mult_env.get_reward(compute_reward)

# Gather the CRNs from the environments
crns = mult_env.gather()

# Sort the CRNs by rewards
sorted_crns_rewards = sorted(zip(crns, rewards), key=lambda x: x[1])

# %%
# Plot the results
n_plot = 100
ax = None
for i in range(n_plot):
    x0_list = ic.get_ic(sorted_crns_rewards[i][0])
    time_horizon, x_list, y_list, last_task_info = sorted_crns_rewards[i][0].transient_response(u_list, x0_list, time_horizon)
    fig, ax = sorted_crns_rewards[i][0].plot_transient_response(axes=ax)
    print(f"IOCRN {i}, Reward: {sorted_crns_rewards[i][1]}")
    print(sorted_crns_rewards[i][0])
# Out:
# IOCRN 0, Reward: 0.011536788514043585
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.144236445426941)]
# X ----> X + X;  [MAK(0.964743971824646)]
# X + Z ----> Z + Z;  [MAK(1.002556562423706)]
# IOCRN 1, Reward: 0.012962893996012198
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X ----> X + X;  [MAK(1.5701642036437988)]
# ∅ ----> X + X;  [MAK(1.134634256362915)]
# X + Z ----> Z + Z;  [MAK(1.002829670906067)]
# IOCRN 2, Reward: 0.016015075383861068
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0072468519210815)]
# ∅ ----> X + X;  [MAK(2.9086177349090576)]
# ∅ ----> X;  [MAK(1.2826738357543945)]
# IOCRN 3, Reward: 0.016492927624463225
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.992304801940918)]
# X ----> X + X;  [MAK(0.6670472025871277)]
# ∅ ----> X + X;  [MAK(1.251713752746582)]
# IOCRN 4, Reward: 0.017202066020861866
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9932435154914856)]
# X ----> X + X;  [MAK(1.6239196062088013)]
# ∅ ----> X;  [MAK(2.625066041946411)]
# IOCRN 5, Reward: 0.017420406978267487
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8464159965515137)]
# X + Z ----> Z + Z;  [MAK(0.9929649233818054)]
# X ----> X + X;  [MAK(1.3759831190109253)]
# IOCRN 6, Reward: 0.01841653685293329
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0084121227264404)]
# ∅ ----> X + X;  [MAK(8.224724769592285)]
# X ----> X + X;  [MAK(0.829475998878479)]
# IOCRN 7, Reward: 0.019376684463421473
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9893112778663635)]
# ∅ ----> X + X;  [MAK(1.6424728631973267)]
# ∅ ----> X;  [MAK(0.8839120268821716)]
# IOCRN 8, Reward: 0.01996687549790933
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0106723308563232)]
# ∅ ----> X + X;  [MAK(4.844127178192139)]
# ∅ ----> X;  [MAK(1.0132335424423218)]
# IOCRN 9, Reward: 0.02032101139693558
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7111098766326904)]
# X + Z ----> Z + Z;  [MAK(0.9878090620040894)]
# ∅ ----> X;  [MAK(1.1984837055206299)]
# IOCRN 10, Reward: 0.020379528267183953
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0177890062332153)]
# X + Z ----> Z + Z;  [MAK(1.005869746208191)]
# X ----> X + X;  [MAK(15.009298324584961)]
# IOCRN 11, Reward: 0.020443397825058975
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8862290978431702)]
# X + Z ----> Z + Z;  [MAK(0.9881922602653503)]
# X ----> X + X;  [MAK(0.5280167460441589)]
# IOCRN 12, Reward: 0.020464806800751217
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9894008040428162)]
# ∅ ----> X + X;  [MAK(5.0013322830200195)]
# ∅ ----> X;  [MAK(0.9946754574775696)]
# IOCRN 13, Reward: 0.02047577714293463
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.227247953414917)]
# X + Z ----> Z + Z;  [MAK(0.9939100742340088)]
# X ----> X + X;  [MAK(9.0031099319458)]
# IOCRN 14, Reward: 0.022463668486881236
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.09709894657135)]
# X + Z ----> Z + Z;  [MAK(1.014400601387024)]
# ∅ ----> X;  [MAK(1.7457433938980103)]
# IOCRN 15, Reward: 0.022845903313081253
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8189664483070374)]
# X + Z ----> Z + Z;  [MAK(0.9857805371284485)]
# ∅ ----> X;  [MAK(1.5998337268829346)]
# IOCRN 16, Reward: 0.025874849841048497
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0693634748458862)]
# X + Z ----> Z + Z;  [MAK(1.0135583877563477)]
# X ----> X + X;  [MAK(3.3183627128601074)]
# IOCRN 17, Reward: 0.026257643063010885
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.410672664642334)]
# X + Z ----> Z;  [MAK(0.9591602683067322)]
# X + Z ----> Z + Z;  [MAK(0.9816439747810364)]
# IOCRN 18, Reward: 0.02731750648590089
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.1596297025680542)]
# X + Z ----> Z + Z;  [MAK(1.0153363943099976)]
# X ----> X + X;  [MAK(2.9618217945098877)]
# IOCRN 19, Reward: 0.02804761671670218
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.318416953086853)]
# X + Z ----> Z + Z;  [MAK(0.9809481501579285)]
# ∅ ----> X;  [MAK(0.4597199559211731)]
# IOCRN 20, Reward: 0.029144051088031964
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9817225337028503)]
# ∅ ----> X + X;  [MAK(5.276721477508545)]
# X ----> X + X;  [MAK(0.900263786315918)]
# IOCRN 21, Reward: 0.03042049602130453
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.1310263872146606)]
# X + Z ----> Z + Z;  [MAK(0.9827147126197815)]
# X ----> X + X;  [MAK(8.622812271118164)]
# IOCRN 22, Reward: 0.030649970711466235
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X ----> X + X;  [MAK(0.7597157955169678)]
# ∅ ----> X + X;  [MAK(1.063367486000061)]
# X + Z ----> Z + Z;  [MAK(0.9793238043785095)]
# IOCRN 23, Reward: 0.031089389162690818
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.2671257257461548)]
# X + Z ----> Z + Z;  [MAK(0.9784663915634155)]
# ∅ ----> X;  [MAK(1.3215174674987793)]
# IOCRN 24, Reward: 0.033885740614609805
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0200896263122559)]
# ∅ ----> X + X;  [MAK(0.9576315879821777)]
# X ----> X + X;  [MAK(5.1244635581970215)]
# IOCRN 25, Reward: 0.03401953934743702
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.976791262626648)]
# ∅ ----> X + X;  [MAK(3.923736333847046)]
# ∅ ----> X;  [MAK(1.2977473735809326)]
# IOCRN 26, Reward: 0.0350911338901097
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.4185653030872345)]
# ∅ ----> X;  [MAK(1.4460453987121582)]
# X + Z ----> Z + Z;  [MAK(0.9713310599327087)]
# IOCRN 27, Reward: 0.035357260712199155
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.9382451772689819)]
# X + Z ----> Z + Z;  [MAK(1.0267248153686523)]
# ∅ ----> X;  [MAK(4.869624614715576)]
# IOCRN 28, Reward: 0.035627013161602335
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0264968872070312)]
# ∅ ----> X + X;  [MAK(4.567502975463867)]
# ∅ ----> X;  [MAK(0.9700878858566284)]
# IOCRN 29, Reward: 0.03596268931483004
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0267692804336548)]
# X + Z ----> Z + Z;  [MAK(0.9741248488426208)]
# ∅ ----> X;  [MAK(2.0142581462860107)]
# IOCRN 30, Reward: 0.0359942848460356
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.6309064626693726)]
# X + Z ----> Z + Z;  [MAK(0.9743872880935669)]
# ∅ ----> X;  [MAK(1.978730320930481)]
# IOCRN 31, Reward: 0.03699669827777059
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.9327724575996399)]
# X + Z ----> Z + Z;  [MAK(0.9991714954376221)]
# ∅ ----> ∅;  [MAK(0.997497022151947)]
# IOCRN 32, Reward: 0.03747573089750612
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.2921156883239746)]
# X + Z ----> Z + Z;  [MAK(0.9724183082580566)]
# ∅ ----> X;  [MAK(0.5158690810203552)]
# IOCRN 33, Reward: 0.0382862029191575
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.1365735530853271)]
# X ----> X + X;  [MAK(0.929577112197876)]
# X + Z ----> Z + Z;  [MAK(0.9727408289909363)]
# IOCRN 34, Reward: 0.04327155646188006
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.9712664484977722)]
# X + Z ----> Z + Z;  [MAK(0.9691213965415955)]
# ∅ ----> X;  [MAK(13.60046672821045)]
# IOCRN 35, Reward: 0.04359053809127732
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8422396779060364)]
# X + Z ----> Z + Z;  [MAK(1.0367684364318848)]
# ∅ ----> X;  [MAK(1.0868582725524902)]
# IOCRN 36, Reward: 0.04439180591565852
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.3267147541046143)]
# X + Z ----> Z + Z;  [MAK(0.9669997692108154)]
# ∅ ----> X;  [MAK(3.098785638809204)]
# IOCRN 37, Reward: 0.04472220807545903
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7633704543113708)]
# X + Z ----> Z + Z;  [MAK(1.0333445072174072)]
# X ----> X + X;  [MAK(2.211089849472046)]
# IOCRN 38, Reward: 0.04538538848790464
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.036755919456482)]
# ∅ ----> X + X;  [MAK(3.012967109680176)]
# ∅ ----> X;  [MAK(2.6921498775482178)]
# IOCRN 39, Reward: 0.0464607453847197
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.5849143266677856)]
# X + Z ----> Z + Z;  [MAK(0.9646391868591309)]
# ∅ ----> X;  [MAK(0.46148890256881714)]
# IOCRN 40, Reward: 0.04702587148421258
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0382505655288696)]
# ∅ ----> X + X;  [MAK(4.621185779571533)]
# ∅ ----> X;  [MAK(0.9969987869262695)]
# IOCRN 41, Reward: 0.04717829808832528
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.4145474433898926)]
# X + Z ----> Z + Z;  [MAK(0.9669166803359985)]
# X ----> X + X;  [MAK(2.537609577178955)]
# IOCRN 42, Reward: 0.047443025128254004
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7133721113204956)]
# ∅ ----> X;  [MAK(1.2249354124069214)]
# X + Z ----> Z + Z;  [MAK(0.9633241891860962)]
# IOCRN 43, Reward: 0.04749590095511809
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9644481539726257)]
# ∅ ----> X + X;  [MAK(1.883239507675171)]
# ∅ ----> X;  [MAK(3.013709545135498)]
# IOCRN 44, Reward: 0.04829244727207606
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.3263405561447144)]
# X + Z ----> Z + Z;  [MAK(0.9635118842124939)]
# ∅ ----> X;  [MAK(2.8744566440582275)]
# IOCRN 45, Reward: 0.04902141257482895
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.3157501220703125)]
# X ----> X + X;  [MAK(1.0018916130065918)]
# X + Z ----> Z + Z;  [MAK(0.9633787870407104)]
# IOCRN 46, Reward: 0.049781736296923305
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.4561666250228882)]
# X + Z ----> Z + Z;  [MAK(0.9621803760528564)]
# ∅ ----> X;  [MAK(2.4928252696990967)]
# IOCRN 47, Reward: 0.05018054840473635
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7654407620429993)]
# X ----> X + X;  [MAK(1.0190513134002686)]
# X + Z ----> Z + Z;  [MAK(1.0416347980499268)]
# IOCRN 48, Reward: 0.051003306415620085
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.632655143737793)]
# X + Z ----> Z + Z;  [MAK(1.0423465967178345)]
# ∅ ----> X + X;  [MAK(3.5957677364349365)]
# IOCRN 49, Reward: 0.051111124573764745
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0495904684066772)]
# X + Z ----> Z + Z;  [MAK(1.0446748733520508)]
# ∅ ----> X;  [MAK(0.7101526260375977)]
# IOCRN 50, Reward: 0.05129026486407849
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(2.0955216884613037)]
# X + Z ----> Z + Z;  [MAK(0.9609942436218262)]
# ∅ ----> X;  [MAK(1.8844197988510132)]
# IOCRN 51, Reward: 0.05129445141033703
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.27890992164611816)]
# ∅ ----> X;  [MAK(1.3056691884994507)]
# X + Z ----> Z + Z;  [MAK(0.9833197593688965)]
# IOCRN 52, Reward: 0.05236587512399855
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.3664759397506714)]
# X ----> X + X;  [MAK(1.2238116264343262)]
# X + Z ----> Z + Z;  [MAK(1.0424840450286865)]
# IOCRN 53, Reward: 0.05282662370704778
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(4.22001314163208)]
# X + Z ----> Z + Z;  [MAK(1.0447278022766113)]
# ∅ ----> X + X;  [MAK(1.717793583869934)]
# IOCRN 54, Reward: 0.05303039710918888
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(7.339030742645264)]
# X + Z ----> Z + Z;  [MAK(0.8223316073417664)]
# X ----> Z + Z;  [MAK(0.8463903069496155)]
# IOCRN 55, Reward: 0.05521232514051935
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8911091685295105)]
# X + Z ----> Z + Z;  [MAK(1.048719882965088)]
# ∅ ----> X;  [MAK(1.3905236721038818)]
# IOCRN 56, Reward: 0.055249908970602515
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.931873083114624)]
# X ----> X + X;  [MAK(0.9416471123695374)]
# X + Z ----> Z + Z;  [MAK(1.0472224950790405)]
# IOCRN 57, Reward: 0.05772660042884933
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0285148620605469)]
# X + Z ----> Z + Z;  [MAK(0.95534747838974)]
# ∅ ----> X;  [MAK(3.752453327178955)]
# IOCRN 58, Reward: 0.05833591334494483
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(0.9549410343170166)]
# ∅ ----> X + X;  [MAK(1.43648099899292)]
# ∅ ----> X;  [MAK(3.5712122917175293)]
# IOCRN 59, Reward: 0.0585343544488243
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.7153477668762207)]
# X + Z ----> Z + Z;  [MAK(0.9541357159614563)]
# ∅ ----> ∅;  [MAK(2.569920778274536)]
# IOCRN 60, Reward: 0.059021771148121085
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(0.5450555086135864)]
# ∅ ----> X + X;  [MAK(0.7173168063163757)]
# X + Z ----> Z + Z;  [MAK(0.9652889966964722)]
# IOCRN 61, Reward: 0.06015156044523927
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0521091222763062)]
# ∅ ----> X + X;  [MAK(0.5980356931686401)]
# ∅ ----> X;  [MAK(9.238754272460938)]
# IOCRN 62, Reward: 0.06120441030615411
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.884621798992157)]
# X + Z ----> Z + Z;  [MAK(0.9557428359985352)]
# X ----> X + X;  [MAK(3.1600115299224854)]
# IOCRN 63, Reward: 0.06155184617588751
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7226673364639282)]
# X + Z ----> Z + Z;  [MAK(1.0526477098464966)]
# X ----> X + X;  [MAK(1.396479845046997)]
# IOCRN 64, Reward: 0.06168268738646546
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.054796814918518)]
# ∅ ----> X + X;  [MAK(0.6344691514968872)]
# ∅ ----> X;  [MAK(3.734732151031494)]
# IOCRN 65, Reward: 0.062187340295539316
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0734772682189941)]
# X + Z ----> Z + Z;  [MAK(0.9513517618179321)]
# ∅ ----> X;  [MAK(2.913576602935791)]
# IOCRN 66, Reward: 0.06328059029223959
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.2063366174697876)]
# X + Z ----> Z + Z;  [MAK(0.9498997330665588)]
# ∅ ----> X;  [MAK(0.8833692073822021)]
# IOCRN 67, Reward: 0.06336554902134482
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.7071606516838074)]
# X + Z ----> Z + Z;  [MAK(0.9743891358375549)]
# ∅ ----> X;  [MAK(0.3984346389770508)]
# IOCRN 68, Reward: 0.0651852854486607
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(4.238621711730957)]
# X + Z ----> Z + Z;  [MAK(1.0572632551193237)]
# ∅ ----> X + X;  [MAK(4.270018577575684)]
# IOCRN 69, Reward: 0.06536496984504796
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X ----> X + X;  [MAK(1.092795729637146)]
# ∅ ----> X + X;  [MAK(0.8654413223266602)]
# X + Z ----> Z + Z;  [MAK(0.949348509311676)]
# IOCRN 70, Reward: 0.06588835007275806
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X ----> X + X;  [MAK(1.5378286838531494)]
# ∅ ----> X;  [MAK(4.954753875732422)]
# X + Z ----> Z + Z;  [MAK(1.057482361793518)]
# IOCRN 71, Reward: 0.06743150978749939
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.3757507801055908)]
# X + Z ----> Z + Z;  [MAK(0.9464976191520691)]
# ∅ ----> X;  [MAK(0.8934682607650757)]
# IOCRN 72, Reward: 0.06744482935375898
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.405761957168579)]
# X ----> X + X;  [MAK(1.2344202995300293)]
# X + Z ----> Z + Z;  [MAK(1.0596144199371338)]
# IOCRN 73, Reward: 0.0678890680028055
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.5422077178955078)]
# X + Z ----> Z + Z;  [MAK(0.9929714798927307)]
# ∅ ----> X;  [MAK(0.42138671875)]
# IOCRN 74, Reward: 0.0687973308149752
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X + Z ----> Z + Z;  [MAK(1.0610281229019165)]
# X ----> X + X;  [MAK(1.1955876350402832)]
# ∅ ----> X;  [MAK(5.376683235168457)]
# IOCRN 75, Reward: 0.06912491504239825
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# X ----> X + X;  [MAK(3.7759275436401367)]
# ∅ ----> X;  [MAK(1.5671849250793457)]
# X + Z ----> Z + Z;  [MAK(1.0577417612075806)]
# IOCRN 76, Reward: 0.06927780481199863
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.450917959213257)]
# X + Z ----> Z + Z;  [MAK(1.0611989498138428)]
# ∅ ----> X + X;  [MAK(7.899166107177734)]
# IOCRN 77, Reward: 0.07054695170729777
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(3.009791612625122)]
# X ----> X + X;  [MAK(1.1879374980926514)]
# X + Z ----> Z + Z;  [MAK(1.0631053447723389)]
# IOCRN 78, Reward: 0.07058534817353697
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(11.342723846435547)]
# X ----> X + X;  [MAK(1.1169540882110596)]
# X + Z ----> Z + Z;  [MAK(1.0626050233840942)]
# IOCRN 79, Reward: 0.0711983480617402
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.8330171704292297)]
# X + Z ----> Z + Z;  [MAK(0.9486545324325562)]
# X ----> X + X;  [MAK(5.2977142333984375)]
# IOCRN 80, Reward: 0.07127017658889752
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(2.455073118209839)]
# X + Z ----> Z;  [MAK(0.884771466255188)]
# X + Z ----> Z + Z;  [MAK(0.9428494572639465)]
# IOCRN 81, Reward: 0.07150911903824658
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.2795108556747437)]
# X + Z ----> Z + Z;  [MAK(0.9437277317047119)]
# ∅ ----> X;  [MAK(4.003566265106201)]
# IOCRN 82, Reward: 0.07199805933541616
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.547047734260559)]
# X + Z ----> Z + Z;  [MAK(0.9415807127952576)]
# X + Z ----> Z;  [MAK(1.0219770669937134)]
# IOCRN 83, Reward: 0.07241081301719002
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.5999216437339783)]
# X + Z ----> Z + Z;  [MAK(1.0663827657699585)]
# ∅ ----> X;  [MAK(4.1551594734191895)]
# IOCRN 84, Reward: 0.07331622833284138
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(3.8113176822662354)]
# X + Z ----> Z + Z;  [MAK(0.8326007723808289)]
# ∅ ----> Z + Z;  [MAK(0.937012791633606)]
# IOCRN 85, Reward: 0.07349308629569362
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.6269005537033081)]
# X + Z ----> Z + Z;  [MAK(1.067833423614502)]
# ∅ ----> X;  [MAK(3.341890335083008)]
# IOCRN 86, Reward: 0.07452668594334828
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0034579038619995)]
# X + Z ----> Z + Z;  [MAK(1.0707916021347046)]
# ∅ ----> X;  [MAK(0.43618354201316833)]
# IOCRN 87, Reward: 0.07506067304322447
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.814032793045044)]
# X + Z ----> Z + Z;  [MAK(1.0679627656936646)]
# X ----> X + X;  [MAK(1.2119464874267578)]
# IOCRN 88, Reward: 0.07787567206609353
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.9935195446014404)]
# X + Z ----> Z + Z;  [MAK(0.9383143186569214)]
# ∅ ----> X;  [MAK(4.1284990310668945)]
# IOCRN 89, Reward: 0.07837735959036003
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(0.8875484466552734)]
# ∅ ----> X + X;  [MAK(1.0489161014556885)]
# X + Z ----> Z + Z;  [MAK(0.9370157718658447)]
# IOCRN 90, Reward: 0.07910111672312811
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.2118349075317383)]
# X ----> X + X;  [MAK(0.9108915328979492)]
# X + Z ----> Z + Z;  [MAK(0.9373765587806702)]
# IOCRN 91, Reward: 0.07963773167574514
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.0494890213012695)]
# X + Z ----> Z + Z;  [MAK(0.9366679787635803)]
# ∅ ----> X;  [MAK(3.131696939468384)]
# IOCRN 92, Reward: 0.08024611780416982
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.57335364818573)]
# X + Z ----> Z + Z;  [MAK(0.9362919926643372)]
# X ----> X + X;  [MAK(0.7323831915855408)]
# IOCRN 93, Reward: 0.08196697427328636
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.077405333518982)]
# X + Z ----> Z + Z;  [MAK(0.9350425004959106)]
# ∅ ----> X;  [MAK(4.672333717346191)]
# IOCRN 94, Reward: 0.08260592612012536
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(6.47875452041626)]
# X + Z ----> Z + Z;  [MAK(0.8173887133598328)]
# X + X ----> Z;  [MAK(0.8925305008888245)]
# IOCRN 95, Reward: 0.08297982307727648
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.062648892402649)]
# X + Z ----> Z + Z;  [MAK(0.9337822198867798)]
# ∅ ----> X;  [MAK(2.5788867473602295)]
# IOCRN 96, Reward: 0.08307464506720309
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.3103085458278656)]
# X + Z ----> Z + Z;  [MAK(1.0791501998901367)]
# ∅ ----> X;  [MAK(2.8211941719055176)]
# IOCRN 97, Reward: 0.0832050655198729
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(1.3073201179504395)]
# ∅ ----> X;  [MAK(0.9129559397697449)]
# X + Z ----> Z + Z;  [MAK(0.9332509636878967)]
# IOCRN 98, Reward: 0.08328221703782906
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X + X;  [MAK(0.6153969168663025)]
# ∅ ----> X;  [MAK(1.1341224908828735)]
# X + Z ----> Z + Z;  [MAK(0.9284220337867737)]
# IOCRN 99, Reward: 0.08410546433235601
# Inputs: ['u_1', 'u_2']
# Species: ['X', 'Z']
# Output Species: ['X']
# Z ----> ∅;  [MAK(1.0, u_1)]
# X ----> ∅;  [MAK(1.0, u_2)]
# ∅ ----> X;  [MAK(2.743959665298462)]
# X + Z ----> Z + Z;  [MAK(1.078306794166565)]
# ∅ ----> X + X;  [MAK(4.208402156829834)]

# %%
if save_flag:
    torch.save(agent.policy.state_dict(), save_filename)
